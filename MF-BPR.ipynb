# %%
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot

from Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Utils.DataReader import load_urm, load_icm, load_target

# %%
URM_all = load_urm()

URM_train, URM_test = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.85)
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_train, train_percentage = 0.85)

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=[10])
# Out:
# Warning: 3084 (7.41 %) of 41629 users have no sampled items
# Warning: 1 (0.00 %) of 41629 users have no train items
# Warning: 4339 (10.42 %) of 41629 users have no sampled items
# EvaluatorHoldout: Ignoring 4339 (10.4%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 3084 ( 7.4%) Users that have less than 1 test interactions

# %% [markdown]
# ## MF-BPR

# %%
from Recommenders.MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_BPR_Cython

recommender_class = MatrixFactorization_BPR_Cython

# %%
import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 20
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from skopt.space import Real, Integer, Categorical
#SLIM BPR is machine learning-based technique
#Hyperparameter tuning is typical of ML models to drive the learning process

hyperparameters_range_dictionary = {
    "epochs": Categorical([100]),
    "sgd_mode": Categorical(["sgd", "adagrad", "adam"]),
    "num_factors": Integer(1, 200),
    "batch_size": Categorical([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]),
    "user_reg": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
    "learning_rate": Real(low = 1e-4, high = 1e-1, prior = 'log-uniform'),
}

# %% [markdown]
# Early Stopping Setup

# %%
earlystopping_keywargs = {"validation_every_n": 10,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 10,
                          "validation_metric": metric_to_optimize,
                          }

# %% [markdown]
# We create a bayesian optimizer object, we pass the recommender and the evaluator

# %%
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                           evaluator_validation=evaluator_validation)

# %% [markdown]
# We provide the data needed to create an instance of the model, one on the URM_train, the other on the URM_all

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)

recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_all],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)

# %% [markdown]
# ### Cython

# %%
import pyximport
pyximport.install()
# Out:
# (None, <pyximport.pyximport.PyxImporter at 0x21fa2622670>)

# %%
# !python run_compile_all_cython.py
# Out:
# run_compile_all_cython: Found 10 Cython files in 4 folders...
# run_compile_all_cython: All files will be compiled using your current python environment: 'C:\Users\Luca\miniconda3\python.exe'
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx...
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx... PASS
#
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx...
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx... PASS
#
# Compiling [3/10]: Compute_Similarity_Cython.pyx...
# Compiling [3/10]: Compute_Similarity_Cython.pyx... PASS
#
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx...
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx... PASS
#
# Compiling [5/10]: Sparse_Matrix_Tree_CSR.pyx...
# Compiling [5/10]: Sparse_Matrix_Tree_CSR.pyx... PASS
#
# Compiling [6/10]: Triangular_Matrix.pyx...
# Compiling [6/10]: Triangular_Matrix.pyx... PASS
#
# Compiling [7/10]: CFW_DVV_Similarity_Cython_SGD.pyx...
# Compiling [7/10]: CFW_DVV_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [8/10]: CFW_D_Similarity_Cython_SGD.pyx...
# Compiling [8/10]: CFW_D_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [9/10]: FBSM_Rating_Cython_SGD.pyx...
# Compiling [9/10]: FBSM_Rating_Cython_SGD.pyx... PASS
#
# Compiling [10/10]: HP3_Similarity_Cython_SGD.pyx...
# Compiling [10/10]: HP3_Similarity_Cython_SGD.pyx... PASS
#
# run_compile_all_cython: Compilation finished. SUCCESS.
# Compilation log can be found here: './result_experiments/run_compile_all_cython.txt'
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\MatrixFactorization\Cython\MatrixFactorizationImpressions_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\MatrixFactorization\Cython\MatrixFactorization_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\Similarity\Cython\Compute_Similarity_Cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\SLIM\Cython\SLIM_BPR_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\SLIM\Cython\Sparse_Matrix_Tree_CSR.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\SLIM\Cython\Triangular_Matrix.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\FeatureWeighting\Cython\CFW_DVV_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\FeatureWeighting\Cython\CFW_D_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\FeatureWeighting\Cython\FBSM_Rating_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\FeatureWeighting\Cython\HP3_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access

# %% [markdown]
# ### Bayesian Search

# %%
hyperparameterSearch.search(recommender_input_args,
                            recommender_input_args_last_test = recommender_input_args_last_test,
                            hyperparameter_search_space = hyperparameters_range_dictionary,
                            n_cases = n_cases,
                            n_random_starts = n_random_starts,
                            save_model = "last",
                            output_folder_path = output_folder_path, # Where to save the results
                            output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                            metric_to_optimize = metric_to_optimize,
                            cutoff_to_optimize = cutoff_to_optimize,
                            )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'epochs': 100, 'sgd_mode': 'adam', 'num_factors': 17, 'batch_size': 4, 'user_reg': 0.00015002679963372703, 'learning_rate': 0.0003162906336872413}
# MatrixFactorization_BPR_Cython_Recommender: URM Detected 1 ( 0.0%) users with no interactions.
# MF_BPR: Processed 41632 (100.0%) in 0.69 sec. MSE loss 3.41E-03. Sample per second: 60074
# MF_BPR: Epoch 1 of 100. Elapsed time 0.51 sec
# MF_BPR: Processed 41632 (100.0%) in 0.96 sec. MSE loss 3.39E-03. Sample per second: 43581
# MF_BPR: Epoch 2 of 100. Elapsed time 0.77 sec
# MF_BPR: Processed 41632 (100.0%) in 1.28 sec. MSE loss 3.40E-03. Sample per second: 32640
# MF_BPR: Epoch 3 of 100. Elapsed time 1.10 sec
# MF_BPR: Processed 41632 (100.0%) in 0.53 sec. MSE loss 3.41E-03. Sample per second: 79036
# MF_BPR: Epoch 4 of 100. Elapsed time 1.35 sec
# MF_BPR: Processed 41632 (100.0%) in 0.83 sec. MSE loss 3.40E-03. Sample per second: 50282
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 42.86 sec. Users per second: 870
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0001582, PRECISION_RECALL_MIN_DEN: 0.0004091, RECALL: 0.0004010, MAP: 0.0000437, MAP_MIN_DEN: 0.0001359, MRR: 0.0004370, NDCG: 0.0002802, F1: 0.0002269, HIT_RATE: 0.0015822, ARHR_ALL_HITS: 0.0004370, NOVELTY: 0.0062930, AVERAGE_POPULARITY: 0.0055180, DIVERSITY_MEAN_INTER_LIST: 0.9961182, DIVERSITY_HERFINDAHL: 0.9996091, COVERAGE_ITEM: 0.4763129, COVERAGE_ITEM_HIT: 0.0021218, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0014173, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.1420021, SHANNON_ENTROPY: 12.1268707, RATIO_DIVERSITY_HERFINDAHL: 1.0000734, RATIO_DIVERSITY_GINI: 0.3238328, RATIO_SHANNON_ENTROPY: 0.9199507, RATIO_AVERAGE_POPULARITY: 0.0906350, RATIO_NOVELTY: 0.6408759,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 5 of 100. Elapsed time 44.53 sec
# MF_BPR: Processed 41632 (100.0%) in 1.13 sec. MSE loss 3.43E-03. Sample per second: 36804
# MF_BPR: Epoch 6 of 100. Elapsed time 44.95 sec
# MF_BPR: Processed 41632 (100.0%) in 0.48 sec. MSE loss 3.44E-03. Sample per second: 85980
# MF_BPR: Epoch 7 of 100. Elapsed time 45.30 sec
# MF_BPR: Processed 41632 (100.0%) in 0.80 sec. MSE loss 3.49E-03. Sample per second: 52275
# MF_BPR: Epoch 8 of 100. Elapsed time 45.62 sec
# MF_BPR: Processed 41632 (100.0%) in 1.12 sec. MSE loss 3.50E-03. Sample per second: 37321
# MF_BPR: Epoch 9 of 100. Elapsed time 45.94 sec
# MF_BPR: Processed 41632 (100.0%) in 0.44 sec. MSE loss 3.50E-03. Sample per second: 95342
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 48.37 sec. Users per second: 771
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0001689, PRECISION_RECALL_MIN_DEN: 0.0004303, RECALL: 0.0004233, MAP: 0.0000476, MAP_MIN_DEN: 0.0001254, MRR: 0.0004707, NDCG: 0.0002860, F1: 0.0002415, HIT_RATE: 0.0016626, ARHR_ALL_HITS: 0.0004734, NOVELTY: 0.0062844, AVERAGE_POPULARITY: 0.0057945, DIVERSITY_MEAN_INTER_LIST: 0.9961486, DIVERSITY_HERFINDAHL: 0.9996122, COVERAGE_ITEM: 0.4760273, COVERAGE_ITEM_HIT: 0.0022035, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0014893, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.1423481, SHANNON_ENTROPY: 12.1321755, RATIO_DIVERSITY_HERFINDAHL: 1.0000764, RATIO_DIVERSITY_GINI: 0.3246221, RATIO_SHANNON_ENTROPY: 0.9203531, RATIO_AVERAGE_POPULARITY: 0.0951755, RATIO_NOVELTY: 0.6400013,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 10 of 100. Elapsed time 1.58 min
# MF_BPR: Processed 41632 (100.0%) in 1.23 sec. MSE loss 3.54E-03. Sample per second: 33909
# MF_BPR: Epoch 11 of 100. Elapsed time 1.58 min
# MF_BPR: Processed 41632 (100.0%) in 0.56 sec. MSE loss 3.57E-03. Sample per second: 74761
# MF_BPR: Epoch 12 of 100. Elapsed time 1.59 min
# MF_BPR: Processed 41632 (100.0%) in 0.88 sec. MSE loss 3.51E-03. Sample per second: 47309
# MF_BPR: Epoch 13 of 100. Elapsed time 1.60 min
# MF_BPR: Processed 41632 (100.0%) in 1.27 sec. MSE loss 3.61E-03. Sample per second: 32731
# MF_BPR: Epoch 14 of 100. Elapsed time 1.60 min
# MF_BPR: Processed 41632 (100.0%) in 0.63 sec. MSE loss 3.62E-03. Sample per second: 66286
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 48.57 sec. Users per second: 768
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0001663, PRECISION_RECALL_MIN_DEN: 0.0004294, RECALL: 0.0004235, MAP: 0.0000519, MAP_MIN_DEN: 0.0001452, MRR: 0.0005134, NDCG: 0.0003054, F1: 0.0002388, HIT_RATE: 0.0016358, ARHR_ALL_HITS: 0.0005164, NOVELTY: 0.0062767, AVERAGE_POPULARITY: 0.0061502, DIVERSITY_MEAN_INTER_LIST: 0.9961548, DIVERSITY_HERFINDAHL: 0.9996128, COVERAGE_ITEM: 0.4767209, COVERAGE_ITEM_HIT: 0.0021218, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0014653, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.1421615, SHANNON_ENTROPY: 12.1314702, RATIO_DIVERSITY_HERFINDAHL: 1.0000771, RATIO_DIVERSITY_GINI: 0.3241965, RATIO_SHANNON_ENTROPY: 0.9202996, RATIO_AVERAGE_POPULARITY: 0.1010178, RATIO_NOVELTY: 0.6392168,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch

#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 60 of 100. Elapsed time 9.26 min
# MF_BPR: Processed 41632 (100.0%) in 0.92 sec. MSE loss 6.04E-03. Sample per second: 45085
# MF_BPR: Epoch 61 of 100. Elapsed time 9.26 min
# MF_BPR: Processed 41632 (100.0%) in 1.30 sec. MSE loss 6.23E-03. Sample per second: 31966
# MF_BPR: Epoch 62 of 100. Elapsed time 9.27 min
# MF_BPR: Processed 41632 (100.0%) in 0.68 sec. MSE loss 6.45E-03. Sample per second: 60832
# MF_BPR: Epoch 63 of 100. Elapsed time 9.28 min
# MF_BPR: Processed 41632 (100.0%) in 0.99 sec. MSE loss 6.47E-03. Sample per second: 41901
# MF_BPR: Epoch 64 of 100. Elapsed time 9.28 min
# MF_BPR: Processed 41632 (100.0%) in 1.30 sec. MSE loss 6.54E-03. Sample per second: 31909
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 48.11 sec. Users per second: 775
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0026173, PRECISION_RECALL_MIN_DEN: 0.0069680, RECALL: 0.0068873, MAP: 0.0014569, MAP_MIN_DEN: 0.0039864, MRR: 0.0139464, NDCG: 0.0067693, F1: 0.0037932, HIT_RATE: 0.0249933, ARHR_ALL_HITS: 0.0142489, NOVELTY: 0.0057083, AVERAGE_POPULARITY: 0.0873863, DIVERSITY_MEAN_INTER_LIST: 0.9828814, DIVERSITY_HERFINDAHL: 0.9982855, COVERAGE_ITEM: 0.4432203, COVERAGE_ITEM_HIT: 0.0036316, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0223882, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.1105338, SHANNON_ENTROPY: 11.4401279, RATIO_DIVERSITY_HERFINDAHL: 0.9987491, RATIO_DIVERSITY_GINI: 0.2520700, RATIO_SHANNON_ENTROPY: 0.8678540, RATIO_AVERAGE_POPULARITY: 1.4353392, RATIO_NOVELTY: 0.5813357,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 65 of 100. Elapsed time 10.09 min
# MF_BPR: Processed 41632 (100.0%) in 0.76 sec. MSE loss 6.64E-03. Sample per second: 54482
# MF_BPR: Epoch 66 of 100. Elapsed time 10.09 min
# MF_BPR: Processed 41632 (100.0%) in 1.07 sec. MSE loss 6.79E-03. Sample per second: 39079
# MF_BPR: Epoch 67 of 100. Elapsed time 10.10 min
# MF_BPR: Processed 41632 (100.0%) in 0.36 sec. MSE loss 6.92E-03. Sample per second: 115778
# MF_BPR: Epoch 68 of 100. Elapsed time 10.10 min
# MF_BPR: Processed 41632 (100.0%) in 0.69 sec. MSE loss 7.05E-03. Sample per second: 60191
# MF_BPR: Epoch 69 of 100. Elapsed time 10.11 min
# MF_BPR: Processed 41632 (100.0%) in 0.98 sec. MSE loss 7.18E-03. Sample per second: 42312
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 47.88 sec. Users per second: 779
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0031698, PRECISION_RECALL_MIN_DEN: 0.0083770, RECALL: 0.0082673, MAP: 0.0017503, MAP_MIN_DEN: 0.0047151, MRR: 0.0165994, NDCG: 0.0080710, F1: 0.0045825, HIT_RATE: 0.0300617, ARHR_ALL_HITS: 0.0170415, NOVELTY: 0.0055854, AVERAGE_POPULARITY: 0.1052443, DIVERSITY_MEAN_INTER_LIST: 0.9767280, DIVERSITY_HERFINDAHL: 0.9976702, COVERAGE_ITEM: 0.4322847, COVERAGE_ITEM_HIT: 0.0039581, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 49.42 sec. Users per second: 755
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0043899, PRECISION_RECALL_MIN_DEN: 0.0116182, RECALL: 0.0114759, MAP: 0.0022567, MAP_MIN_DEN: 0.0059985, MRR: 0.0211051, NDCG: 0.0105932, F1: 0.0063505, HIT_RATE: 0.0410029, ARHR_ALL_HITS: 0.0218148, NOVELTY: 0.0053310, AVERAGE_POPULARITY: 0.1414867, DIVERSITY_MEAN_INTER_LIST: 0.9608663, DIVERSITY_HERFINDAHL: 0.9960841, COVERAGE_ITEM: 0.4127800, COVERAGE_ITEM_HIT: 0.0047333, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0367292, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0872820, SHANNON_ENTROPY: 10.7361908, RATIO_DIVERSITY_HERFINDAHL: 0.9965467, RATIO_DIVERSITY_GINI: 0.1990447, RATIO_SHANNON_ENTROPY: 0.8144530, RATIO_AVERAGE_POPULARITY: 2.3239492, RATIO_NOVELTY: 0.5429130,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 80 of 100. Elapsed time 12.59 min
# MF_BPR: Processed 41632 (100.0%) in 1.16 sec. MSE loss 9.13E-03. Sample per second: 35767
# MF_BPR: Epoch 81 of 100. Elapsed time 12.60 min
# MF_BPR: Processed 41632 (100.0%) in 0.56 sec. MSE loss 9.19E-03. Sample per second: 74353
# MF_BPR: Epoch 82 of 100. Elapsed time 12.61 min
# MF_BPR: Processed 41632 (100.0%) in 0.97 sec. MSE loss 9.75E-03. Sample per second: 43060
# MF_BPR: Epoch 83 of 100. Elapsed time 12.61 min
# MF_BPR: Processed 41632 (100.0%) in 1.36 sec. MSE loss 1.00E-02. Sample per second: 30662
# MF_BPR: Epoch 84 of 100. Elapsed time 12.62 min
# MF_BPR: Processed 41632 (100.0%) in 0.74 sec. MSE loss 9.87E-03. Sample per second: 55975
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 47.23 sec. Users per second: 789
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0050550, PRECISION_RECALL_MIN_DEN: 0.0132964, RECALL: 0.0131314, MAP: 0.0025197, MAP_MIN_DEN: 0.0066523, MRR: 0.0234526, NDCG: 0.0119095, F1: 0.0072999, HIT_RATE: 0.0470099, ARHR_ALL_HITS: 0.0243028, NOVELTY: 0.0051979, AVERAGE_POPULARITY: 0.1599416, DIVERSITY_MEAN_INTER_LIST: 0.9509800, DIVERSITY_HERFINDAHL: 0.9950955, COVERAGE_ITEM: 0.4006610, COVERAGE_ITEM_HIT: 0.0048966, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0421101, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0793211, SHANNON_ENTROPY: 10.4643200, RATIO_DIVERSITY_HERFINDAHL: 0.9955576, RATIO_DIVERSITY_GINI: 0.1808901, RATIO_SHANNON_ENTROPY: 0.7938287, RATIO_AVERAGE_POPULARITY: 2.6270751, RATIO_NOVELTY: 0.5293599,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch

#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 95 of 100. Elapsed time 15.03 min
# MF_BPR: Processed 41632 (100.0%) in 0.44 sec. MSE loss 1.40E-02. Sample per second: 95083
# MF_BPR: Epoch 96 of 100. Elapsed time 15.04 min
# MF_BPR: Processed 41632 (100.0%) in 0.78 sec. MSE loss 1.44E-02. Sample per second: 53107
# MF_BPR: Epoch 97 of 100. Elapsed time 15.04 min
# MF_BPR: Processed 41632 (100.0%) in 1.14 sec. MSE loss 1.45E-02. Sample per second: 36647
# MF_BPR: Epoch 98 of 100. Elapsed time 15.05 min
# MF_BPR: Processed 41632 (100.0%) in 0.52 sec. MSE loss 1.47E-02. Sample per second: 80371
# MF_BPR: Epoch 99 of 100. Elapsed time 15.06 min
# MF_BPR: Processed 41632 (100.0%) in 0.86 sec. MSE loss 1.52E-02. Sample per second: 48350
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 47.44 sec. Users per second: 786
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0069107, PRECISION_RECALL_MIN_DEN: 0.0184352, RECALL: 0.0182143, MAP: 0.0033005, MAP_MIN_DEN: 0.0087318, MRR: 0.0300370, NDCG: 0.0158181, F1: 0.0100198, HIT_RATE: 0.0624564, ARHR_ALL_HITS: 0.0314599, NOVELTY: 0.0048329, AVERAGE_POPULARITY: 0.2106117, DIVERSITY_MEAN_INTER_LIST: 0.9175324, DIVERSITY_HERFINDAHL: 0.9917508, COVERAGE_ITEM: 0.3636920, COVERAGE_ITEM_HIT: 0.0052230, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0559466, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0580538, SHANNON_ENTROPY: 9.6498157, RATIO_DIVERSITY_HERFINDAHL: 0.9922114, RATIO_DIVERSITY_GINI: 0.1323905, RATIO_SHANNON_ENTROPY: 0.7320400, RATIO_AVERAGE_POPULARITY: 3.4593416, RATIO_NOVELTY: 0.4921785,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 100 of 100. Elapsed time 15.85 min
# MF_BPR: Terminating at epoch 100. Best value for 'MAP' at epoch 100 is 0.0033. Elapsed time 15.85 min
# EvaluatorHoldout: Processed 37290 (100.0%) in 47.74 sec. Users per second: 781
# SearchBayesianSkopt: New best config found. Config 0: {'epochs': 100, 'sgd_mode': 'adam', 'num_factors': 17, 'batch_size': 4, 'user_reg': 0.00015002679963372703, 'learning_rate': 0.0003162906336872413} - results: PRECISION: 0.0069107, PRECISION_RECALL_MIN_DEN: 0.0184352, RECALL: 0.0182143, MAP: 0.0033005, MAP_MIN_DEN: 0.0087318, MRR: 0.0300370, NDCG: 0.0158181, F1: 0.0100198, HIT_RATE: 0.0624564, ARHR_ALL_HITS: 0.0314599, NOVELTY: 0.0048329, AVERAGE_POPULARITY: 0.2106117, DIVERSITY_MEAN_INTER_LIST: 0.9175324, DIVERSITY_HERFINDAHL: 0.9917508, COVERAGE_ITEM: 0.3636920, COVERAGE_ITEM_HIT: 0.0052230, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0559466, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0580538, SHANNON_ENTROPY: 9.6498157, RATIO_DIVERSITY_HERFINDAHL: 0.9922114, RATIO_DIVERSITY_GINI: 0.1323905, RATIO_SHANNON_ENTROPY: 0.7320400, RATIO_AVERAGE_POPULARITY: 3.4593416, RATIO_NOVELTY: 0.4921785,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 999.3295
# Function value obtained: -0.0033
# Current minimum: -0.0033
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'epochs': 100, 'sgd_mode': 'adagrad', 'num_factors': 64, 'batch_size': 128, 'user_reg': 5.372533789839864e-05, 'learning_rate': 0.03449265149936343}
# MatrixFactorization_BPR_Cython_Recommender: URM Detected 1 ( 0.0%) users with no interactions.
# MF_BPR: Processed 41728 (100.0%) in 1.58 sec. MSE loss 1.93E-02. Sample per second: 26344
# MF_BPR: Epoch 1 of 100. Elapsed time 0.89 sec
# MF_BPR: Processed 41728 (100.0%) in 1.41 sec. MSE loss 2.89E-02. Sample per second: 29504
# MF_BPR: Epoch 2 of 100. Elapsed time 1.73 sec
# MF_BPR: Processed 41728 (100.0%) in 1.29 sec. MSE loss 3.62E-02. Sample per second: 32400
# MF_BPR: Epoch 3 of 100. Elapsed time 2.60 sec
# MF_BPR: Processed 41728 (100.0%) in 1.17 sec. MSE loss 4.39E-02. Sample per second: 35527
# MF_BPR: Epoch 4 of 100. Elapsed time 3.49 sec
# MF_BPR: Processed 41728 (100.0%) in 0.97 sec. MSE loss 5.09E-02. Sample per second: 43086
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 43.98 sec. Users per second: 848
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0005283, PRECISION_RECALL_MIN_DEN: 0.0015010, RECALL: 0.0014873, MAP: 0.0001790, MAP_MIN_DEN: 0.0004893, MRR: 0.0017903, NDCG: 0.0010426, F1: 0.0007797, HIT_RATE: 0.0052829, ARHR_ALL_HITS: 0.0017903, NOVELTY: 0.0060531, AVERAGE_POPULARITY: 0.0189855, DIVERSITY_MEAN_INTER_LIST: 0.9985130, DIVERSITY_HERFINDAHL: 0.9998486, COVERAGE_ITEM: 0.8869303, COVERAGE_ITEM_HIT: 0.0047741, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0047323, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.3618548, SHANNON_ENTROPY: 13.4674884, RATIO_DIVERSITY_HERFINDAHL: 1.0003130, RATIO_DIVERSITY_GINI: 0.8252026, RATIO_SHANNON_ENTROPY: 1.0216507, RATIO_AVERAGE_POPULARITY: 0.3118403, RATIO_NOVELTY: 0.6164502,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 5 of 100. Elapsed time 48.31 sec
# MF_BPR: Processed 41728 (100.0%) in 1.89 sec. MSE loss 5.87E-02. Sample per second: 22086
# MF_BPR: Epoch 6 of 100. Elapsed time 49.20 sec
# MF_BPR: Processed 41728 (100.0%) in 1.65 sec. MSE loss 6.71E-02. Sample per second: 25316
# MF_BPR: Epoch 7 of 100. Elapsed time 49.96 sec
# MF_BPR: Processed 41728 (100.0%) in 1.44 sec. MSE loss 7.47E-02. Sample per second: 29050
# MF_BPR: Epoch 8 of 100. Elapsed time 50.75 sec
# MF_BPR: Processed 41728 (100.0%) in 1.22 sec. MSE loss 8.46E-02. Sample per second: 34262
# MF_BPR: Epoch 9 of 100. Elapsed time 51.53 sec
# MF_BPR: Processed 41728 (100.0%) in 1.06 sec. MSE loss 9.37E-02. Sample per second: 39228
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 43.83 sec. Users per second: 851
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0014427, PRECISION_RECALL_MIN_DEN: 0.0039540, RECALL: 0.0039152, MAP: 0.0006527, MAP_MIN_DEN: 0.0017688, MRR: 0.0064130, NDCG: 0.0033030, F1: 0.0021085, HIT_RATE: 0.0141593, ARHR_ALL_HITS: 0.0064698, NOVELTY: 0.0057802, AVERAGE_POPULARITY: 0.0466949, DIVERSITY_MEAN_INTER_LIST: 0.9961502, DIVERSITY_HERFINDAHL: 0.9996123, COVERAGE_ITEM: 0.8423716, COVERAGE_ITEM_HIT: 0.0068144, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0126835, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.2898902, SHANNON_ENTROPY: 12.9806256, RATIO_DIVERSITY_HERFINDAHL: 1.0000766, RATIO_DIVERSITY_GINI: 0.6610888, RATIO_SHANNON_ENTROPY: 0.9847170, RATIO_AVERAGE_POPULARITY: 0.7669729, RATIO_NOVELTY: 0.5886520,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 10 of 100. Elapsed time 1.60 min
# MF_BPR: Processed 41728 (100.0%) in 1.78 sec. MSE loss 1.03E-01. Sample per second: 23369
# MF_BPR: Epoch 11 of 100. Elapsed time 1.62 min
# MF_BPR: Processed 41728 (100.0%) in 1.63 sec. MSE loss 1.14E-01. Sample per second: 25548
# MF_BPR: Epoch 12 of 100. Elapsed time 1.63 min
# MF_BPR: Processed 41728 (100.0%) in 1.47 sec. MSE loss 1.26E-01. Sample per second: 28462
# MF_BPR: Epoch 13 of 100. Elapsed time 1.65 min
# MF_BPR: Processed 41728 (100.0%) in 1.26 sec. MSE loss 1.41E-01. Sample per second: 33146
# MF_BPR: Epoch 14 of 100. Elapsed time 1.66 min
# MF_BPR: Processed 41728 (100.0%) in 1.04 sec. MSE loss 1.54E-01. Sample per second: 40243
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 42.73 sec. Users per second: 873
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0034057, PRECISION_RECALL_MIN_DEN: 0.0091357, RECALL: 0.0090410, MAP: 0.0015634, MAP_MIN_DEN: 0.0042586, MRR: 0.0149038, NDCG: 0.0077929, F1: 0.0049477, HIT_RATE: 0.0323947, ARHR_ALL_HITS: 0.0152626, NOVELTY: 0.0053748, AVERAGE_POPULARITY: 0.0924640, DIVERSITY_MEAN_INTER_LIST: 0.9871764, DIVERSITY_HERFINDAHL: 0.9987150, COVERAGE_ITEM: 0.7805525, COVERAGE_ITEM_HIT: 0.0080385, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0290182, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.2069767, SHANNON_ENTROPY: 12.1138289, RATIO_DIVERSITY_HERFINDAHL: 0.9991788, RATIO_DIVERSITY_GINI: 0.4720062, RATIO_SHANNON_ENTROPY: 0.9189613, RATIO_AVERAGE_POPULARITY: 1.5187404, RATIO_NOVELTY: 0.5473745,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 15 of 100. Elapsed time 2.39 min
# MF_BPR: Processed 41728 (100.0%) in 1.67 sec. MSE loss 1.68E-01. Sample per second: 25021
# MF_BPR: Epoch 16 of 100. Elapsed time 2.40 min
# MF_BPR: Processed 41728 (100.0%) in 1.42 sec. MSE loss 1.87E-01. Sample per second: 29371
# MF_BPR: Epoch 17 of 100. Elapsed time 2.41 min
# MF_BPR: Processed 41728 (100.0%) in 1.20 sec. MSE loss 2.01E-01. Sample per second: 34670
# MF_BPR: Epoch 18 of 100. Elapsed time 2.43 min
# MF_BPR: Processed 41728 (100.0%) in 1.04 sec. MSE loss 2.19E-01. Sample per second: 40246
# MF_BPR: Epoch 19 of 100. Elapsed time 2.44 min
# MF_BPR: Processed 41728 (100.0%) in 0.87 sec. MSE loss 2.42E-01. Sample per second: 47707
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 42.63 sec. Users per second: 875
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0059319, PRECISION_RECALL_MIN_DEN: 0.0156412, RECALL: 0.0154616, MAP: 0.0025929, MAP_MIN_DEN: 0.0067882, MRR: 0.0236750, NDCG: 0.0127873, F1: 0.0085742, HIT_RATE: 0.0539823, ARHR_ALL_HITS: 0.0247640, NOVELTY: 0.0049497, AVERAGE_POPULARITY: 0.1448125, DIVERSITY_MEAN_INTER_LIST: 0.9688229, DIVERSITY_HERFINDAHL: 0.9968797, COVERAGE_ITEM: 0.7002897, COVERAGE_ITEM_HIT: 0.0096707, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0483557, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.1384052, SHANNON_ENTROPY: 11.0565260, RATIO_DIVERSITY_HERFINDAHL: 0.9973427, RATIO_DIVERSITY_GINI: 0.3156303, RATIO_SHANNON_ENTROPY: 0.8387538, RATIO_AVERAGE_POPULARITY: 2.3785757, RATIO_NOVELTY: 0.5040808,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 20 of 100. Elapsed time 3.16 min
# MF_BPR: Processed 41728 (100.0%) in 1.31 sec. MSE loss 2.64E-01. Sample per second: 31962
# MF_BPR: Epoch 21 of 100. Elapsed time 3.18 min
# MF_BPR: Processed 41728 (100.0%) in 1.13 sec. MSE loss 2.87E-01. Sample per second: 36981
# MF_BPR: Epoch 22 of 100. Elapsed time 3.19 min
# MF_BPR: Processed 41728 (100.0%) in 0.97 sec. MSE loss 3.14E-01. Sample per second: 43144
# MF_BPR: Epoch 23 of 100. Elapsed time 3.20 min
# MF_BPR: Processed 41728 (100.0%) in 1.80 sec. MSE loss 3.35E-01. Sample per second: 23234
# MF_BPR: Epoch 24 of 100. Elapsed time 3.22 min
# MF_BPR: Processed 41728 (100.0%) in 1.62 sec. MSE loss 3.67E-01. Sample per second: 25683
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 42.19 sec. Users per second: 884
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0081282, PRECISION_RECALL_MIN_DEN: 0.0210546, RECALL: 0.0207954, MAP: 0.0034793, MAP_MIN_DEN: 0.0089251, MRR: 0.0308557, NDCG: 0.0169818, F1: 0.0116880, HIT_RATE: 0.0720837, ARHR_ALL_HITS: 0.0327466, NOVELTY: 0.0046270, AVERAGE_POPULARITY: 0.1894319, DIVERSITY_MEAN_INTER_LIST: 0.9460481, DIVERSITY_HERFINDAHL: 0.9946023, COVERAGE_ITEM: 0.6312482, COVERAGE_ITEM_HIT: 0.0094259, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0645704, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0951440, SHANNON_ENTROPY: 10.1460391, RATIO_DIVERSITY_HERFINDAHL: 0.9950642, RATIO_DIVERSITY_GINI: 0.2169740, RATIO_SHANNON_ENTROPY: 0.7696838, RATIO_AVERAGE_POPULARITY: 3.1114595, RATIO_NOVELTY: 0.4712135,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 25 of 100. Elapsed time 3.94 min
# MF_BPR: Processed 41728 (100.0%) in 1.85 sec. MSE loss 3.91E-01. Sample per second: 22567
# MF_BPR: Epoch 26 of 100. Elapsed time 3.95 min
# MF_BPR: Processed 41728 (100.0%) in 1.69 sec. MSE loss 4.28E-01. Sample per second: 24663
# MF_BPR: Epoch 27 of 100. Elapsed time 3.97 min
# MF_BPR: Processed 41728 (100.0%) in 1.51 sec. MSE loss 4.57E-01. Sample per second: 27713
# MF_BPR: Epoch 28 of 100. Elapsed time 3.98 min
# MF_BPR: Processed 41728 (100.0%) in 1.33 sec. MSE loss 4.99E-01. Sample per second: 31432
# MF_BPR: Epoch 29 of 100. Elapsed time 3.99 min
# MF_BPR: Processed 41728 (100.0%) in 1.05 sec. MSE loss 5.24E-01. Sample per second: 39834
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 42.51 sec. Users per second: 877
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0096648, PRECISION_RECALL_MIN_DEN: 0.0249225, RECALL: 0.0246159, MAP: 0.0040521, MAP_MIN_DEN: 0.0103428, MRR: 0.0353172, NDCG: 0.0198117, F1: 0.0138800, HIT_RATE: 0.0843926, ARHR_ALL_HITS: 0.0377956, NOVELTY: 0.0044119, AVERAGE_POPULARITY: 0.2224804, DIVERSITY_MEAN_INTER_LIST: 0.9242435, DIVERSITY_HERFINDAHL: 0.9924219, COVERAGE_ITEM: 0.5755906, COVERAGE_ITEM_HIT: 0.0090586, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0755963, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0701800, SHANNON_ENTROPY: 9.4785829, RATIO_DIVERSITY_HERFINDAHL: 0.9928828, RATIO_DIVERSITY_GINI: 0.1600441, RATIO_SHANNON_ENTROPY: 0.7190502, RATIO_AVERAGE_POPULARITY: 3.6542888, RATIO_NOVELTY: 0.4493082,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 30 of 100. Elapsed time 4.72 min
# MF_BPR: Processed 41728 (100.0%) in 1.56 sec. MSE loss 5.65E-01. Sample per second: 26814
# MF_BPR: Epoch 31 of 100. Elapsed time 4.73 min
# MF_BPR: Processed 41728 (100.0%) in 1.37 sec. MSE loss 6.09E-01. Sample per second: 30502
# MF_BPR: Epoch 32 of 100. Elapsed time 4.74 min
# MF_BPR: Processed 41728 (100.0%) in 1.14 sec. MSE loss 6.43E-01. Sample per second: 36698
# MF_BPR: Epoch 33 of 100. Elapsed time 4.76 min
# MF_BPR: Processed 41728 (100.0%) in 0.96 sec. MSE loss 6.96E-01. Sample per second: 43473
# MF_BPR: Epoch 34 of 100. Elapsed time 4.77 min
# MF_BPR: Processed 41728 (100.0%) in 1.80 sec. MSE loss 7.40E-01. Sample per second: 23226
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 45.70 sec. Users per second: 816
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0108206, PRECISION_RECALL_MIN_DEN: 0.0277368, RECALL: 0.0273873, MAP: 0.0044616, MAP_MIN_DEN: 0.0113073, MRR: 0.0384923, NDCG: 0.0218183, F1: 0.0155123, HIT_RATE: 0.0934299, ARHR_ALL_HITS: 0.0413908, NOVELTY: 0.0042753, AVERAGE_POPULARITY: 0.2458922, DIVERSITY_MEAN_INTER_LIST: 0.9062566, DIVERSITY_HERFINDAHL: 0.9906232, COVERAGE_ITEM: 0.5336026, COVERAGE_ITEM_HIT: 0.0086506, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0836917, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0559399, SHANNON_ENTROPY: 9.0234775, RATIO_DIVERSITY_HERFINDAHL: 0.9910833, RATIO_DIVERSITY_GINI: 0.1275698, RATIO_SHANNON_ENTROPY: 0.6845257, RATIO_AVERAGE_POPULARITY: 4.0388321, RATIO_NOVELTY: 0.4353975,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 35 of 100. Elapsed time 5.55 min
# MF_BPR: Processed 41728 (100.0%) in 1.83 sec. MSE loss 7.81E-01. Sample per second: 22793
# MF_BPR: Epoch 36 of 100. Elapsed time 5.57 min
# MF_BPR: Processed 41728 (100.0%) in 2.06 sec. MSE loss 8.25E-01. Sample per second: 20206
# MF_BPR: Epoch 37 of 100. Elapsed time 5.59 min
# MF_BPR: Processed 41728 (100.0%) in 0.87 sec. MSE loss 8.78E-01. Sample per second: 47867
# MF_BPR: Epoch 38 of 100. Elapsed time 5.60 min
# MF_BPR: Processed 41728 (100.0%) in 1.74 sec. MSE loss 9.35E-01. Sample per second: 23997
# MF_BPR: Epoch 39 of 100. Elapsed time 5.62 min
# MF_BPR: Processed 41728 (100.0%) in 1.63 sec. MSE loss 9.67E-01. Sample per second: 25640
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 45.18 sec. Users per second: 825
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0115956, PRECISION_RECALL_MIN_DEN: 0.0295023, RECALL: 0.0291173, MAP: 0.0047791, MAP_MIN_DEN: 0.0121035, MRR: 0.0409293, NDCG: 0.0232810, F1: 0.0165860, HIT_RATE: 0.0992759, ARHR_ALL_HITS: 0.0441699, NOVELTY: 0.0041879, AVERAGE_POPULARITY: 0.2623396, DIVERSITY_MEAN_INTER_LIST: 0.8922596, DIVERSITY_HERFINDAHL: 0.9892236, COVERAGE_ITEM: 0.5068756, COVERAGE_ITEM_HIT: 0.0086098, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0889284, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0476652, SHANNON_ENTROPY: 8.7220887, RATIO_DIVERSITY_HERFINDAHL: 0.9896830, RATIO_DIVERSITY_GINI: 0.1086996, RATIO_SHANNON_ENTROPY: 0.6616622, RATIO_AVERAGE_POPULARITY: 4.3089836, RATIO_NOVELTY: 0.4265014,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 40 of 100. Elapsed time 6.39 min
# MF_BPR: Processed 41728 (100.0%) in 1.93 sec. MSE loss 1.02E+00. Sample per second: 21621
# MF_BPR: Epoch 41 of 100. Elapsed time 6.40 min
# MF_BPR: Processed 41728 (100.0%) in 1.81 sec. MSE loss 1.08E+00. Sample per second: 23084
# MF_BPR: Epoch 42 of 100. Elapsed time 6.42 min
# MF_BPR: Processed 41728 (100.0%) in 1.64 sec. MSE loss 1.13E+00. Sample per second: 25447
# MF_BPR: Epoch 43 of 100. Elapsed time 6.43 min
# MF_BPR: Processed 41728 (100.0%) in 1.67 sec. MSE loss 1.19E+00. Sample per second: 24927
# MF_BPR: Epoch 44 of 100. Elapsed time 6.45 min
# MF_BPR: Processed 41728 (100.0%) in 1.59 sec. MSE loss 1.24E+00. Sample per second: 26170
# MF_BPR: Validation begins...
# EvaluatorHoldout: Processed 37290 (100.0%) in 44.23 sec. Users per second: 843
# MF_BPR: CUTOFF: 10 - PRECISION: 0.0121668, PRECISION_RECALL_MIN_DEN: 0.0309312, RECALL: 0.0305212, MAP: 0.0049773, MAP_MIN_DEN: 0.0125397, MRR: 0.0425022, NDCG: 0.0242512, F1: 0.0173981, HIT_RATE: 0.1041030, ARHR_ALL_HITS: 0.0459264, NOVELTY: 0.0041289, AVERAGE_POPULARITY: 0.2743555, DIVERSITY_MEAN_INTER_LIST: 0.8808472, DIVERSITY_HERFINDAHL: 0.9880824, COVERAGE_ITEM: 0.4858204, COVERAGE_ITEM_HIT: 0.0086506, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.0932523, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0422991, SHANNON_ENTROPY: 8.5051542, RATIO_DIVERSITY_HERFINDAHL: 0.9885413, RATIO_DIVERSITY_GINI: 0.0964622, RATIO_SHANNON_ENTROPY: 0.6452054, RATIO_AVERAGE_POPULARITY: 4.5063485, RATIO_NOVELTY: 0.4204868,
#
# MF_BPR: New best model found! Updating.
# MF_BPR: Epoch 45 of 100. Elapsed time 7.20 min
# MF_BPR: Processed 41728 (100.0%) in 1.76 sec. MSE loss 1.32E+00. Sample per second: 23709
# MF_BPR: Epoch 46 of 100. Elapsed time 7.22 min
# MF_BPR: Processed 41728 (100.0%) in 1.61 sec. MSE loss 1.36E+00. Sample per second: 25976
# MF_BPR: Epoch 47 of 100. Elapsed time 7.23 min
# ...
# EvaluatorHoldout: Processed 37290 (100.0%) in 51.34 sec. Users per second: 726
# SearchBayesianSkopt: New best config found. Config 1: {'epochs': 100, 'sgd_mode': 'adagrad', 'num_factors': 64, 'batch_size': 128, 'user_reg': 5.372533789839864e-05, 'learning_rate': 0.03449265149936343} - results: PRECISION: 0.0135184, PRECISION_RECALL_MIN_DEN: 0.0342048, RECALL: 0.0337391, MAP: 0.0055066, MAP_MIN_DEN: 0.0136907, MRR: 0.0467685, NDCG: 0.0266630, F1: 0.0193027, HIT_RATE: 0.1148565, ARHR_ALL_HITS: 0.0506631, NOVELTY: 0.0040211, AVERAGE_POPULARITY: 0.2989340, DIVERSITY_MEAN_INTER_LIST: 0.8589594, DIVERSITY_HERFINDAHL: 0.9858936, COVERAGE_ITEM: 0.4582772, COVERAGE_ITEM_HIT: 0.0079161, ITEMS_IN_GT: 0.9296936, COVERAGE_USER: 0.8957698, COVERAGE_USER_HIT: 0.1028850, USERS_IN_GT: 0.8957698, DIVERSITY_GINI: 0.0350650, SHANNON_ENTROPY: 8.1558027, RATIO_DIVERSITY_HERFINDAHL: 0.9863515, RATIO_DIVERSITY_GINI: 0.0799650, RATIO_SHANNON_ENTROPY: 0.6187034, RATIO_AVERAGE_POPULARITY: 4.9100552, RATIO_NOVELTY: 0.4095134,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1035.1981
# Function value obtained: -0.0055
# Current minimum: -0.0055
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'epochs': 100, 'sgd_mode': 'adam', 'num_factors': 89, 'batch_size': 256, 'user_reg': 1.71201448367304e-05, 'learning_rate': 0.010252900148782263}
# MatrixFactorization_BPR_Cython_Recommender: URM Detected 1 ( 0.0%) users with no interactions.
# MF_BPR: Processed 41728 (100.0%) in 3.00 sec. MSE loss 2.05E-02. Sample per second: 13887
# MF_BPR: Epoch 1 of 100. Elapsed time 2.01 sec
# MF_BPR: Processed 41728 (100.0%) in 1.70 sec. MSE loss 3.84E-02. Sample per second: 24514
# MF_BPR: Epoch 2 of 100. Elapsed time 3.71 sec
# MF_BPR: Processed 41728 (100.0%) in 2.02 sec. MSE loss 8.25E-02. Sample per second: 20639
# MF_BPR: Epoch 3 of 100. Elapsed time 5.02 sec
# MF_BPR: Processed 41728 (100.0%) in 1.58 sec. MSE loss 1.78E-01. Sample per second: 26383
# MF_BPR: Epoch 4 of 100. Elapsed time 6.58 sec
# MF_BPR: Processed 41728 (100.0%) in 2.32 sec. MSE loss 3.64E-01. Sample per second: 18018
# MF_BPR: Validation begins...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 hyperparameterSearch.search(recommender_input_args,
#       2                             recommender_input_args_last_test = recommender_input_args_last_test,
#       3                             hyperparameter_search_space = hyperparameters_range_dictionary,
#       4                             n_cases = n_cases,
#       5                             n_random_starts = n_random_starts,
#       6                             save_model = "last",
#       7                             output_folder_path = output_folder_path, # Where to save the results
#       8                             output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
#       9                             metric_to_optimize = metric_to_optimize,
#      10                             cutoff_to_optimize = cutoff_to_optimize,
#      11                             )
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\HyperparameterTuning\SearchBayesianSkopt.py:340, in SearchBayesianSkopt.search(self, recommender_input_args, hyperparameter_search_space, metric_to_optimize, cutoff_to_optimize, n_cases, n_random_starts, output_folder_path, output_file_name_root, save_model, save_metadata, resume_from_saved, recommender_input_args_last_test, evaluate_on_test, max_total_time, terminate_on_memory_error)
#     333         self.n_loaded_counter = self.model_counter
#     336     if self.n_calls - self.model_counter > 0:
#     337         # When resuming an incomplete search the gp_minimize will continue to tell you "Evaluating function at random point" instead
#     338         # of "Searching for the next optimal point". This may be due to a bug in the print rather than the underlying process
#     339         # https://github.com/scikit-optimize/scikit-optimize/issues/949
# --> 340         self.result = gp_minimize(self._objective_function_list_input,
#     341                                   self.hyperparams_values,
#     342                                   base_estimator=None,
#     343                                   n_calls=max(0, self.n_calls - self.model_counter),
#     344                                   n_initial_points= max(0, self.n_random_starts - self.model_counter),
#     345                                   initial_point_generator = "random",
#     346                                   acq_func=self.acq_func,
#     347                                   acq_optimizer=self.acq_optimizer,
#     348                                   x0=self.x0,
#     349                                   y0=self.y0,
#     350                                   random_state=self.random_state,
#     351                                   verbose=self.verbose,
#     352                                   callback=None,
#     353                                   n_points=self.n_point,
#     354                                   n_restarts_optimizer=self.n_restarts_optimizer,
#     355                                   xi=self.xi,
#     356                                   kappa=self.kappa,
#     357                                   noise=self.noise,
#     358                                   n_jobs=self.n_jobs)
#     360 except ValueError as e:
#     361     traceback.print_exc()
#
# File ~\miniconda3\lib\site-packages\skopt\optimizer\gp.py:259, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     254 if base_estimator is None:
#     255     base_estimator = cook_estimator(
#     256         "GP", space=space, random_state=rng.randint(0, np.iinfo(np.int32).max),
#     257         noise=noise)
# --> 259 return base_minimize(
#     260     func, space, base_estimator=base_estimator,
#     261     acq_func=acq_func,
#     262     xi=xi, kappa=kappa, acq_optimizer=acq_optimizer, n_calls=n_calls,
#     263     n_points=n_points, n_random_starts=n_random_starts,
#     264     n_initial_points=n_initial_points,
#     265     initial_point_generator=initial_point_generator,
#     266     n_restarts_optimizer=n_restarts_optimizer,
#     267     x0=x0, y0=y0, random_state=rng, verbose=verbose,
#     268     callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# File ~\miniconda3\lib\site-packages\skopt\optimizer\base.py:299, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     297 for n in range(n_calls):
#     298     next_x = optimizer.ask()
# --> 299     next_y = func(next_x)
#     300     result = optimizer.tell(next_x, next_y)
#     301     result.specs = specs
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\HyperparameterTuning\SearchBayesianSkopt.py:415, in SearchBayesianSkopt._objective_function_list_input(self, current_fit_hyperparameters_list_of_values)
#     411         raise TimeoutError(self.max_total_time, total_current_time + estimated_last_time)
#     414 current_fit_hyperparameters_dict = dict(zip(self.hyperparams_names, current_fit_hyperparameters_list_of_values))
# --> 415 result = self._objective_function(current_fit_hyperparameters_dict)
#     417 # The search can only progress if there is at least a valid config in the initial random start
#     418 if self.metadata_dict['result_on_validation_df'] is None and self.model_counter >= self.n_random_starts:
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\HyperparameterTuning\SearchAbstractClass.py:539, in SearchAbstractClass._objective_function(self, current_fit_hyperparameters_dict)
#     534             recommender_instance.save_model(self.output_folder_path, file_name =self.output_file_name_root + "_best_model")
#     537 except (KeyboardInterrupt, SystemExit) as e:
#     538     # If getting a interrupt, terminate without saving the exception
# --> 539     raise e
#     541 # Catch exception only if terminate_on_memory_error is True
#     542 except MEMORY_ERROR_EXCEPTION_TUPLE if self.terminate_on_memory_error else (NeverMatch) as e:
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\HyperparameterTuning\SearchAbstractClass.py:468, in SearchAbstractClass._objective_function(self, current_fit_hyperparameters_dict)
#     465 self._print("{}: Testing config: {}".format(self.ALGORITHM_NAME, current_fit_hyperparameters_dict))
#     467 was_already_evaluated_flag, was_already_evaluated_index = self._was_already_evaluated_check(current_fit_hyperparameters_dict)
# --> 468 result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#     470 result_series = result_df.loc[self.metadata_dict["cutoff_to_optimize"]]
#     471 current_result = - result_series[self.metric_to_optimize]
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\HyperparameterTuning\SearchAbstractClass.py:326, in SearchAbstractClass._evaluate_on_validation(self, current_fit_hyperparameters, was_already_evaluated_flag, was_already_evaluated_index)
#     323 for key in current_fit_hyperparameters.keys():
#     324     self.metadata_dict["hyperparameters_df"].loc[self.model_counter,key] = current_fit_hyperparameters[key]
# --> 326 recommender_instance, train_time = self._fit_model(current_fit_hyperparameters)
#     327 start_time = time.time()
#     329 # Evaluate recommender and get results for the first cutoff
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\HyperparameterTuning\SearchAbstractClass.py:297, in SearchAbstractClass._fit_model(self, current_fit_hyperparameters)
#     293 # Construct a new recommender instance
#     294 recommender_instance = self.recommender_class(*self.recommender_input_args.CONSTRUCTOR_POSITIONAL_ARGS,
#     295                                               **self.recommender_input_args.CONSTRUCTOR_KEYWORD_ARGS)
# --> 297 recommender_instance.fit(*self.recommender_input_args.FIT_POSITIONAL_ARGS,
#     298                          **self.recommender_input_args.FIT_KEYWORD_ARGS,
#     299                          **self.recommender_input_args.EARLYSTOPPING_KEYWORD_ARGS,
#     300                          **current_fit_hyperparameters)
#     302 train_time = time.time() - start_time
#     304 return recommender_instance, train_time
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\MatrixFactorization\Cython\MatrixFactorization_Cython.py:167, in MatrixFactorization_BPR_Cython.fit(self, **key_args)
#     164 key_args["use_bias"] = False
#     165 key_args["negative_interactions_quota"] = 0.0
# --> 167 super(MatrixFactorization_BPR_Cython, self).fit(**key_args)
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\MatrixFactorization\Cython\MatrixFactorization_Cython.py:109, in _MatrixFactorization_Cython.fit(self, epochs, batch_size, num_factors, positive_threshold_BPR, learning_rate, use_bias, use_embeddings, sgd_mode, negative_interactions_quota, dropout_quota, init_mean, init_std_dev, user_reg, item_reg, bias_reg, positive_reg, negative_reg, random_seed, **earlystopping_kwargs)
#     106 self._prepare_model_for_validation()
#     107 self._update_best_model()
# --> 109 self._train_with_early_stopping(epochs,
#     110                                 algorithm_name = self.algorithm_name,
#     111                                 **earlystopping_kwargs)
#     114 self.USER_factors = self.USER_factors_best
#     115 self.ITEM_factors = self.ITEM_factors_best
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\Incremental_Training_Early_Stopping.py:215, in Incremental_Training_Early_Stopping._train_with_early_stopping(self, epochs_max, epochs_min, validation_every_n, stop_on_validation, validation_metric, lower_validations_allowed, evaluator_object, algorithm_name)
#     213 # If the evaluator validation has multiple cutoffs, choose the first one
#     214 start_time_validation = time.time()
# --> 215 results_run, results_run_string = evaluator_object.evaluateRecommender(self)
#     216 results_run["earlystopping_evaluation_time"] = time.time()-start_time_validation
#     217 self._update_validation_summary_table(epochs_current, results_run)
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\Evaluation\Evaluator.py:276, in Evaluator.evaluateRecommender(self, recommender_object)
#     273 self._start_time_print = time.time()
#     274 self._n_users_evaluated = 0
# --> 276 results_dict = self._run_evaluation_on_selected_users(recommender_object, self.users_to_evaluate)
#     279 if self._n_users_evaluated > 0:
#     281     for cutoff in self.cutoff_list:
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\Evaluation\Evaluator.py:476, in EvaluatorHoldout._run_evaluation_on_selected_users(self, recommender_object, users_to_evaluate, block_size)
#     473     user_batch_start = user_batch_end
#     475     # Compute predictions for a batch of users using vectorization, much more efficient than computing it one at a time
# --> 476     recommended_items_batch_list, scores_batch = recommender_object.recommend(test_user_batch_array,
#     477                                                                               remove_seen_flag=self.exclude_seen,
#     478                                                                               cutoff = self.max_cutoff,
#     479                                                                               remove_top_pop_flag=False,
#     480                                                                               remove_custom_items_flag=self.ignore_items_flag,
#     481                                                                               return_scores = True
#     482                                                                               )
#     484     results_dict = self._compute_metrics_on_recommendation_list(test_user_batch_array = test_user_batch_array,
#     485                                                                 recommended_items_batch_list = recommended_items_batch_list,
#     486                                                                 scores_batch = scores_batch,
#     487                                                                 results_dict = results_dict)
#     490 return results_dict
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\BaseRecommender.py:147, in BaseRecommender.recommend(self, user_id_array, cutoff, remove_seen_flag, items_to_compute, remove_top_pop_flag, remove_custom_items_flag, return_scores)
#     143 cutoff = min(cutoff, self.URM_train.shape[1] - 1)
#     145 # Compute the scores using the model-specific function
#     146 # Vectorize over all users in user_id_array
# --> 147 scores_batch = self._compute_item_score(user_id_array, items_to_compute=items_to_compute)
#     150 for user_index in range(len(user_id_array)):
#     152     user_id = user_id_array[user_index]
#
# File ~\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\BaseMatrixFactorizationRecommender.py:62, in BaseMatrixFactorizationRecommender._compute_item_score(self, user_id_array, items_to_compute)
#      59     item_scores[:, items_to_compute] = np.dot(self.USER_factors[user_id_array], self.ITEM_factors[items_to_compute,:].T)
#      61 else:
# ---> 62     item_scores = np.dot(self.USER_factors[user_id_array], self.ITEM_factors.T)
#      65 # No need to select only the specific negative items or warm users because the -inf score will not change
#      66 if self.use_bias:
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# Now we will fit the model with the hyperparameters obtained from the previous bayesian search and evaluate them on the validation set

# %% [markdown]
# ## Recommender Testing

# %%
recommender = MatrixFactorization_BPR_Cython(URM_all)
recommender.fit(epochs=,
                sgd_mode='',
                num_factors=,
                batch_size=,
                user_reg=,
                learning_rate=)

# %% [markdown]
# ## Submissions

# %%
test_users = pd.read_csv('../Dataset/data_target_users_test.csv')

# %%
user_id = test_users['user_id']
recommendations = []
for user in user_id:
    recommendations.append(recommender.recommend(user, cutoff=10))

# %%
for index in range(len(recommendations)):
    recommendations[index]=np.array(recommendations[index])

test_users['item_list']= recommendations
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])
test_users.to_csv('..\Submissions\Submission_04_10933934_MF_BPR.csv', index=False)
