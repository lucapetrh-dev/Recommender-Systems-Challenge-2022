# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
# %matplotlib inline

# %%
from Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Utils.DataReader import load_urm, load_icm, load_target

# %%
URM_all = load_urm()

URM_train, URM_test = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.85)
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_train, train_percentage = 0.85)

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=[10])
# Out:
# Warning: 3151 (7.57 %) of 41629 users have no sampled items
# Warning: 2 (0.00 %) of 41629 users have no train items
# Warning: 4356 (10.46 %) of 41629 users have no sampled items
# EvaluatorHoldout: Ignoring 4356 (10.5%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 3151 ( 7.6%) Users that have less than 1 test interactions

# %% [markdown]
# ## Slim BPR

# %%
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython

#try a SLIM BPR model
recommender_class = SLIM_BPR_Cython

# %%
import os

output_folder_path = "Experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 10
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10

# %%
from skopt.space import Real, Integer, Categorical

hyperparameters_range_dictionary = {
    "epochs": Categorical([700]),
    "sgd_mode": Categorical(["sgd", "adagrad", "adam"]),
    "topK": Integer(5, 700),
    "lambda_i": Real(low = 1e-4, high = 1e-1, prior = 'log-uniform'),
    "lambda_j": Real(low = 1e-4, high = 1e-1, prior = 'log-uniform'),
    "learning_rate": Real(low = 1e-4, high = 1e-1, prior = 'log-uniform')
}

# %%
earlystopping_keywargs = {"validation_every_n": 15,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

#create a bayesian optimizer object, we pass the recommender and the evaluator
hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                           evaluator_validation=evaluator_validation)

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_all],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)

# %%
# !python run_compile_all_cython.py
# Out:
# run_compile_all_cython: Found 10 Cython files in 4 folders...
# run_compile_all_cython: All files will be compiled using your current python environment: 'C:\Users\Luca\miniconda3\python.exe'
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx...
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx... PASS
#
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx...
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx... PASS
#
# Compiling [3/10]: Compute_Similarity_Cython.pyx...
# Compiling [3/10]: Compute_Similarity_Cython.pyx... PASS
#
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx...
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx... FAIL: Command 'C:\Users\Luca\miniconda3\python.exe C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022/CythonCompiler/compile_script.py SLIM_BPR_Cython_Epoch.pyx build_ext --inplace' returned non-zero exit status 1.
#
# Compiling [5/10]: Sparse_Matrix_Tree_CSR.pyx...
# Compiling [5/10]: Sparse_Matrix_Tree_CSR.pyx... PASS
#
# Compiling [6/10]: Triangular_Matrix.pyx...
# Compiling [6/10]: Triangular_Matrix.pyx... PASS
#
# Compiling [7/10]: CFW_DVV_Similarity_Cython_SGD.pyx...
# Compiling [7/10]: CFW_DVV_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [8/10]: CFW_D_Similarity_Cython_SGD.pyx...
# Compiling [8/10]: CFW_D_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [9/10]: FBSM_Rating_Cython_SGD.pyx...
# Compiling [9/10]: FBSM_Rating_Cython_SGD.pyx... PASS
#
# Compiling [10/10]: HP3_Similarity_Cython_SGD.pyx...
# Compiling [10/10]: HP3_Similarity_Cython_SGD.pyx... PASS
#
# run_compile_all_cython: Compilation finished. FAILS 1/10.
# Compilation log can be found here: './result_experiments/run_compile_all_cython.txt'
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\MatrixFactorization\Cython\MatrixFactorizationImpressions_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\MatrixFactorization\Cython\MatrixFactorization_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\Similarity\Cython\Compute_Similarity_Cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# error: command 'C:\\Program Files\\Microsoft Visual Studio\\2022\\Community\\VC\\Tools\\MSVC\\14.32.31326\\bin\\HostX86\\x64\\link.exe' failed with exit code 1104
# Traceback (most recent call last):
#   File "C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\run_compile_all_cython.py", line 59, in <module>
#     run_compile_subprocess(file_path, [file_name])
#   File "C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\CythonCompiler\run_compile_subprocess.py", line 51, in run_compile_subprocess
#     raise exc
#   File "C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\CythonCompiler\run_compile_subprocess.py", line 32, in run_compile_subprocess
#     output = subprocess.check_output(' '.join(command),
#   File "C:\Users\Luca\miniconda3\lib\subprocess.py", line 424, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#   File "C:\Users\Luca\miniconda3\lib\subprocess.py", line 528, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command 'C:\Users\Luca\miniconda3\python.exe C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022/CythonCompiler/compile_script.py SLIM_BPR_Cython_Epoch.pyx build_ext --inplace' returned non-zero exit status 1.
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\SLIM\Cython\Sparse_Matrix_Tree_CSR.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\SLIM\Cython\Triangular_Matrix.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\FeatureWeighting\Cython\CFW_DVV_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\FeatureWeighting\Cython\CFW_D_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\FeatureWeighting\Cython\FBSM_Rating_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\Luca\miniconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Luca\DataspellProjects\Recommender-Systems-Challenge-2022\Recommenders\FeatureWeighting\Cython\HP3_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access

# %%
#let's run the bayesian search
hyperparameterSearch.search(recommender_input_args,
                            recommender_input_args_last_test = recommender_input_args_last_test,
                            hyperparameter_search_space = hyperparameters_range_dictionary,
                            n_cases = n_cases,
                            n_random_starts = n_random_starts,
                            save_model = "last",
                            output_folder_path = output_folder_path, # Where to save the results
                            output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                            metric_to_optimize = metric_to_optimize,
                            cutoff_to_optimize = cutoff_to_optimize,
                            )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'epochs': 700, 'sgd_mode': 'adam', 'topK': 162, 'lambda_i': 0.02893179462978207, 'lambda_j': 0.024830665584446056, 'learning_rate': 0.00022273197535303317}
# SLIM_BPR_Recommender: URM Detected 2 ( 0.0%) users with no interactions.
# Unable to read memory status: list index out of range
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Unable to get current RAM status, you may be using a non-Linux operating system. Using dense matrix.
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 9.60E-04. Sample per second: 102933
# SLIM_BPR_Recommender: Epoch 1 of 700. Elapsed time 0.12 sec
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 4.36E-03. Sample per second: 76692
# SLIM_BPR_Recommender: Epoch 2 of 700. Elapsed time 0.26 sec
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 8.61E-03. Sample per second: 61067
# SLIM_BPR_Recommender: Epoch 3 of 700. Elapsed time 0.40 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 1.32E-02. Sample per second: 50732
# SLIM_BPR_Recommender: Epoch 4 of 700. Elapsed time 0.54 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 1.84E-02. Sample per second: 43546
# SLIM_BPR_Recommender: Epoch 5 of 700. Elapsed time 0.68 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 2.49E-02. Sample per second: 38439
# SLIM_BPR_Recommender: Epoch 6 of 700. Elapsed time 0.80 sec
# Processed 41629 (100.0%) in 0.21 sec. BPR loss is 2.92E-02. Sample per second: 199715
# SLIM_BPR_Recommender: Epoch 7 of 700. Elapsed time 0.93 sec
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 3.63E-02. Sample per second: 121230
# SLIM_BPR_Recommender: Epoch 8 of 700. Elapsed time 1.06 sec
# Processed 41629 (100.0%) in 0.48 sec. BPR loss is 4.05E-02. Sample per second: 86060
# SLIM_BPR_Recommender: Epoch 9 of 700. Elapsed time 1.20 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 4.81E-02. Sample per second: 67023
# SLIM_BPR_Recommender: Epoch 10 of 700. Elapsed time 1.34 sec
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 5.77E-02. Sample per second: 55063
# SLIM_BPR_Recommender: Epoch 11 of 700. Elapsed time 1.48 sec
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 6.11E-02. Sample per second: 46987
# SLIM_BPR_Recommender: Epoch 12 of 700. Elapsed time 1.60 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 6.78E-02. Sample per second: 40619
# SLIM_BPR_Recommender: Epoch 13 of 700. Elapsed time 1.74 sec
# Processed 41629 (100.0%) in 0.16 sec. BPR loss is 7.17E-02. Sample per second: 253476
# SLIM_BPR_Recommender: Epoch 14 of 700. Elapsed time 1.88 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 8.06E-02. Sample per second: 143178
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 29.93 sec. Users per second: 1245
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0297910, PRECISION_RECALL_MIN_DEN: 0.0768718, RECALL: 0.0759085, MAP: 0.0131069, MAP_MIN_DEN: 0.0338280, MRR: 0.1038877, NDCG: 0.0617448, F1: 0.0427890, HIT_RATE: 0.2341910, ARHR_ALL_HITS: 0.1163791, NOVELTY: 0.0038503, AVERAGE_POPULARITY: 0.3417512, DIVERSITY_MEAN_INTER_LIST: 0.7814087, DIVERSITY_HERFINDAHL: 0.9781388, COVERAGE_ITEM: 0.4566858, COVERAGE_ITEM_HIT: 0.0195454, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2096856, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0252806, SHANNON_ENTROPY: 7.3572561, RATIO_DIVERSITY_HERFINDAHL: 0.9785958, RATIO_DIVERSITY_GINI: 0.0576941, RATIO_SHANNON_ENTROPY: 0.5581738, RATIO_AVERAGE_POPULARITY: 5.6964300, RATIO_NOVELTY: 0.3921518,
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 15 of 700. Elapsed time 43.73 sec
# Processed 41629 (100.0%) in 0.15 sec. BPR loss is 8.42E-02. Sample per second: 284865
# SLIM_BPR_Recommender: Epoch 16 of 700. Elapsed time 43.87 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 1.03E-01. Sample per second: 143070
# SLIM_BPR_Recommender: Epoch 17 of 700. Elapsed time 44.01 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 1.08E-01. Sample per second: 97295
# SLIM_BPR_Recommender: Epoch 18 of 700. Elapsed time 44.15 sec
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 1.10E-01. Sample per second: 72065
# SLIM_BPR_Recommender: Epoch 19 of 700. Elapsed time 44.30 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 1.23E-01. Sample per second: 57579
# SLIM_BPR_Recommender: Epoch 20 of 700. Elapsed time 44.44 sec
# Processed 41629 (100.0%) in 0.85 sec. BPR loss is 1.24E-01. Sample per second: 48864
# SLIM_BPR_Recommender: Epoch 21 of 700. Elapsed time 44.57 sec
# Processed 41629 (100.0%) in 1.00 sec. BPR loss is 1.33E-01. Sample per second: 41784
# SLIM_BPR_Recommender: Epoch 22 of 700. Elapsed time 44.72 sec
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 1.49E-01. Sample per second: 36735
# SLIM_BPR_Recommender: Epoch 23 of 700. Elapsed time 44.85 sec
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 1.47E-01. Sample per second: 158787
# SLIM_BPR_Recommender: Epoch 24 of 700. Elapsed time 44.98 sec
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 1.60E-01. Sample per second: 106975
# SLIM_BPR_Recommender: Epoch 25 of 700. Elapsed time 45.11 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 1.72E-01. Sample per second: 79291
# SLIM_BPR_Recommender: Epoch 26 of 700. Elapsed time 45.24 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 1.85E-01. Sample per second: 62332
# SLIM_BPR_Recommender: Epoch 27 of 700. Elapsed time 45.39 sec
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 1.87E-01. Sample per second: 52049
# SLIM_BPR_Recommender: Epoch 28 of 700. Elapsed time 45.52 sec
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 1.91E-01. Sample per second: 44584
# SLIM_BPR_Recommender: Epoch 29 of 700. Elapsed time 45.65 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 2.14E-01. Sample per second: 38633
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 29.45 sec. Users per second: 1266
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0296408, PRECISION_RECALL_MIN_DEN: 0.0767325, RECALL: 0.0757753, MAP: 0.0130366, MAP_MIN_DEN: 0.0337223, MRR: 0.1035598, NDCG: 0.0615535, F1: 0.0426128, HIT_RATE: 0.2334398, ARHR_ALL_HITS: 0.1158878, NOVELTY: 0.0038440, AVERAGE_POPULARITY: 0.3471169, DIVERSITY_MEAN_INTER_LIST: 0.7717555, DIVERSITY_HERFINDAHL: 0.9771735, COVERAGE_ITEM: 0.4686008, COVERAGE_ITEM_HIT: 0.0197903, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2090129, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0262072, SHANNON_ENTROPY: 7.3123780, RATIO_DIVERSITY_HERFINDAHL: 0.9776300, RATIO_DIVERSITY_GINI: 0.0598089, RATIO_SHANNON_ENTROPY: 0.5547690, RATIO_AVERAGE_POPULARITY: 5.7858677, RATIO_NOVELTY: 0.3915042,
#
# SLIM_BPR_Recommender: Epoch 30 of 700. Elapsed time 1.44 min
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 2.16E-01. Sample per second: 41920
# SLIM_BPR_Recommender: Epoch 31 of 700. Elapsed time 1.45 min
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 2.28E-01. Sample per second: 36552
# SLIM_BPR_Recommender: Epoch 32 of 700. Elapsed time 1.45 min
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 2.24E-01. Sample per second: 152595
# SLIM_BPR_Recommender: Epoch 33 of 700. Elapsed time 1.45 min
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 2.51E-01. Sample per second: 103351
# SLIM_BPR_Recommender: Epoch 34 of 700. Elapsed time 1.45 min
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 2.64E-01. Sample per second: 76507
# SLIM_BPR_Recommender: Epoch 35 of 700. Elapsed time 1.45 min
# Processed 41629 (100.0%) in 0.69 sec. BPR loss is 2.65E-01. Sample per second: 60683
# SLIM_BPR_Recommender: Epoch 36 of 700. Elapsed time 1.46 min
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 2.83E-01. Sample per second: 50590
# SLIM_BPR_Recommender: Epoch 37 of 700. Elapsed time 1.46 min
# Processed 41629 (100.0%) in 0.95 sec. BPR loss is 2.79E-01. Sample per second: 43597
# SLIM_BPR_Recommender: Epoch 38 of 700. Elapsed time 1.46 min
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 3.02E-01. Sample per second: 38376
# SLIM_BPR_Recommender: Epoch 39 of 700. Elapsed time 1.46 min
# Processed 41629 (100.0%) in 0.22 sec. BPR loss is 3.04E-01. Sample per second: 189059
# SLIM_BPR_Recommender: Epoch 40 of 700. Elapsed time 1.47 min
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 3.37E-01. Sample per second: 118550
# SLIM_BPR_Recommender: Epoch 41 of 700. Elapsed time 1.47 min
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 3.25E-01. Sample per second: 82617
# SLIM_BPR_Recommender: Epoch 42 of 700. Elapsed time 1.47 min
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 3.47E-01. Sample per second: 64517
# SLIM_BPR_Recommender: Epoch 43 of 700. Elapsed time 1.47 min
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 3.64E-01. Sample per second: 52525
# SLIM_BPR_Recommender: Epoch 44 of 700. Elapsed time 1.48 min
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 3.65E-01. Sample per second: 44694
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 29.16 sec. Users per second: 1278
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0293430, PRECISION_RECALL_MIN_DEN: 0.0762223, RECALL: 0.0752738, MAP: 0.0128698, MAP_MIN_DEN: 0.0333961, MRR: 0.1025542, NDCG: 0.0610047, F1: 0.0422257, HIT_RATE: 0.2319105, ARHR_ALL_HITS: 0.1145810, NOVELTY: 0.0038364, AVERAGE_POPULARITY: 0.3512019, DIVERSITY_MEAN_INTER_LIST: 0.7641429, DIVERSITY_HERFINDAHL: 0.9764122, COVERAGE_ITEM: 0.4719876, COVERAGE_ITEM_HIT: 0.0197495, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2076437, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0263336, SHANNON_ENTROPY: 7.2695099, RATIO_DIVERSITY_HERFINDAHL: 0.9768684, RATIO_DIVERSITY_GINI: 0.0600973, RATIO_SHANNON_ENTROPY: 0.5515167, RATIO_AVERAGE_POPULARITY: 5.8539572, RATIO_NOVELTY: 0.3907336,
#
# SLIM_BPR_Recommender: Epoch 45 of 700. Elapsed time 2.16 min
# Processed 41629 (100.0%) in 1.09 sec. BPR loss is 3.67E-01. Sample per second: 38313
# SLIM_BPR_Recommender: Epoch 46 of 700. Elapsed time 2.16 min
# Processed 41629 (100.0%) in 0.23 sec. BPR loss is 3.75E-01. Sample per second: 181509
# SLIM_BPR_Recommender: Epoch 47 of 700. Elapsed time 2.17 min
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 3.88E-01. Sample per second: 111253
# SLIM_BPR_Recommender: Epoch 48 of 700. Elapsed time 2.17 min
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 4.11E-01. Sample per second: 81374
# SLIM_BPR_Recommender: Epoch 49 of 700. Elapsed time 2.17 min
# Processed 41629 (100.0%) in 0.65 sec. BPR loss is 4.28E-01. Sample per second: 63851
# SLIM_BPR_Recommender: Epoch 50 of 700. Elapsed time 2.17 min
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 4.21E-01. Sample per second: 53408
# SLIM_BPR_Recommender: Epoch 51 of 700. Elapsed time 2.17 min
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 4.48E-01. Sample per second: 45530
# SLIM_BPR_Recommender: Epoch 52 of 700. Elapsed time 2.18 min
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 4.51E-01. Sample per second: 39655
# SLIM_BPR_Recommender: Epoch 53 of 700. Elapsed time 2.18 min
# Processed 41629 (100.0%) in 0.19 sec. BPR loss is 4.81E-01. Sample per second: 217846
# SLIM_BPR_Recommender: Epoch 54 of 700. Elapsed time 2.18 min
# Processed 41629 (100.0%) in 0.33 sec. BPR loss is 4.92E-01. Sample per second: 125391
# SLIM_BPR_Recommender: Epoch 55 of 700. Elapsed time 2.18 min
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 4.84E-01. Sample per second: 88044
# SLIM_BPR_Recommender: Epoch 56 of 700. Elapsed time 2.19 min
# Processed 41629 (100.0%) in 0.61 sec. BPR loss is 4.95E-01. Sample per second: 67999
# SLIM_BPR_Recommender: Epoch 57 of 700. Elapsed time 2.19 min
# Processed 41629 (100.0%) in 0.75 sec. BPR loss is 4.82E-01. Sample per second: 55499
# SLIM_BPR_Recommender: Epoch 58 of 700. Elapsed time 2.19 min
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 5.12E-01. Sample per second: 46828
# SLIM_BPR_Recommender: Epoch 59 of 700. Elapsed time 2.19 min
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 5.70E-01. Sample per second: 40345
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 29.56 sec. Users per second: 1261
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0291820, PRECISION_RECALL_MIN_DEN: 0.0757136, RECALL: 0.0747784, MAP: 0.0127731, MAP_MIN_DEN: 0.0332230, MRR: 0.1019593, NDCG: 0.0606571, F1: 0.0419810, HIT_RATE: 0.2309715, ARHR_ALL_HITS: 0.1138434, NOVELTY: 0.0038298, AVERAGE_POPULARITY: 0.3541813, DIVERSITY_MEAN_INTER_LIST: 0.7586013, DIVERSITY_HERFINDAHL: 0.9758581, COVERAGE_ITEM: 0.4725181, COVERAGE_ITEM_HIT: 0.0195046, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2068029, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0263020, SHANNON_ENTROPY: 7.2334174, RATIO_DIVERSITY_HERFINDAHL: 0.9763140, RATIO_DIVERSITY_GINI: 0.0600252, RATIO_SHANNON_ENTROPY: 0.5487785, RATIO_AVERAGE_POPULARITY: 5.9036191, RATIO_NOVELTY: 0.3900644,
#
# SLIM_BPR_Recommender: Epoch 60 of 700. Elapsed time 2.89 min
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 5.41E-01. Sample per second: 49728
# SLIM_BPR_Recommender: Epoch 61 of 700. Elapsed time 2.89 min
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 5.57E-01. Sample per second: 42479
# SLIM_BPR_Recommender: Epoch 62 of 700. Elapsed time 2.89 min
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 5.84E-01. Sample per second: 36766
# SLIM_BPR_Recommender: Epoch 63 of 700. Elapsed time 2.90 min
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 6.00E-01. Sample per second: 151847
# SLIM_BPR_Recommender: Epoch 64 of 700. Elapsed time 2.90 min
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 6.15E-01. Sample per second: 103657
# SLIM_BPR_Recommender: Epoch 65 of 700. Elapsed time 2.90 min
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 6.37E-01. Sample per second: 79574
# SLIM_BPR_Recommender: Epoch 66 of 700. Elapsed time 2.90 min
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 6.19E-01. Sample per second: 64625
# SLIM_BPR_Recommender: Epoch 67 of 700. Elapsed time 2.91 min
# Processed 41629 (100.0%) in 0.77 sec. BPR loss is 6.66E-01. Sample per second: 53986
# SLIM_BPR_Recommender: Epoch 68 of 700. Elapsed time 2.91 min
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 6.53E-01. Sample per second: 46766
# SLIM_BPR_Recommender: Epoch 69 of 700. Elapsed time 2.91 min
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 7.13E-01. Sample per second: 41209
# SLIM_BPR_Recommender: Epoch 70 of 700. Elapsed time 2.91 min
# Processed 41629 (100.0%) in 0.13 sec. BPR loss is 7.31E-01. Sample per second: 320838
# SLIM_BPR_Recommender: Epoch 71 of 700. Elapsed time 2.91 min
# Processed 41629 (100.0%) in 0.25 sec. BPR loss is 7.07E-01. Sample per second: 167347
# SLIM_BPR_Recommender: Epoch 72 of 700. Elapsed time 2.92 min
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 7.05E-01. Sample per second: 112601
# SLIM_BPR_Recommender: Epoch 73 of 700. Elapsed time 2.92 min
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 7.27E-01. Sample per second: 83859
# SLIM_BPR_Recommender: Epoch 74 of 700. Elapsed time 2.92 min
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 7.30E-01. Sample per second: 67442
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 29.91 sec. Users per second: 1246
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0290586, PRECISION_RECALL_MIN_DEN: 0.0755286, RECALL: 0.0745953, MAP: 0.0126854, MAP_MIN_DEN: 0.0330754, MRR: 0.1013080, NDCG: 0.0603961, F1: 0.0418244, HIT_RATE: 0.2301130, ARHR_ALL_HITS: 0.1130846, NOVELTY: 0.0038248, AVERAGE_POPULARITY: 0.3563617, DIVERSITY_MEAN_INTER_LIST: 0.7547388, DIVERSITY_HERFINDAHL: 0.9754719, COVERAGE_ITEM: 0.4707635, COVERAGE_ITEM_HIT: 0.0195862, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2060343, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0261279, SHANNON_ENTROPY: 7.2084105, RATIO_DIVERSITY_HERFINDAHL: 0.9759276, RATIO_DIVERSITY_GINI: 0.0596277, RATIO_SHANNON_ENTROPY: 0.5468813, RATIO_AVERAGE_POPULARITY: 5.9399622, RATIO_NOVELTY: 0.3895526,
#
# SLIM_BPR_Recommender: Epoch 75 of 700. Elapsed time 3.62 min
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 7.63E-01. Sample per second: 123246
# SLIM_BPR_Recommender: Epoch 76 of 700. Elapsed time 3.62 min
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 7.36E-01. Sample per second: 88067
# SLIM_BPR_Recommender: Epoch 77 of 700. Elapsed time 3.62 min
# Processed 41629 (100.0%) in 0.61 sec. BPR loss is 7.50E-01. Sample per second: 68676
# SLIM_BPR_Recommender: Epoch 78 of 700. Elapsed time 3.62 min
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 8.37E-01. Sample per second: 56692
# SLIM_BPR_Recommender: Epoch 79 of 700. Elapsed time 3.62 min
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 8.54E-01. Sample per second: 48360
# SLIM_BPR_Recommender: Epoch 80 of 700. Elapsed time 3.63 min
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 8.34E-01. Sample per second: 40914
# SLIM_BPR_Recommender: Epoch 81 of 700. Elapsed time 3.63 min
# Processed 41629 (100.0%) in 0.14 sec. BPR loss is 8.23E-01. Sample per second: 296154
# SLIM_BPR_Recommender: Epoch 82 of 700. Elapsed time 3.63 min
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 8.72E-01. Sample per second: 161497
# SLIM_BPR_Recommender: Epoch 83 of 700. Elapsed time 3.63 min
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 8.64E-01. Sample per second: 109611
# SLIM_BPR_Recommender: Epoch 84 of 700. Elapsed time 3.63 min
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 8.87E-01. Sample per second: 83364
# SLIM_BPR_Recommender: Epoch 85 of 700. Elapsed time 3.64 min
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 8.81E-01. Sample per second: 67425
# SLIM_BPR_Recommender: Epoch 86 of 700. Elapsed time 3.64 min
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 9.84E-01. Sample per second: 56704
# SLIM_BPR_Recommender: Epoch 87 of 700. Elapsed time 3.64 min
# Processed 41629 (100.0%) in 0.85 sec. BPR loss is 9.11E-01. Sample per second: 48820
# SLIM_BPR_Recommender: Epoch 88 of 700. Elapsed time 3.64 min
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 9.40E-01. Sample per second: 42882
# SLIM_BPR_Recommender: Epoch 89 of 700. Elapsed time 3.64 min
# Processed 41629 (100.0%) in 1.09 sec. BPR loss is 9.87E-01. Sample per second: 38236
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 33.31 sec. Users per second: 1119
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0290425, PRECISION_RECALL_MIN_DEN: 0.0755479, RECALL: 0.0746170, MAP: 0.0126498, MAP_MIN_DEN: 0.0330334, MRR: 0.1010645, NDCG: 0.0603337, F1: 0.0418112, HIT_RATE: 0.2301130, ARHR_ALL_HITS: 0.1127950, NOVELTY: 0.0038209, AVERAGE_POPULARITY: 0.3577728, DIVERSITY_MEAN_INTER_LIST: 0.7525744, DIVERSITY_HERFINDAHL: 0.9752554, COVERAGE_ITEM: 0.4725181, COVERAGE_ITEM_HIT: 0.0194638, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2060343, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0261056, SHANNON_ENTROPY: 7.1912786, RATIO_DIVERSITY_HERFINDAHL: 0.9757111, RATIO_DIVERSITY_GINI: 0.0595769, RATIO_SHANNON_ENTROPY: 0.5455815, RATIO_AVERAGE_POPULARITY: 5.9634832, RATIO_NOVELTY: 0.3891591,
#
# SLIM_BPR_Recommender: Convergence reached! Terminating at epoch 90. Best value for 'MAP' at epoch 15 is 0.0131. Elapsed time 4.41 min
# SLIM_BPR_Recommender: Epoch 90 of 700. Elapsed time 4.41 min
# Deallocating Cython objects
# EvaluatorHoldout: Processed 37273 (100.0%) in 33.36 sec. Users per second: 1117
# SearchBayesianSkopt: New best config found. Config 0: {'epochs': 15, 'sgd_mode': 'adam', 'topK': 162, 'lambda_i': 0.02893179462978207, 'lambda_j': 0.024830665584446056, 'learning_rate': 0.00022273197535303317} - results: PRECISION: 0.0290425, PRECISION_RECALL_MIN_DEN: 0.0755479, RECALL: 0.0746170, MAP: 0.0126498, MAP_MIN_DEN: 0.0330334, MRR: 0.1010645, NDCG: 0.0603337, F1: 0.0418112, HIT_RATE: 0.2301130, ARHR_ALL_HITS: 0.1127950, NOVELTY: 0.0038209, AVERAGE_POPULARITY: 0.3577728, DIVERSITY_MEAN_INTER_LIST: 0.7525744, DIVERSITY_HERFINDAHL: 0.9752554, COVERAGE_ITEM: 0.4725181, COVERAGE_ITEM_HIT: 0.0194638, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2060343, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0261056, SHANNON_ENTROPY: 7.1912786, RATIO_DIVERSITY_HERFINDAHL: 0.9757111, RATIO_DIVERSITY_GINI: 0.0595769, RATIO_SHANNON_ENTROPY: 0.5455815, RATIO_AVERAGE_POPULARITY: 5.9634832, RATIO_NOVELTY: 0.3891591,
#
# Deallocating Cython objects
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 324.0852
# Function value obtained: -0.0126
# Current minimum: -0.0126
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'epochs': 700, 'sgd_mode': 'adagrad', 'topK': 203, 'lambda_i': 0.013059269115507578, 'lambda_j': 0.05361280291442453, 'learning_rate': 0.00020991854599116224}
# SLIM_BPR_Recommender: URM Detected 2 ( 0.0%) users with no interactions.
# Unable to read memory status: list index out of range
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Unable to get current RAM status, you may be using a non-Linux operating system. Using dense matrix.
# Processed 41629 (100.0%) in 0.87 sec. BPR loss is 2.48E-06. Sample per second: 47640
# SLIM_BPR_Recommender: Epoch 1 of 700. Elapsed time 0.14 sec
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 7.55E-06. Sample per second: 40474
# SLIM_BPR_Recommender: Epoch 2 of 700. Elapsed time 0.30 sec
# Processed 41629 (100.0%) in 0.18 sec. BPR loss is 1.34E-05. Sample per second: 232131
# SLIM_BPR_Recommender: Epoch 3 of 700. Elapsed time 0.45 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 1.84E-05. Sample per second: 128814
# SLIM_BPR_Recommender: Epoch 4 of 700. Elapsed time 0.59 sec
# Processed 41629 (100.0%) in 0.48 sec. BPR loss is 2.43E-05. Sample per second: 86209
# SLIM_BPR_Recommender: Epoch 5 of 700. Elapsed time 0.75 sec
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 2.85E-05. Sample per second: 65236
# SLIM_BPR_Recommender: Epoch 6 of 700. Elapsed time 0.91 sec
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 3.47E-05. Sample per second: 52242
# SLIM_BPR_Recommender: Epoch 7 of 700. Elapsed time 1.06 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 4.05E-05. Sample per second: 43340
# SLIM_BPR_Recommender: Epoch 8 of 700. Elapsed time 1.23 sec
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 4.48E-05. Sample per second: 36932
# SLIM_BPR_Recommender: Epoch 9 of 700. Elapsed time 1.39 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 4.97E-05. Sample per second: 144849
# SLIM_BPR_Recommender: Epoch 10 of 700. Elapsed time 1.55 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 6.01E-05. Sample per second: 96084
# SLIM_BPR_Recommender: Epoch 11 of 700. Elapsed time 1.70 sec
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 6.00E-05. Sample per second: 71525
# SLIM_BPR_Recommender: Epoch 12 of 700. Elapsed time 1.85 sec
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 6.72E-05. Sample per second: 56162
# SLIM_BPR_Recommender: Epoch 13 of 700. Elapsed time 2.01 sec
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 7.35E-05. Sample per second: 46155
# SLIM_BPR_Recommender: Epoch 14 of 700. Elapsed time 2.17 sec
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 8.20E-05. Sample per second: 39768
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 34.44 sec. Users per second: 1082
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0301130, PRECISION_RECALL_MIN_DEN: 0.0773522, RECALL: 0.0763574, MAP: 0.0133751, MAP_MIN_DEN: 0.0343680, MRR: 0.1055220, NDCG: 0.0624977, F1: 0.0431922, HIT_RATE: 0.2352641, ARHR_ALL_HITS: 0.1184805, NOVELTY: 0.0038939, AVERAGE_POPULARITY: 0.3332260, DIVERSITY_MEAN_INTER_LIST: 0.7939954, DIVERSITY_HERFINDAHL: 0.9793974, COVERAGE_ITEM: 0.4938589, COVERAGE_ITEM_HIT: 0.0207696, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2106464, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0301899, SHANNON_ENTROPY: 7.5247521, RATIO_DIVERSITY_HERFINDAHL: 0.9798550, RATIO_DIVERSITY_GINI: 0.0688980, RATIO_SHANNON_ENTROPY: 0.5708812, RATIO_AVERAGE_POPULARITY: 5.5543288, RATIO_NOVELTY: 0.3965852,
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 15 of 700. Elapsed time 52.50 sec
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 8.70E-05. Sample per second: 107771
# SLIM_BPR_Recommender: Epoch 16 of 700. Elapsed time 52.65 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 9.19E-05. Sample per second: 78018
# SLIM_BPR_Recommender: Epoch 17 of 700. Elapsed time 52.80 sec
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 9.35E-05. Sample per second: 61541
# SLIM_BPR_Recommender: Epoch 18 of 700. Elapsed time 52.94 sec
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 1.02E-04. Sample per second: 51814
# SLIM_BPR_Recommender: Epoch 19 of 700. Elapsed time 53.07 sec
# Processed 41629 (100.0%) in 0.94 sec. BPR loss is 1.13E-04. Sample per second: 44366
# SLIM_BPR_Recommender: Epoch 20 of 700. Elapsed time 53.21 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 1.13E-04. Sample per second: 38451
# SLIM_BPR_Recommender: Epoch 21 of 700. Elapsed time 53.35 sec
# Processed 41629 (100.0%) in 0.21 sec. BPR loss is 1.21E-04. Sample per second: 194411
# SLIM_BPR_Recommender: Epoch 22 of 700. Elapsed time 53.48 sec
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 1.28E-04. Sample per second: 116789
# SLIM_BPR_Recommender: Epoch 23 of 700. Elapsed time 53.62 sec
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 1.31E-04. Sample per second: 82227
# SLIM_BPR_Recommender: Epoch 24 of 700. Elapsed time 53.77 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 1.37E-04. Sample per second: 62604
# SLIM_BPR_Recommender: Epoch 25 of 700. Elapsed time 53.93 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 1.41E-04. Sample per second: 50970
# SLIM_BPR_Recommender: Epoch 26 of 700. Elapsed time 54.08 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 1.45E-04. Sample per second: 42785
# SLIM_BPR_Recommender: Epoch 27 of 700. Elapsed time 54.24 sec
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 1.52E-04. Sample per second: 37291
# SLIM_BPR_Recommender: Epoch 28 of 700. Elapsed time 54.38 sec
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 1.56E-04. Sample per second: 150815
# SLIM_BPR_Recommender: Epoch 29 of 700. Elapsed time 54.54 sec
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 1.68E-04. Sample per second: 98682
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 35.59 sec. Users per second: 1047
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0302444, PRECISION_RECALL_MIN_DEN: 0.0778975, RECALL: 0.0769108, MAP: 0.0134643, MAP_MIN_DEN: 0.0346195, MRR: 0.1061178, NDCG: 0.0629008, F1: 0.0434159, HIT_RATE: 0.2363105, ARHR_ALL_HITS: 0.1192074, NOVELTY: 0.0038878, AVERAGE_POPULARITY: 0.3340169, DIVERSITY_MEAN_INTER_LIST: 0.7932277, DIVERSITY_HERFINDAHL: 0.9793206, COVERAGE_ITEM: 0.4926348, COVERAGE_ITEM_HIT: 0.0208920, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2115833, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0295304, SHANNON_ENTROPY: 7.4981426, RATIO_DIVERSITY_HERFINDAHL: 0.9797782, RATIO_DIVERSITY_GINI: 0.0673927, RATIO_SHANNON_ENTROPY: 0.5688624, RATIO_AVERAGE_POPULARITY: 5.5675110, RATIO_NOVELTY: 0.3959727,
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 30 of 700. Elapsed time 1.79 min
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 1.73E-04. Sample per second: 40355
# SLIM_BPR_Recommender: Epoch 31 of 700. Elapsed time 1.79 min
# Processed 41629 (100.0%) in 0.16 sec. BPR loss is 1.78E-04. Sample per second: 260984
# SLIM_BPR_Recommender: Epoch 32 of 700. Elapsed time 1.79 min
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 1.88E-04. Sample per second: 142826
# SLIM_BPR_Recommender: Epoch 33 of 700. Elapsed time 1.79 min
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 1.89E-04. Sample per second: 95965
# SLIM_BPR_Recommender: Epoch 34 of 700. Elapsed time 1.80 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 1.89E-04. Sample per second: 72247
# SLIM_BPR_Recommender: Epoch 35 of 700. Elapsed time 1.80 min
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 1.98E-04. Sample per second: 59122
# SLIM_BPR_Recommender: Epoch 36 of 700. Elapsed time 1.80 min
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 2.11E-04. Sample per second: 49969
# SLIM_BPR_Recommender: Epoch 37 of 700. Elapsed time 1.80 min
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 2.17E-04. Sample per second: 42462
# SLIM_BPR_Recommender: Epoch 38 of 700. Elapsed time 1.80 min
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 2.09E-04. Sample per second: 37192
# SLIM_BPR_Recommender: Epoch 39 of 700. Elapsed time 1.81 min
# Processed 41629 (100.0%) in 0.25 sec. BPR loss is 2.14E-04. Sample per second: 165067
# SLIM_BPR_Recommender: Epoch 40 of 700. Elapsed time 1.81 min
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 2.33E-04. Sample per second: 104461
# SLIM_BPR_Recommender: Epoch 41 of 700. Elapsed time 1.81 min
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 2.34E-04. Sample per second: 76616
# SLIM_BPR_Recommender: Epoch 42 of 700. Elapsed time 1.81 min
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 2.30E-04. Sample per second: 62380
# SLIM_BPR_Recommender: Epoch 43 of 700. Elapsed time 1.82 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 2.39E-04. Sample per second: 51379
# SLIM_BPR_Recommender: Epoch 44 of 700. Elapsed time 1.82 min
# Processed 41629 (100.0%) in 0.94 sec. BPR loss is 2.54E-04. Sample per second: 44208
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 35.11 sec. Users per second: 1061
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0304188, PRECISION_RECALL_MIN_DEN: 0.0783838, RECALL: 0.0773955, MAP: 0.0135326, MAP_MIN_DEN: 0.0348170, MRR: 0.1065421, NDCG: 0.0632463, F1: 0.0436728, HIT_RATE: 0.2371690, ARHR_ALL_HITS: 0.1197556, NOVELTY: 0.0038849, AVERAGE_POPULARITY: 0.3344496, DIVERSITY_MEAN_INTER_LIST: 0.7930608, DIVERSITY_HERFINDAHL: 0.9793039, COVERAGE_ITEM: 0.4914514, COVERAGE_ITEM_HIT: 0.0207696, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2123520, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0291591, SHANNON_ENTROPY: 7.4864303, RATIO_DIVERSITY_HERFINDAHL: 0.9797615, RATIO_DIVERSITY_GINI: 0.0665454, RATIO_SHANNON_ENTROPY: 0.5679738, RATIO_AVERAGE_POPULARITY: 5.5747235, RATIO_NOVELTY: 0.3956757,
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 45 of 700. Elapsed time 2.68 min
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 2.47E-04. Sample per second: 46200
# SLIM_BPR_Recommender: Epoch 46 of 700. Elapsed time 2.69 min
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 2.74E-04. Sample per second: 39206
# SLIM_BPR_Recommender: Epoch 47 of 700. Elapsed time 2.69 min
# Processed 41629 (100.0%) in 0.21 sec. BPR loss is 2.66E-04. Sample per second: 197697
# SLIM_BPR_Recommender: Epoch 48 of 700. Elapsed time 2.69 min
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 2.69E-04. Sample per second: 114574
# SLIM_BPR_Recommender: Epoch 49 of 700. Elapsed time 2.69 min
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 2.82E-04. Sample per second: 79139
# SLIM_BPR_Recommender: Epoch 50 of 700. Elapsed time 2.70 min
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 2.95E-04. Sample per second: 58384
# SLIM_BPR_Recommender: Epoch 51 of 700. Elapsed time 2.70 min
# Processed 41629 (100.0%) in 0.87 sec. BPR loss is 2.87E-04. Sample per second: 48000
# SLIM_BPR_Recommender: Epoch 52 of 700. Elapsed time 2.70 min
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 2.92E-04. Sample per second: 40224
# SLIM_BPR_Recommender: Epoch 53 of 700. Elapsed time 2.71 min
# Processed 41629 (100.0%) in 0.19 sec. BPR loss is 3.09E-04. Sample per second: 216047
# SLIM_BPR_Recommender: Epoch 54 of 700. Elapsed time 2.71 min
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 2.94E-04. Sample per second: 120518
# SLIM_BPR_Recommender: Epoch 55 of 700. Elapsed time 2.71 min
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 3.17E-04. Sample per second: 82332
# SLIM_BPR_Recommender: Epoch 56 of 700. Elapsed time 2.71 min
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 3.23E-04. Sample per second: 62565
# SLIM_BPR_Recommender: Epoch 57 of 700. Elapsed time 2.72 min
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 3.28E-04. Sample per second: 51008
# SLIM_BPR_Recommender: Epoch 58 of 700. Elapsed time 2.72 min
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 3.38E-04. Sample per second: 42988
# SLIM_BPR_Recommender: Epoch 59 of 700. Elapsed time 2.72 min
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 3.12E-04. Sample per second: 36982
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 35.40 sec. Users per second: 1053
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0304725, PRECISION_RECALL_MIN_DEN: 0.0785126, RECALL: 0.0775185, MAP: 0.0135343, MAP_MIN_DEN: 0.0348065, MRR: 0.1065284, NDCG: 0.0632870, F1: 0.0437477, HIT_RATE: 0.2379470, ARHR_ALL_HITS: 0.1197534, NOVELTY: 0.0038837, AVERAGE_POPULARITY: 0.3343283, DIVERSITY_MEAN_INTER_LIST: 0.7931252, DIVERSITY_HERFINDAHL: 0.9793104, COVERAGE_ITEM: 0.4887175, COVERAGE_ITEM_HIT: 0.0211368, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2130486, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0288539, SHANNON_ENTROPY: 7.4801901, RATIO_DIVERSITY_HERFINDAHL: 0.9797679, RATIO_DIVERSITY_GINI: 0.0658489, RATIO_SHANNON_ENTROPY: 0.5675004, RATIO_AVERAGE_POPULARITY: 5.5727025, RATIO_NOVELTY: 0.3955545,
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 60 of 700. Elapsed time 3.59 min
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 3.55E-04. Sample per second: 39448
# SLIM_BPR_Recommender: Epoch 61 of 700. Elapsed time 3.59 min
# Processed 41629 (100.0%) in 0.20 sec. BPR loss is 3.41E-04. Sample per second: 209048
# SLIM_BPR_Recommender: Epoch 62 of 700. Elapsed time 3.59 min
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 3.55E-04. Sample per second: 111241
# SLIM_BPR_Recommender: Epoch 63 of 700. Elapsed time 3.59 min
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 3.57E-04. Sample per second: 79820
# SLIM_BPR_Recommender: Epoch 64 of 700. Elapsed time 3.60 min
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 3.61E-04. Sample per second: 61282
# SLIM_BPR_Recommender: Epoch 65 of 700. Elapsed time 3.60 min
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 3.70E-04. Sample per second: 49619
# SLIM_BPR_Recommender: Epoch 66 of 700. Elapsed time 3.60 min
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 3.68E-04. Sample per second: 41871
# SLIM_BPR_Recommender: Epoch 67 of 700. Elapsed time 3.60 min
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 3.66E-04. Sample per second: 36611
# SLIM_BPR_Recommender: Epoch 68 of 700. Elapsed time 3.61 min
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 3.85E-04. Sample per second: 141927
# SLIM_BPR_Recommender: Epoch 69 of 700. Elapsed time 3.61 min
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 3.94E-04. Sample per second: 93523
# SLIM_BPR_Recommender: Epoch 70 of 700. Elapsed time 3.61 min
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 4.00E-04. Sample per second: 69171
# SLIM_BPR_Recommender: Epoch 71 of 700. Elapsed time 3.61 min
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 3.94E-04. Sample per second: 54452
# SLIM_BPR_Recommender: Epoch 72 of 700. Elapsed time 3.62 min
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 4.10E-04. Sample per second: 45531
# SLIM_BPR_Recommender: Epoch 73 of 700. Elapsed time 3.62 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 4.10E-04. Sample per second: 38814
# SLIM_BPR_Recommender: Epoch 74 of 700. Elapsed time 3.62 min
# Processed 41629 (100.0%) in 0.21 sec. BPR loss is 4.18E-04. Sample per second: 195537
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 34.47 sec. Users per second: 1081
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0304644, PRECISION_RECALL_MIN_DEN: 0.0785264, RECALL: 0.0775366, MAP: 0.0135418, MAP_MIN_DEN: 0.0348134, MRR: 0.1065614, NDCG: 0.0633063, F1: 0.0437423, HIT_RATE: 0.2378934, ARHR_ALL_HITS: 0.1198058, NOVELTY: 0.0038834, AVERAGE_POPULARITY: 0.3343305, DIVERSITY_MEAN_INTER_LIST: 0.7931435, DIVERSITY_HERFINDAHL: 0.9793122, COVERAGE_ITEM: 0.4887991, COVERAGE_ITEM_HIT: 0.0212184, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2130006, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0287784, SHANNON_ENTROPY: 7.4775462, RATIO_DIVERSITY_HERFINDAHL: 0.9797698, RATIO_DIVERSITY_GINI: 0.0656767, RATIO_SHANNON_ENTROPY: 0.5672998, RATIO_AVERAGE_POPULARITY: 5.5727395, RATIO_NOVELTY: 0.3955158,
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 75 of 700. Elapsed time 4.49 min
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 4.27E-04. Sample per second: 39804
# SLIM_BPR_Recommender: Epoch 76 of 700. Elapsed time 4.49 min
# Processed 41629 (100.0%) in 0.17 sec. BPR loss is 4.11E-04. Sample per second: 242918
# SLIM_BPR_Recommender: Epoch 77 of 700. Elapsed time 4.49 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 4.09E-04. Sample per second: 130628
# SLIM_BPR_Recommender: Epoch 78 of 700. Elapsed time 4.49 min
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 4.14E-04. Sample per second: 91652
# SLIM_BPR_Recommender: Epoch 79 of 700. Elapsed time 4.50 min
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 4.30E-04. Sample per second: 68809
# SLIM_BPR_Recommender: Epoch 80 of 700. Elapsed time 4.50 min
# Processed 41629 (100.0%) in 0.75 sec. BPR loss is 4.61E-04. Sample per second: 55226
# SLIM_BPR_Recommender: Epoch 81 of 700. Elapsed time 4.50 min
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 4.61E-04. Sample per second: 47317
# SLIM_BPR_Recommender: Epoch 82 of 700. Elapsed time 4.50 min
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 4.59E-04. Sample per second: 41390
# SLIM_BPR_Recommender: Epoch 83 of 700. Elapsed time 4.50 min
# Processed 41629 (100.0%) in 0.14 sec. BPR loss is 4.51E-04. Sample per second: 292826
# SLIM_BPR_Recommender: Epoch 84 of 700. Elapsed time 4.51 min
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 4.65E-04. Sample per second: 152520
# SLIM_BPR_Recommender: Epoch 85 of 700. Elapsed time 4.51 min
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 4.71E-04. Sample per second: 103071
# SLIM_BPR_Recommender: Epoch 86 of 700. Elapsed time 4.51 min
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 4.82E-04. Sample per second: 78418
# SLIM_BPR_Recommender: Epoch 87 of 700. Elapsed time 4.51 min
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 4.91E-04. Sample per second: 62994
# SLIM_BPR_Recommender: Epoch 88 of 700. Elapsed time 4.52 min
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 4.80E-04. Sample per second: 52346
# SLIM_BPR_Recommender: Epoch 89 of 700. Elapsed time 4.52 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 5.23E-04. Sample per second: 45139
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 35.13 sec. Users per second: 1061
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0304617, PRECISION_RECALL_MIN_DEN: 0.0785261, RECALL: 0.0775342, MAP: 0.0135848, MAP_MIN_DEN: 0.0349049, MRR: 0.1069838, NDCG: 0.0634220, F1: 0.0437392, HIT_RATE: 0.2381080, ARHR_ALL_HITS: 0.1202503, NOVELTY: 0.0038831, AVERAGE_POPULARITY: 0.3341323, DIVERSITY_MEAN_INTER_LIST: 0.7934614, DIVERSITY_HERFINDAHL: 0.9793440, COVERAGE_ITEM: 0.4869629, COVERAGE_ITEM_HIT: 0.0210552, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2131927, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0285851, SHANNON_ENTROPY: 7.4757188, RATIO_DIVERSITY_HERFINDAHL: 0.9798016, RATIO_DIVERSITY_GINI: 0.0652354, RATIO_SHANNON_ENTROPY: 0.5671612, RATIO_AVERAGE_POPULARITY: 5.5694359, RATIO_NOVELTY: 0.3954894,
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 90 of 700. Elapsed time 5.39 min
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 5.18E-04. Sample per second: 116671
# SLIM_BPR_Recommender: Epoch 91 of 700. Elapsed time 5.39 min
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 5.20E-04. Sample per second: 80518
# SLIM_BPR_Recommender: Epoch 92 of 700. Elapsed time 5.40 min
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 5.28E-04. Sample per second: 62851
# SLIM_BPR_Recommender: Epoch 93 of 700. Elapsed time 5.40 min
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 5.28E-04. Sample per second: 50671
# SLIM_BPR_Recommender: Epoch 94 of 700. Elapsed time 5.40 min
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 5.01E-04. Sample per second: 42791
# SLIM_BPR_Recommender: Epoch 95 of 700. Elapsed time 5.40 min
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 5.52E-04. Sample per second: 36919
# SLIM_BPR_Recommender: Epoch 96 of 700. Elapsed time 5.41 min
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 5.33E-04. Sample per second: 144896
# SLIM_BPR_Recommender: Epoch 97 of 700. Elapsed time 5.41 min
# Processed 41629 (100.0%) in 0.44 sec. BPR loss is 5.34E-04. Sample per second: 95240
# SLIM_BPR_Recommender: Epoch 98 of 700. Elapsed time 5.41 min
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 5.12E-04. Sample per second: 69811
# SLIM_BPR_Recommender: Epoch 99 of 700. Elapsed time 5.41 min
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 5.23E-04. Sample per second: 54845
# SLIM_BPR_Recommender: Epoch 100 of 700. Elapsed time 5.42 min
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 5.93E-04. Sample per second: 45707
# SLIM_BPR_Recommender: Epoch 101 of 700. Elapsed time 5.42 min
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 5.74E-04. Sample per second: 39716
# SLIM_BPR_Recommender: Epoch 102 of 700. Elapsed time 5.42 min
# Processed 41629 (100.0%) in 0.20 sec. BPR loss is 5.66E-04. Sample per second: 208205
# SLIM_BPR_Recommender: Epoch 103 of 700. Elapsed time 5.42 min
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 5.66E-04. Sample per second: 123766
# SLIM_BPR_Recommender: Epoch 104 of 700. Elapsed time 5.43 min
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 5.66E-04. Sample per second: 90822
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 34.65 sec. Users per second: 1076
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0305315, PRECISION_RECALL_MIN_DEN: 0.0786046, RECALL: 0.0776111, MAP: 0.0136152, MAP_MIN_DEN: 0.0349902, MRR: 0.1071227, NDCG: 0.0635305, F1: 0.0438233, HIT_RATE: 0.2383763, ARHR_ALL_HITS: 0.1204586, NOVELTY: 0.0038834, AVERAGE_POPULARITY: 0.3339501, DIVERSITY_MEAN_INTER_LIST: 0.7938242, DIVERSITY_HERFINDAHL: 0.9793803, COVERAGE_ITEM: 0.4861468, COVERAGE_ITEM_HIT: 0.0212592, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2134329, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0285563, SHANNON_ENTROPY: 7.4773277, RATIO_DIVERSITY_HERFINDAHL: 0.9798379, RATIO_DIVERSITY_GINI: 0.0651698, RATIO_SHANNON_ENTROPY: 0.5672832, RATIO_AVERAGE_POPULARITY: 5.5663980, RATIO_NOVELTY: 0.3955209,
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 105 of 700. Elapsed time 6.29 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 5.77E-04. Sample per second: 71223
# SLIM_BPR_Recommender: Epoch 106 of 700. Elapsed time 6.30 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 5.86E-04. Sample per second: 56279
# SLIM_BPR_Recommender: Epoch 107 of 700. Elapsed time 6.30 min
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 6.04E-04. Sample per second: 46775
# SLIM_BPR_Recommender: Epoch 108 of 700. Elapsed time 6.30 min
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 6.13E-04. Sample per second: 39379
# SLIM_BPR_Recommender: Epoch 109 of 700. Elapsed time 6.31 min
# Processed 41629 (100.0%) in 0.20 sec. BPR loss is 5.87E-04. Sample per second: 203618
# SLIM_BPR_Recommender: Epoch 110 of 700. Elapsed time 6.31 min
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 6.10E-04. Sample per second: 111580
# SLIM_BPR_Recommender: Epoch 111 of 700. Elapsed time 6.31 min
# Processed 41629 (100.0%) in 0.55 sec. BPR loss is 6.30E-04. Sample per second: 75260
# SLIM_BPR_Recommender: Epoch 112 of 700. Elapsed time 6.31 min
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 6.25E-04. Sample per second: 57915
# SLIM_BPR_Recommender: Epoch 113 of 700. Elapsed time 6.32 min
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 6.31E-04. Sample per second: 47041
# SLIM_BPR_Recommender: Epoch 114 of 700. Elapsed time 6.32 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 6.28E-04. Sample per second: 39015
# SLIM_BPR_Recommender: Epoch 115 of 700. Elapsed time 6.32 min
# Processed 41629 (100.0%) in 0.23 sec. BPR loss is 6.82E-04. Sample per second: 184030
# SLIM_BPR_Recommender: Epoch 116 of 700. Elapsed time 6.32 min
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 6.58E-04. Sample per second: 110135
# SLIM_BPR_Recommender: Epoch 117 of 700. Elapsed time 6.33 min
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 6.58E-04. Sample per second: 76435
# SLIM_BPR_Recommender: Epoch 118 of 700. Elapsed time 6.33 min
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 6.78E-04. Sample per second: 58813
# SLIM_BPR_Recommender: Epoch 119 of 700. Elapsed time 6.33 min
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 6.56E-04. Sample per second: 47416
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 35.41 sec. Users per second: 1053
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0305905, PRECISION_RECALL_MIN_DEN: 0.0787090, RECALL: 0.0777097, MAP: 0.0136171, MAP_MIN_DEN: 0.0349620, MRR: 0.1071321, NDCG: 0.0635480, F1: 0.0438998, HIT_RATE: 0.2388861, ARHR_ALL_HITS: 0.1204610, NOVELTY: 0.0038833, AVERAGE_POPULARITY: 0.3338494, DIVERSITY_MEAN_INTER_LIST: 0.7939865, DIVERSITY_HERFINDAHL: 0.9793965, COVERAGE_ITEM: 0.4852083, COVERAGE_ITEM_HIT: 0.0213000, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.2138894, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0285023, SHANNON_ENTROPY: 7.4760258, RATIO_DIVERSITY_HERFINDAHL: 0.9798541, RATIO_DIVERSITY_GINI: 0.0650465, RATIO_SHANNON_ENTROPY: 0.5671845, RATIO_AVERAGE_POPULARITY: 5.5647198, RATIO_NOVELTY: 0.3955147,
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 120 of 700. Elapsed time 7.22 min
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 6.67E-04. Sample per second: 47146
# SLIM_BPR_Recommender: Epoch 121 of 700. Elapsed time 7.22 min
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 6.58E-04. Sample per second: 40957
# SLIM_BPR_Recommender: Epoch 122 of 700. Elapsed time 7.22 min
# Processed 41629 (100.0%) in 0.19 sec. BPR loss is 6.99E-04. Sample per second: 213015
# SLIM_BPR_Recommender: Epoch 123 of 700. Elapsed time 7.22 min
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 6.78E-04. Sample per second: 107877
# SLIM_BPR_Recommender: Epoch 124 of 700. Elapsed time 7.23 min
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 6.89E-04. Sample per second: 65930
# SLIM_BPR_Recommender: Epoch 125 of 700. Elapsed time 7.23 min
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 6.95E-04. Sample per second: 52652
# SLIM_BPR_Recommender: Epoch 126 of 700. Elapsed time 7.23 min
# Processed 41629 (100.0%) in 0.94 sec. BPR loss is 6.98E-04. Sample per second: 44290
# SLIM_BPR_Recommender: Epoch 127 of 700. Elapsed time 7.24 min
# Processed 41629 (100.0%) in 1.09 sec. BPR loss is 7.08E-04. Sample per second: 38098
# SLIM_BPR_Recommender: Epoch 128 of 700. Elapsed time 7.24 min
# Processed 41629 (100.0%) in 0.25 sec. BPR loss is 6.93E-04. Sample per second: 165256
# SLIM_BPR_Recommender: Epoch 129 of 700. Elapsed time 7.24 min
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 6.87E-04. Sample per second: 102996
# SLIM_BPR_Recommender: Epoch 130 of 700. Elapsed time 7.24 min
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 7.53E-04. Sample per second: 73245
# SLIM_BPR_Recommender: Epoch 131 of 700. Elapsed time 7.25 min
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 7.12E-04. Sample per second: 58249
# SLIM_BPR_Recommender: Epoch 132 of 700. Elapsed time 7.25 min
# Processed 41629 (100.0%) in 0.85 sec. BPR loss is 6.99E-04. Sample per second: 48743
# SLIM_BPR_Recommender: Epoch 133 of 700. Elapsed time 7.25 min
# Processed 41629 (100.0%) in 1.00 sec. BPR loss is 7.14E-04. Sample per second: 41448
# ...
#
# SLIM_BPR_Recommender: New best model found! Updating.
# SLIM_BPR_Recommender: Epoch 15 of 150. Elapsed time 51.08 sec
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 1.04E-02. Sample per second: 66232
# SLIM_BPR_Recommender: Epoch 16 of 150. Elapsed time 51.31 sec
# Processed 41629 (100.0%) in 0.85 sec. BPR loss is 1.04E-02. Sample per second: 48734
# SLIM_BPR_Recommender: Epoch 17 of 150. Elapsed time 51.53 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 1.14E-02. Sample per second: 40001
# SLIM_BPR_Recommender: Epoch 18 of 150. Elapsed time 51.72 sec
# Processed 41629 (100.0%) in 0.22 sec. BPR loss is 1.13E-02. Sample per second: 192033
# SLIM_BPR_Recommender: Epoch 19 of 150. Elapsed time 51.90 sec
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 1.19E-02. Sample per second: 101235
# SLIM_BPR_Recommender: Epoch 20 of 150. Elapsed time 52.09 sec
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 1.33E-02. Sample per second: 71244
# SLIM_BPR_Recommender: Epoch 21 of 150. Elapsed time 52.26 sec
# Processed 41629 (100.0%) in 0.75 sec. BPR loss is 1.27E-02. Sample per second: 55839
# SLIM_BPR_Recommender: Epoch 22 of 150. Elapsed time 52.43 sec
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 1.41E-02. Sample per second: 45688
# SLIM_BPR_Recommender: Epoch 23 of 150. Elapsed time 52.59 sec
# Processed 41629 (100.0%) in 1.10 sec. BPR loss is 1.40E-02. Sample per second: 37977
# SLIM_BPR_Recommender: Epoch 24 of 150. Elapsed time 52.78 sec
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 1.51E-02. Sample per second: 146253
# SLIM_BPR_Recommender: Epoch 25 of 150. Elapsed time 52.96 sec
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 1.56E-02. Sample per second: 89777
# SLIM_BPR_Recommender: Epoch 26 of 150. Elapsed time 53.14 sec
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 1.54E-02. Sample per second: 64864
# SLIM_BPR_Recommender: Epoch 27 of 150. Elapsed time 53.32 sec
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 1.60E-02. Sample per second: 52038
# SLIM_BPR_Recommender: Epoch 28 of 150. Elapsed time 53.48 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 1.71E-02. Sample per second: 42801
# SLIM_BPR_Recommender: Epoch 29 of 150. Elapsed time 53.65 sec
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 1.74E-02. Sample per second: 36192
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 37.22 sec. Users per second: 1001
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0000000, PRECISION_RECALL_MIN_DEN: 0.0000000, RECALL: 0.0000000, MAP: 0.0000000, MAP_MIN_DEN: 0.0000000, MRR: 0.0000000, NDCG: 0.0000000, F1: 0.0000000, HIT_RATE: 0.0000000, ARHR_ALL_HITS: 0.0000000, NOVELTY: 0.0038277, AVERAGE_POPULARITY: 0.3280520, DIVERSITY_MEAN_INTER_LIST: 0.8145050, DIVERSITY_HERFINDAHL: 0.9814483, COVERAGE_ITEM: 0.3105235, COVERAGE_ITEM_HIT: 0.0000000, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.0000000, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0128732, SHANNON_ENTROPY: 7.2662112, RATIO_DIVERSITY_HERFINDAHL: 0.9819045, RATIO_DIVERSITY_GINI: 0.0289780, RATIO_SHANNON_ENTROPY: 0.5509365, RATIO_AVERAGE_POPULARITY: 5.4183531, RATIO_NOVELTY: 0.2814933,
#
# SLIM_BPR_Recommender: Epoch 30 of 150. Elapsed time 1.79 min
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 1.73E-02. Sample per second: 36618
# SLIM_BPR_Recommender: Epoch 31 of 150. Elapsed time 1.80 min
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 1.87E-02. Sample per second: 99812
# SLIM_BPR_Recommender: Epoch 32 of 150. Elapsed time 1.80 min
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 1.92E-02. Sample per second: 54540
# SLIM_BPR_Recommender: Epoch 33 of 150. Elapsed time 1.81 min
# Processed 41629 (100.0%) in 1.00 sec. BPR loss is 1.90E-02. Sample per second: 41634
# SLIM_BPR_Recommender: Epoch 34 of 150. Elapsed time 1.81 min
# Processed 41629 (100.0%) in 0.24 sec. BPR loss is 1.96E-02. Sample per second: 175650
# SLIM_BPR_Recommender: Epoch 35 of 150. Elapsed time 1.82 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 2.01E-02. Sample per second: 71935
# SLIM_BPR_Recommender: Epoch 36 of 150. Elapsed time 1.82 min
# Processed 41629 (100.0%) in 0.94 sec. BPR loss is 2.08E-02. Sample per second: 44063
# SLIM_BPR_Recommender: Epoch 37 of 150. Elapsed time 1.83 min
# Processed 41629 (100.0%) in 1.18 sec. BPR loss is 1.99E-02. Sample per second: 35179
# SLIM_BPR_Recommender: Epoch 38 of 150. Elapsed time 1.83 min
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 2.12E-02. Sample per second: 98894
# SLIM_BPR_Recommender: Epoch 39 of 150. Elapsed time 1.84 min
# Processed 41629 (100.0%) in 0.65 sec. BPR loss is 2.29E-02. Sample per second: 63792
# SLIM_BPR_Recommender: Epoch 40 of 150. Elapsed time 1.84 min
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 2.21E-02. Sample per second: 46820
# SLIM_BPR_Recommender: Epoch 41 of 150. Elapsed time 1.84 min
# Processed 41629 (100.0%) in 1.10 sec. BPR loss is 2.38E-02. Sample per second: 37727
# SLIM_BPR_Recommender: Epoch 42 of 150. Elapsed time 1.85 min
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 2.26E-02. Sample per second: 132699
# SLIM_BPR_Recommender: Epoch 43 of 150. Elapsed time 1.85 min
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 2.22E-02. Sample per second: 78185
# SLIM_BPR_Recommender: Epoch 44 of 150. Elapsed time 1.85 min
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 2.40E-02. Sample per second: 57232
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 39.03 sec. Users per second: 955
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0000000, PRECISION_RECALL_MIN_DEN: 0.0000000, RECALL: 0.0000000, MAP: 0.0000000, MAP_MIN_DEN: 0.0000000, MRR: 0.0000000, NDCG: 0.0000000, F1: 0.0000000, HIT_RATE: 0.0000000, ARHR_ALL_HITS: 0.0000000, NOVELTY: 0.0038361, AVERAGE_POPULARITY: 0.3237239, DIVERSITY_MEAN_INTER_LIST: 0.8213164, DIVERSITY_HERFINDAHL: 0.9821294, COVERAGE_ITEM: 0.3062390, COVERAGE_ITEM_HIT: 0.0000000, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.0000000, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0127316, SHANNON_ENTROPY: 7.3076420, RATIO_DIVERSITY_HERFINDAHL: 0.9825860, RATIO_DIVERSITY_GINI: 0.0286593, RATIO_SHANNON_ENTROPY: 0.5540779, RATIO_AVERAGE_POPULARITY: 5.3468674, RATIO_NOVELTY: 0.2821110,
#
# SLIM_BPR_Recommender: Epoch 45 of 150. Elapsed time 2.80 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 2.50E-02. Sample per second: 45147
# SLIM_BPR_Recommender: Epoch 46 of 150. Elapsed time 2.81 min
# Processed 41629 (100.0%) in 1.30 sec. BPR loss is 2.56E-02. Sample per second: 32034
# SLIM_BPR_Recommender: Epoch 47 of 150. Elapsed time 2.82 min
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 2.55E-02. Sample per second: 63443
# SLIM_BPR_Recommender: Epoch 48 of 150. Elapsed time 2.82 min
# Processed 41629 (100.0%) in 0.95 sec. BPR loss is 2.65E-02. Sample per second: 43807
# SLIM_BPR_Recommender: Epoch 49 of 150. Elapsed time 2.83 min
# Processed 41629 (100.0%) in 1.24 sec. BPR loss is 2.58E-02. Sample per second: 33560
# SLIM_BPR_Recommender: Epoch 50 of 150. Elapsed time 2.83 min
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 2.57E-02. Sample per second: 80026
# SLIM_BPR_Recommender: Epoch 51 of 150. Elapsed time 2.84 min
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 2.74E-02. Sample per second: 52824
# SLIM_BPR_Recommender: Epoch 52 of 150. Elapsed time 2.84 min
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 2.72E-02. Sample per second: 40181
# SLIM_BPR_Recommender: Epoch 53 of 150. Elapsed time 2.85 min
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 2.75E-02. Sample per second: 120991
# SLIM_BPR_Recommender: Epoch 54 of 150. Elapsed time 2.85 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 2.92E-02. Sample per second: 71634
# SLIM_BPR_Recommender: Epoch 55 of 150. Elapsed time 2.85 min
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 2.82E-02. Sample per second: 51852
# SLIM_BPR_Recommender: Epoch 56 of 150. Elapsed time 2.86 min
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 2.89E-02. Sample per second: 36198
# SLIM_BPR_Recommender: Epoch 57 of 150. Elapsed time 2.86 min
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 2.96E-02. Sample per second: 100333
# SLIM_BPR_Recommender: Epoch 58 of 150. Elapsed time 2.87 min
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 3.01E-02. Sample per second: 61599
# SLIM_BPR_Recommender: Epoch 59 of 150. Elapsed time 2.87 min
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 2.90E-02. Sample per second: 44536
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 33.57 sec. Users per second: 1110
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0000000, PRECISION_RECALL_MIN_DEN: 0.0000000, RECALL: 0.0000000, MAP: 0.0000000, MAP_MIN_DEN: 0.0000000, MRR: 0.0000000, NDCG: 0.0000000, F1: 0.0000000, HIT_RATE: 0.0000000, ARHR_ALL_HITS: 0.0000000, NOVELTY: 0.0038444, AVERAGE_POPULARITY: 0.3194755, DIVERSITY_MEAN_INTER_LIST: 0.8282870, DIVERSITY_HERFINDAHL: 0.9828265, COVERAGE_ITEM: 0.3041172, COVERAGE_ITEM_HIT: 0.0000000, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.0000000, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0127022, SHANNON_ENTROPY: 7.3521283, RATIO_DIVERSITY_HERFINDAHL: 0.9832834, RATIO_DIVERSITY_GINI: 0.0285929, RATIO_SHANNON_ENTROPY: 0.5574509, RATIO_AVERAGE_POPULARITY: 5.2766975, RATIO_NOVELTY: 0.2827279,
#
# SLIM_BPR_Recommender: Epoch 60 of 150. Elapsed time 3.76 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 3.05E-02. Sample per second: 129908
# SLIM_BPR_Recommender: Epoch 61 of 150. Elapsed time 3.77 min
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 3.14E-02. Sample per second: 79473
# SLIM_BPR_Recommender: Epoch 62 of 150. Elapsed time 3.77 min
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 3.20E-02. Sample per second: 57170
# SLIM_BPR_Recommender: Epoch 63 of 150. Elapsed time 3.77 min
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 3.02E-02. Sample per second: 44737
# SLIM_BPR_Recommender: Epoch 64 of 150. Elapsed time 3.78 min
# Processed 41629 (100.0%) in 1.11 sec. BPR loss is 3.11E-02. Sample per second: 37417
# SLIM_BPR_Recommender: Epoch 65 of 150. Elapsed time 3.78 min
# Processed 41629 (100.0%) in 0.30 sec. BPR loss is 3.42E-02. Sample per second: 138283
# SLIM_BPR_Recommender: Epoch 66 of 150. Elapsed time 3.78 min
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 3.28E-02. Sample per second: 81411
# SLIM_BPR_Recommender: Epoch 67 of 150. Elapsed time 3.79 min
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 3.26E-02. Sample per second: 57331
# SLIM_BPR_Recommender: Epoch 68 of 150. Elapsed time 3.79 min
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 3.27E-02. Sample per second: 44764
# SLIM_BPR_Recommender: Epoch 69 of 150. Elapsed time 3.79 min
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 3.26E-02. Sample per second: 36795
# SLIM_BPR_Recommender: Epoch 70 of 150. Elapsed time 3.80 min
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 3.28E-02. Sample per second: 100177
# SLIM_BPR_Recommender: Epoch 71 of 150. Elapsed time 3.80 min
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 3.31E-02. Sample per second: 57691
# SLIM_BPR_Recommender: Epoch 72 of 150. Elapsed time 3.81 min
# Processed 41629 (100.0%) in 0.95 sec. BPR loss is 3.45E-02. Sample per second: 43970
# SLIM_BPR_Recommender: Epoch 73 of 150. Elapsed time 3.81 min
# Processed 41629 (100.0%) in 1.18 sec. BPR loss is 3.45E-02. Sample per second: 35312
# SLIM_BPR_Recommender: Epoch 74 of 150. Elapsed time 3.81 min
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 3.32E-02. Sample per second: 104431
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 33.35 sec. Users per second: 1118
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0000000, PRECISION_RECALL_MIN_DEN: 0.0000000, RECALL: 0.0000000, MAP: 0.0000000, MAP_MIN_DEN: 0.0000000, MRR: 0.0000000, NDCG: 0.0000000, F1: 0.0000000, HIT_RATE: 0.0000000, ARHR_ALL_HITS: 0.0000000, NOVELTY: 0.0038533, AVERAGE_POPULARITY: 0.3149452, DIVERSITY_MEAN_INTER_LIST: 0.8354373, DIVERSITY_HERFINDAHL: 0.9835415, COVERAGE_ITEM: 0.3042396, COVERAGE_ITEM_HIT: 0.0000000, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.0000000, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0127626, SHANNON_ENTROPY: 7.3973776, RATIO_DIVERSITY_HERFINDAHL: 0.9839987, RATIO_DIVERSITY_GINI: 0.0287290, RATIO_SHANNON_ENTROPY: 0.5608818, RATIO_AVERAGE_POPULARITY: 5.2018716, RATIO_NOVELTY: 0.2833799,
#
# SLIM_BPR_Recommender: Epoch 75 of 150. Elapsed time 4.63 min
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 3.50E-02. Sample per second: 123637
# SLIM_BPR_Recommender: Epoch 76 of 150. Elapsed time 4.63 min
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 3.58E-02. Sample per second: 77452
# SLIM_BPR_Recommender: Epoch 77 of 150. Elapsed time 4.64 min
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 3.56E-02. Sample per second: 57211
# SLIM_BPR_Recommender: Epoch 78 of 150. Elapsed time 4.64 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 3.62E-02. Sample per second: 45440
# SLIM_BPR_Recommender: Epoch 79 of 150. Elapsed time 4.64 min
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 3.56E-02. Sample per second: 38497
# SLIM_BPR_Recommender: Epoch 80 of 150. Elapsed time 4.65 min
# Processed 41629 (100.0%) in 0.24 sec. BPR loss is 3.63E-02. Sample per second: 170262
# SLIM_BPR_Recommender: Epoch 81 of 150. Elapsed time 4.65 min
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 3.59E-02. Sample per second: 101249
# SLIM_BPR_Recommender: Epoch 82 of 150. Elapsed time 4.65 min
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 3.84E-02. Sample per second: 72859
# SLIM_BPR_Recommender: Epoch 83 of 150. Elapsed time 4.65 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 3.81E-02. Sample per second: 56359
# SLIM_BPR_Recommender: Epoch 84 of 150. Elapsed time 4.66 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 3.84E-02. Sample per second: 45338
# SLIM_BPR_Recommender: Epoch 85 of 150. Elapsed time 4.66 min
# Processed 41629 (100.0%) in 1.09 sec. BPR loss is 3.91E-02. Sample per second: 38320
# SLIM_BPR_Recommender: Epoch 86 of 150. Elapsed time 4.66 min
# Processed 41629 (100.0%) in 0.25 sec. BPR loss is 3.74E-02. Sample per second: 165519
# SLIM_BPR_Recommender: Epoch 87 of 150. Elapsed time 4.67 min
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 3.90E-02. Sample per second: 99117
# SLIM_BPR_Recommender: Epoch 88 of 150. Elapsed time 4.67 min
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 3.82E-02. Sample per second: 70072
# SLIM_BPR_Recommender: Epoch 89 of 150. Elapsed time 4.67 min
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 3.75E-02. Sample per second: 54721
# SLIM_BPR_Recommender: Validation begins...
# EvaluatorHoldout: Processed 37273 (100.0%) in 33.14 sec. Users per second: 1125
# SLIM_BPR_Recommender: CUTOFF: 10 - PRECISION: 0.0000000, PRECISION_RECALL_MIN_DEN: 0.0000000, RECALL: 0.0000000, MAP: 0.0000000, MAP_MIN_DEN: 0.0000000, MRR: 0.0000000, NDCG: 0.0000000, F1: 0.0000000, HIT_RATE: 0.0000000, ARHR_ALL_HITS: 0.0000000, NOVELTY: 0.0038632, AVERAGE_POPULARITY: 0.3096992, DIVERSITY_MEAN_INTER_LIST: 0.8432526, DIVERSITY_HERFINDAHL: 0.9843230, COVERAGE_ITEM: 0.3023218, COVERAGE_ITEM_HIT: 0.0000000, ITEMS_IN_GT: 0.9297344, COVERAGE_USER: 0.8953614, COVERAGE_USER_HIT: 0.0000000, USERS_IN_GT: 0.8953614, DIVERSITY_GINI: 0.0127961, SHANNON_ENTROPY: 7.4457398, RATIO_DIVERSITY_HERFINDAHL: 0.9847806, RATIO_DIVERSITY_GINI: 0.0288044, RATIO_SHANNON_ENTROPY: 0.5645487, RATIO_AVERAGE_POPULARITY: 5.1152245, RATIO_NOVELTY: 0.2841096,
#
# SLIM_BPR_Recommender: Convergence reached! Terminating at epoch 90. Best value for 'MAP' at epoch 15 is 0.0000. Elapsed time 5.52 min
# SLIM_BPR_Recommender: Epoch 90 of 150. Elapsed time 5.52 min
# Deallocating Cython objects
# SearchBayesianSkopt: Saving model in Experiments/SLIM_BPR_Recommender
#
# SLIM_BPR_Recommender: Saving model in file 'Experiments/SLIM_BPR_Recommender_best_model_last'
# SLIM_BPR_Recommender: Saving complete
# Deallocating Cython objects

# %%
from Recommenders.DataIO import DataIO

#explore the results of the search
data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

search_metadata.keys()
# Out:
# dict_keys(['algorithm_name_recommender', 'algorithm_name_search', 'cutoff_to_optimize', 'exception_list', 'hyperparameters_best', 'hyperparameters_best_index', 'hyperparameters_df', 'metric_to_optimize', 'result_on_earlystopping_df', 'result_on_last', 'result_on_test_best', 'result_on_test_df', 'result_on_validation_best', 'result_on_validation_df', 'time_df', 'time_on_last_df', 'time_on_test_avg', 'time_on_test_total', 'time_on_train_avg', 'time_on_train_total', 'time_on_validation_avg', 'time_on_validation_total'])

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#   epochs sgd_mode topK  lambda_i  lambda_j learning_rate
# 0     15     adam  162  0.028932  0.024831      0.000223
# 1    690  adagrad  203  0.013059  0.053613       0.00021
# 2    690      sgd  248  0.001175  0.008156      0.004101
# 3     45      sgd  237  0.098615  0.004788      0.009941
# 4    690      sgd  260  0.000864  0.006736      0.004865
# 5    135  adagrad  284    0.0001  0.005777       0.00049
# 6     15     adam  174    0.0001  0.002028      0.002223
# 7    150  adagrad  116  0.099904  0.001133      0.001331
# 8     15  adagrad  590       0.1    0.0001      0.048334
# 9    540  adagrad    5    0.0001  0.055215      0.002598

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#          PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#   cutoff
# 0 10      0.029042                 0.075548  0.074617   0.01265    0.033033
# 1 10      0.030768                 0.079168  0.078173  0.013758    0.035275
# 2 10      0.032063                 0.083292  0.082319  0.014368    0.037373
# 3 10      0.030124                 0.077981  0.077035  0.012918    0.033111
# 4 10      0.032249                 0.083742  0.082749  0.014433    0.037521
# 5 10      0.030362                 0.078117   0.07713  0.013399    0.034426
# 6 10      0.029684                 0.077371  0.076429  0.012904    0.033628
# 7 10      0.032544                 0.082636  0.081524  0.014815    0.036954
# 8 10      0.021101                 0.050217  0.049316  0.008369    0.019673
# 9 10      0.030032                  0.07494  0.073942  0.013429    0.033869
#
#                MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#   cutoff                                                        ...
# 0 10      0.101065  0.060334  0.041811  0.230113      0.112795  ...
# 1 10      0.108266  0.064066  0.044156  0.240201      0.121725  ...
# 2 10      0.113851  0.067544  0.046151  0.251254      0.127643  ...
# 3 10      0.102927  0.061533  0.043311  0.239664      0.115075  ...
# 4 10       0.11432  0.067835   0.04641  0.252623      0.128201  ...
# 5 10      0.105433  0.062781  0.043572  0.236874      0.118537  ...
# 6 10      0.102652  0.061526   0.04276  0.234379      0.114821  ...
# 7 10      0.114405  0.067235  0.046518  0.249242      0.129813  ...
# 8 10      0.066795  0.038941  0.029556  0.169935      0.074571  ...
# 9 10      0.106274  0.061752  0.042715  0.234674      0.119194  ...
#
#          COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#   cutoff
# 0 10          0.895361          0.206034    0.895361       0.026106
# 1 10          0.895361          0.215066    0.895361       0.028121
# 2 10          0.895361          0.224963    0.895361        0.02718
# 3 10          0.895361          0.214586    0.895361       0.025836
# 4 10          0.895361          0.226188    0.895361       0.027862
# 5 10          0.895361          0.212088    0.895361       0.027304
# 6 10          0.895361          0.209854    0.895361        0.02762
# 7 10          0.895361          0.223162    0.895361       0.032102
# 8 10          0.895361          0.152154    0.895361       0.084752
# 9 10          0.895361          0.210118    0.895361       0.091922
#
#          SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#   cutoff
# 0 10            7.191279                   0.975711             0.059577
# 1 10            7.489129                   0.980137             0.064175
# 2 10            8.062424                   0.986952             0.062029
# 3 10            8.370642                    0.99153             0.058961
# 4 10            8.142371                   0.987686             0.063585
# 5 10              7.3486                   0.978078             0.062312
# 6 10            7.299853                   0.976671             0.063034
# 7 10            8.184916                   0.989669             0.073262
# 8 10           10.684975                   0.998996             0.193417
# 9 10            9.966349                   0.995125              0.20978
#
#          RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#   cutoff
# 0 10                  0.545582                 5.963483      0.389159
# 1 10                  0.568179                 5.539833      0.395767
# 2 10                  0.611673                 4.833712      0.405138
# 3 10                  0.635056                 3.977819      0.414112
# 4 10                  0.617738                 4.740049      0.406911
# 5 10                  0.557517                 5.749305      0.392777
# 6 10                  0.553819                 5.892495      0.390964
# 7 10                  0.620966                 4.400237      0.410667
# 8 10                  0.810638                 1.339368      0.484435
# 9 10                  0.756118                 3.044067      0.465576
#
# [10 rows x 27 columns]

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'epochs': 150,
#  'sgd_mode': 'adagrad',
#  'topK': 116,
#  'lambda_i': 0.0999035041910438,
#  'lambda_j': 0.001133491359312735,
#  'learning_rate': 0.0013313596244767724}

# %%
recommender = SLIM_BPR_Cython(URM_all)
recommender.fit(epochs=462, sgd_mode = "sgd", topK = 50, lambda_i = 0.0002100158148046903, lambda_j = 0.00021427617376060016, learning_rate = 0.02543769736452639)
# Out:
# Unable to read memory status: list index out of range
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Unable to get current RAM status, you may be using a non-Linux operating system. Using dense matrix.
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 3.04E-04. Sample per second: 89830
# SLIM_BPR_Recommender: Epoch 1 of 150. Elapsed time 0.16 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 9.97E-04. Sample per second: 63385
# SLIM_BPR_Recommender: Epoch 2 of 150. Elapsed time 0.35 sec
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 1.69E-03. Sample per second: 50404
# SLIM_BPR_Recommender: Epoch 3 of 150. Elapsed time 0.52 sec
# Processed 41629 (100.0%) in 1.00 sec. BPR loss is 2.24E-03. Sample per second: 41494
# SLIM_BPR_Recommender: Epoch 4 of 150. Elapsed time 0.70 sec
# Processed 41629 (100.0%) in 0.19 sec. BPR loss is 3.06E-03. Sample per second: 213253
# SLIM_BPR_Recommender: Epoch 5 of 150. Elapsed time 0.89 sec
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 3.72E-03. Sample per second: 111081
# SLIM_BPR_Recommender: Epoch 6 of 150. Elapsed time 1.07 sec
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 4.34E-03. Sample per second: 74040
# SLIM_BPR_Recommender: Epoch 7 of 150. Elapsed time 1.25 sec
# Processed 41629 (100.0%) in 0.75 sec. BPR loss is 5.32E-03. Sample per second: 55633
# SLIM_BPR_Recommender: Epoch 8 of 150. Elapsed time 1.44 sec
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 5.51E-03. Sample per second: 46126
# SLIM_BPR_Recommender: Epoch 9 of 150. Elapsed time 1.59 sec
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 6.22E-03. Sample per second: 39425
# SLIM_BPR_Recommender: Epoch 10 of 150. Elapsed time 1.75 sec
# Processed 41629 (100.0%) in 0.21 sec. BPR loss is 6.99E-03. Sample per second: 200916
# SLIM_BPR_Recommender: Epoch 11 of 150. Elapsed time 1.90 sec
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 7.73E-03. Sample per second: 115645
# SLIM_BPR_Recommender: Epoch 12 of 150. Elapsed time 2.05 sec
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 8.37E-03. Sample per second: 81657
# SLIM_BPR_Recommender: Epoch 13 of 150. Elapsed time 2.20 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 9.02E-03. Sample per second: 63065
# SLIM_BPR_Recommender: Epoch 14 of 150. Elapsed time 2.35 sec
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 9.36E-03. Sample per second: 51434
# SLIM_BPR_Recommender: Epoch 15 of 150. Elapsed time 2.50 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 1.01E-02. Sample per second: 43402
# SLIM_BPR_Recommender: Epoch 16 of 150. Elapsed time 2.65 sec
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 1.10E-02. Sample per second: 36960
# SLIM_BPR_Recommender: Epoch 17 of 150. Elapsed time 2.82 sec
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 1.08E-02. Sample per second: 134359
# SLIM_BPR_Recommender: Epoch 18 of 150. Elapsed time 3.00 sec
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 1.15E-02. Sample per second: 89598
# SLIM_BPR_Recommender: Epoch 19 of 150. Elapsed time 3.16 sec
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 1.28E-02. Sample per second: 65944
# SLIM_BPR_Recommender: Epoch 20 of 150. Elapsed time 3.32 sec
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 1.26E-02. Sample per second: 51883
# SLIM_BPR_Recommender: Epoch 21 of 150. Elapsed time 3.49 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 1.31E-02. Sample per second: 42720
# SLIM_BPR_Recommender: Epoch 22 of 150. Elapsed time 3.67 sec
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 1.40E-02. Sample per second: 36228
# SLIM_BPR_Recommender: Epoch 23 of 150. Elapsed time 3.84 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 1.43E-02. Sample per second: 128214
# SLIM_BPR_Recommender: Epoch 24 of 150. Elapsed time 4.02 sec
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 1.49E-02. Sample per second: 83049
# SLIM_BPR_Recommender: Epoch 25 of 150. Elapsed time 4.19 sec
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 1.60E-02. Sample per second: 61283
# SLIM_BPR_Recommender: Epoch 26 of 150. Elapsed time 4.37 sec
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 1.56E-02. Sample per second: 48525
# SLIM_BPR_Recommender: Epoch 27 of 150. Elapsed time 4.55 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 1.62E-02. Sample per second: 40108
# SLIM_BPR_Recommender: Epoch 28 of 150. Elapsed time 4.73 sec
# Processed 41629 (100.0%) in 0.22 sec. BPR loss is 1.72E-02. Sample per second: 193175
# SLIM_BPR_Recommender: Epoch 29 of 150. Elapsed time 4.91 sec
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 1.72E-02. Sample per second: 100106
# SLIM_BPR_Recommender: Epoch 30 of 150. Elapsed time 5.11 sec
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 1.81E-02. Sample per second: 65652
# SLIM_BPR_Recommender: Epoch 31 of 150. Elapsed time 5.33 sec
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 1.89E-02. Sample per second: 51255
# SLIM_BPR_Recommender: Epoch 32 of 150. Elapsed time 5.50 sec
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 1.95E-02. Sample per second: 41935
# SLIM_BPR_Recommender: Epoch 33 of 150. Elapsed time 5.68 sec
# Processed 41629 (100.0%) in 1.17 sec. BPR loss is 1.91E-02. Sample per second: 35587
# SLIM_BPR_Recommender: Epoch 34 of 150. Elapsed time 5.86 sec
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 2.01E-02. Sample per second: 123377
# SLIM_BPR_Recommender: Epoch 35 of 150. Elapsed time 6.03 sec
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 2.05E-02. Sample per second: 81781
# SLIM_BPR_Recommender: Epoch 36 of 150. Elapsed time 6.20 sec
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 2.05E-02. Sample per second: 59810
# SLIM_BPR_Recommender: Epoch 37 of 150. Elapsed time 6.39 sec
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 2.15E-02. Sample per second: 46210
# SLIM_BPR_Recommender: Epoch 38 of 150. Elapsed time 6.59 sec
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 2.12E-02. Sample per second: 38726
# SLIM_BPR_Recommender: Epoch 39 of 150. Elapsed time 6.77 sec
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 2.24E-02. Sample per second: 162926
# SLIM_BPR_Recommender: Epoch 40 of 150. Elapsed time 6.95 sec
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 2.12E-02. Sample per second: 98724
# SLIM_BPR_Recommender: Epoch 41 of 150. Elapsed time 7.11 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 2.29E-02. Sample per second: 67457
# SLIM_BPR_Recommender: Epoch 42 of 150. Elapsed time 7.31 sec
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 2.30E-02. Sample per second: 52948
# SLIM_BPR_Recommender: Epoch 43 of 150. Elapsed time 7.48 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 2.38E-02. Sample per second: 43171
# SLIM_BPR_Recommender: Epoch 44 of 150. Elapsed time 7.66 sec
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 2.29E-02. Sample per second: 36441
# SLIM_BPR_Recommender: Epoch 45 of 150. Elapsed time 7.83 sec
# Processed 41629 (100.0%) in 0.33 sec. BPR loss is 2.64E-02. Sample per second: 127745
# SLIM_BPR_Recommender: Epoch 46 of 150. Elapsed time 8.02 sec
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 2.53E-02. Sample per second: 83923
# SLIM_BPR_Recommender: Epoch 47 of 150. Elapsed time 8.19 sec
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 2.50E-02. Sample per second: 61527
# SLIM_BPR_Recommender: Epoch 48 of 150. Elapsed time 8.37 sec
# Processed 41629 (100.0%) in 0.85 sec. BPR loss is 2.55E-02. Sample per second: 48908
# SLIM_BPR_Recommender: Epoch 49 of 150. Elapsed time 8.54 sec
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 2.73E-02. Sample per second: 40409
# SLIM_BPR_Recommender: Epoch 50 of 150. Elapsed time 8.72 sec
# Processed 41629 (100.0%) in 0.21 sec. BPR loss is 2.71E-02. Sample per second: 196611
# SLIM_BPR_Recommender: Epoch 51 of 150. Elapsed time 8.90 sec
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 2.65E-02. Sample per second: 104276
# SLIM_BPR_Recommender: Epoch 52 of 150. Elapsed time 9.09 sec
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 2.71E-02. Sample per second: 69600
# SLIM_BPR_Recommender: Epoch 53 of 150. Elapsed time 9.29 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 2.81E-02. Sample per second: 50997
# SLIM_BPR_Recommender: Epoch 54 of 150. Elapsed time 9.51 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 2.79E-02. Sample per second: 42691
# SLIM_BPR_Recommender: Epoch 55 of 150. Elapsed time 9.67 sec
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 2.91E-02. Sample per second: 36651
# SLIM_BPR_Recommender: Epoch 56 of 150. Elapsed time 9.83 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 2.94E-02. Sample per second: 145504
# SLIM_BPR_Recommender: Epoch 57 of 150. Elapsed time 9.98 sec
# Processed 41629 (100.0%) in 0.44 sec. BPR loss is 2.83E-02. Sample per second: 95290
# SLIM_BPR_Recommender: Epoch 58 of 150. Elapsed time 10.13 sec
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 2.84E-02. Sample per second: 70746
# SLIM_BPR_Recommender: Epoch 59 of 150. Elapsed time 10.28 sec
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 2.97E-02. Sample per second: 56113
# SLIM_BPR_Recommender: Epoch 60 of 150. Elapsed time 10.43 sec
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 2.93E-02. Sample per second: 46843
# SLIM_BPR_Recommender: Epoch 61 of 150. Elapsed time 10.58 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 2.96E-02. Sample per second: 40137
# SLIM_BPR_Recommender: Epoch 62 of 150. Elapsed time 10.73 sec
# Processed 41629 (100.0%) in 0.19 sec. BPR loss is 2.99E-02. Sample per second: 222061
# SLIM_BPR_Recommender: Epoch 63 of 150. Elapsed time 10.88 sec
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 3.09E-02. Sample per second: 123252
# SLIM_BPR_Recommender: Epoch 64 of 150. Elapsed time 11.03 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 3.15E-02. Sample per second: 85737
# SLIM_BPR_Recommender: Epoch 65 of 150. Elapsed time 11.18 sec
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 3.22E-02. Sample per second: 65370
# SLIM_BPR_Recommender: Epoch 66 of 150. Elapsed time 11.33 sec
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 3.13E-02. Sample per second: 52953
# SLIM_BPR_Recommender: Epoch 67 of 150. Elapsed time 11.48 sec
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 3.25E-02. Sample per second: 44693
# SLIM_BPR_Recommender: Epoch 68 of 150. Elapsed time 11.62 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 3.22E-02. Sample per second: 38568
# SLIM_BPR_Recommender: Epoch 69 of 150. Elapsed time 11.77 sec
# Processed 41629 (100.0%) in 0.23 sec. BPR loss is 3.30E-02. Sample per second: 181663
# SLIM_BPR_Recommender: Epoch 70 of 150. Elapsed time 11.92 sec
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 3.32E-02. Sample per second: 110532
# SLIM_BPR_Recommender: Epoch 71 of 150. Elapsed time 12.07 sec
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 3.42E-02. Sample per second: 79450
# SLIM_BPR_Recommender: Epoch 72 of 150. Elapsed time 12.22 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 3.46E-02. Sample per second: 61736
# SLIM_BPR_Recommender: Epoch 73 of 150. Elapsed time 12.37 sec
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 3.50E-02. Sample per second: 50122
# SLIM_BPR_Recommender: Epoch 74 of 150. Elapsed time 12.52 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 3.55E-02. Sample per second: 42593
# SLIM_BPR_Recommender: Epoch 75 of 150. Elapsed time 12.67 sec
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 3.45E-02. Sample per second: 37010
# SLIM_BPR_Recommender: Epoch 76 of 150. Elapsed time 12.82 sec
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 3.55E-02. Sample per second: 152709
# SLIM_BPR_Recommender: Epoch 77 of 150. Elapsed time 12.96 sec
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 3.47E-02. Sample per second: 98777
# SLIM_BPR_Recommender: Epoch 78 of 150. Elapsed time 13.11 sec
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 3.53E-02. Sample per second: 72939
# SLIM_BPR_Recommender: Epoch 79 of 150. Elapsed time 13.26 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 3.71E-02. Sample per second: 57620
# SLIM_BPR_Recommender: Epoch 80 of 150. Elapsed time 13.41 sec
# Processed 41629 (100.0%) in 0.87 sec. BPR loss is 3.70E-02. Sample per second: 47725
# SLIM_BPR_Recommender: Epoch 81 of 150. Elapsed time 13.56 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 3.68E-02. Sample per second: 40671
# SLIM_BPR_Recommender: Epoch 82 of 150. Elapsed time 13.72 sec
# Processed 41629 (100.0%) in 0.18 sec. BPR loss is 3.65E-02. Sample per second: 234786
# SLIM_BPR_Recommender: Epoch 83 of 150. Elapsed time 13.87 sec
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 3.59E-02. Sample per second: 115071
# SLIM_BPR_Recommender: Epoch 84 of 150. Elapsed time 14.05 sec
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 3.86E-02. Sample per second: 76974
# SLIM_BPR_Recommender: Epoch 85 of 150. Elapsed time 14.23 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 3.76E-02. Sample per second: 57590
# SLIM_BPR_Recommender: Epoch 86 of 150. Elapsed time 14.41 sec
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 3.78E-02. Sample per second: 46514
# SLIM_BPR_Recommender: Epoch 87 of 150. Elapsed time 14.59 sec
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 3.82E-02. Sample per second: 38995
# SLIM_BPR_Recommender: Epoch 88 of 150. Elapsed time 14.76 sec
# Processed 41629 (100.0%) in 0.24 sec. BPR loss is 3.87E-02. Sample per second: 170186
# SLIM_BPR_Recommender: Epoch 89 of 150. Elapsed time 14.94 sec
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 3.94E-02. Sample per second: 102083
# SLIM_BPR_Recommender: Epoch 90 of 150. Elapsed time 15.10 sec
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 3.94E-02. Sample per second: 71970
# SLIM_BPR_Recommender: Epoch 91 of 150. Elapsed time 15.27 sec
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 3.98E-02. Sample per second: 54919
# SLIM_BPR_Recommender: Epoch 92 of 150. Elapsed time 15.45 sec
# Processed 41629 (100.0%) in 0.94 sec. BPR loss is 3.98E-02. Sample per second: 44331
# SLIM_BPR_Recommender: Epoch 93 of 150. Elapsed time 15.63 sec
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 3.97E-02. Sample per second: 37232
# SLIM_BPR_Recommender: Epoch 94 of 150. Elapsed time 15.81 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 4.04E-02. Sample per second: 142245
# SLIM_BPR_Recommender: Epoch 95 of 150. Elapsed time 15.98 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 4.16E-02. Sample per second: 88905
# SLIM_BPR_Recommender: Epoch 96 of 150. Elapsed time 16.16 sec
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 3.90E-02. Sample per second: 64859
# SLIM_BPR_Recommender: Epoch 97 of 150. Elapsed time 16.33 sec
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 4.07E-02. Sample per second: 49836
# SLIM_BPR_Recommender: Epoch 98 of 150. Elapsed time 16.53 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 4.17E-02. Sample per second: 40941
# SLIM_BPR_Recommender: Epoch 99 of 150. Elapsed time 16.71 sec
# Processed 41629 (100.0%) in 0.19 sec. BPR loss is 4.16E-02. Sample per second: 222064
# SLIM_BPR_Recommender: Epoch 100 of 150. Elapsed time 16.88 sec
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 4.09E-02. Sample per second: 118060
# SLIM_BPR_Recommender: Epoch 101 of 150. Elapsed time 17.04 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 4.37E-02. Sample per second: 78809
# SLIM_BPR_Recommender: Epoch 102 of 150. Elapsed time 17.22 sec
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 4.20E-02. Sample per second: 58943
# SLIM_BPR_Recommender: Epoch 103 of 150. Elapsed time 17.40 sec
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 4.23E-02. Sample per second: 47128
# SLIM_BPR_Recommender: Epoch 104 of 150. Elapsed time 17.58 sec
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 4.39E-02. Sample per second: 38930
# SLIM_BPR_Recommender: Epoch 105 of 150. Elapsed time 17.76 sec
# Processed 41629 (100.0%) in 0.24 sec. BPR loss is 4.28E-02. Sample per second: 171365
# SLIM_BPR_Recommender: Epoch 106 of 150. Elapsed time 17.93 sec
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 4.40E-02. Sample per second: 100301
# SLIM_BPR_Recommender: Epoch 107 of 150. Elapsed time 18.11 sec
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 4.33E-02. Sample per second: 69780
# SLIM_BPR_Recommender: Epoch 108 of 150. Elapsed time 18.29 sec
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 4.30E-02. Sample per second: 53094
# SLIM_BPR_Recommender: Epoch 109 of 150. Elapsed time 18.48 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 4.52E-02. Sample per second: 43378
# SLIM_BPR_Recommender: Epoch 110 of 150. Elapsed time 18.65 sec
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 4.59E-02. Sample per second: 36717
# SLIM_BPR_Recommender: Epoch 111 of 150. Elapsed time 18.83 sec
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 4.41E-02. Sample per second: 132039
# SLIM_BPR_Recommender: Epoch 112 of 150. Elapsed time 19.01 sec
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 4.38E-02. Sample per second: 83869
# SLIM_BPR_Recommender: Epoch 113 of 150. Elapsed time 19.19 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 4.47E-02. Sample per second: 62045
# SLIM_BPR_Recommender: Epoch 114 of 150. Elapsed time 19.36 sec
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 4.43E-02. Sample per second: 48552
# SLIM_BPR_Recommender: Epoch 115 of 150. Elapsed time 19.55 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 4.45E-02. Sample per second: 40029
# SLIM_BPR_Recommender: Epoch 116 of 150. Elapsed time 19.73 sec
# Processed 41629 (100.0%) in 0.20 sec. BPR loss is 4.55E-02. Sample per second: 209033
# SLIM_BPR_Recommender: Epoch 117 of 150. Elapsed time 19.89 sec
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 4.72E-02. Sample per second: 116810
# SLIM_BPR_Recommender: Epoch 118 of 150. Elapsed time 20.05 sec
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 4.48E-02. Sample per second: 80807
# SLIM_BPR_Recommender: Epoch 119 of 150. Elapsed time 20.21 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 4.81E-02. Sample per second: 62235
# SLIM_BPR_Recommender: Epoch 120 of 150. Elapsed time 20.36 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 4.75E-02. Sample per second: 50725
# SLIM_BPR_Recommender: Epoch 121 of 150. Elapsed time 20.51 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 4.41E-02. Sample per second: 42762
# SLIM_BPR_Recommender: Epoch 122 of 150. Elapsed time 20.67 sec
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 4.60E-02. Sample per second: 37057
# SLIM_BPR_Recommender: Epoch 123 of 150. Elapsed time 20.81 sec
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 4.98E-02. Sample per second: 151725
# SLIM_BPR_Recommender: Epoch 124 of 150. Elapsed time 20.97 sec
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 4.82E-02. Sample per second: 98374
# SLIM_BPR_Recommender: Epoch 125 of 150. Elapsed time 21.11 sec
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 4.65E-02. Sample per second: 72845
# SLIM_BPR_Recommender: Epoch 126 of 150. Elapsed time 21.26 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 4.78E-02. Sample per second: 57796
# SLIM_BPR_Recommender: Epoch 127 of 150. Elapsed time 21.41 sec
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 4.69E-02. Sample per second: 47519
# SLIM_BPR_Recommender: Epoch 128 of 150. Elapsed time 21.57 sec
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 4.59E-02. Sample per second: 40521
# SLIM_BPR_Recommender: Epoch 129 of 150. Elapsed time 21.72 sec
# Processed 41629 (100.0%) in 0.18 sec. BPR loss is 4.88E-02. Sample per second: 234416
# SLIM_BPR_Recommender: Epoch 130 of 150. Elapsed time 21.87 sec
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 4.76E-02. Sample per second: 112050
# SLIM_BPR_Recommender: Epoch 131 of 150. Elapsed time 22.06 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 4.87E-02. Sample per second: 63533
# SLIM_BPR_Recommender: Epoch 132 of 150. Elapsed time 22.35 sec
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 4.90E-02. Sample per second: 50374
# SLIM_BPR_Recommender: Epoch 133 of 150. Elapsed time 22.52 sec
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 4.80E-02. Sample per second: 41870
# SLIM_BPR_Recommender: Epoch 134 of 150. Elapsed time 22.69 sec
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 4.98E-02. Sample per second: 36389
# SLIM_BPR_Recommender: Epoch 135 of 150. Elapsed time 22.84 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 4.86E-02. Sample per second: 141214
# SLIM_BPR_Recommender: Epoch 136 of 150. Elapsed time 22.99 sec
# Processed 41629 (100.0%) in 0.44 sec. BPR loss is 5.13E-02. Sample per second: 93578
# SLIM_BPR_Recommender: Epoch 137 of 150. Elapsed time 23.14 sec
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 4.94E-02. Sample per second: 70163
# SLIM_BPR_Recommender: Epoch 138 of 150. Elapsed time 23.29 sec
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 5.02E-02. Sample per second: 56017
# SLIM_BPR_Recommender: Epoch 139 of 150. Elapsed time 23.43 sec
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 5.01E-02. Sample per second: 46491
# SLIM_BPR_Recommender: Epoch 140 of 150. Elapsed time 23.59 sec
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 5.03E-02. Sample per second: 39736
# SLIM_BPR_Recommender: Epoch 141 of 150. Elapsed time 23.74 sec
# Processed 41629 (100.0%) in 0.20 sec. BPR loss is 4.96E-02. Sample per second: 208230
# SLIM_BPR_Recommender: Epoch 142 of 150. Elapsed time 23.89 sec
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 5.06E-02. Sample per second: 114480
# SLIM_BPR_Recommender: Epoch 143 of 150. Elapsed time 24.06 sec
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 5.31E-02. Sample per second: 79690
# SLIM_BPR_Recommender: Epoch 144 of 150. Elapsed time 24.21 sec
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 5.13E-02. Sample per second: 60945
# SLIM_BPR_Recommender: Epoch 145 of 150. Elapsed time 24.37 sec
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 5.14E-02. Sample per second: 49456
# SLIM_BPR_Recommender: Epoch 146 of 150. Elapsed time 24.53 sec
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 5.15E-02. Sample per second: 41856
# SLIM_BPR_Recommender: Epoch 147 of 150. Elapsed time 24.69 sec
# Processed 41629 (100.0%) in 1.16 sec. BPR loss is 5.22E-02. Sample per second: 35728
# SLIM_BPR_Recommender: Epoch 148 of 150. Elapsed time 24.86 sec
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 5.04E-02. Sample per second: 122873
# SLIM_BPR_Recommender: Epoch 149 of 150. Elapsed time 25.03 sec
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 5.17E-02. Sample per second: 81087
# SLIM_BPR_Recommender: Epoch 150 of 150. Elapsed time 25.21 sec
# SLIM_BPR_Recommender: Terminating at epoch 150. Elapsed time 45.76 sec
# Deallocating Cython objects

# %% [markdown]
# ## Submissions

# %%
test_users = pd.read_csv('Dataset\data_target_users_test.csv')
test_users
# Out:
#        user_id
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ...        ...
# 41111    41624
# 41112    41625
# 41113    41626
# 41114    41627
# 41115    41628
#
# [41116 rows x 1 columns]

# %%
user_id = test_users['user_id']
recommendations = []
for user in user_id:
    recommendations.append(recommender.recommend(user, cutoff=10))

# %%
for index in range(len(recommendations)):
    recommendations[index]=np.array(recommendations[index])

test_users['item_list']= recommendations
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])
test_users.to_csv('Submission_10933934.csv', index=False)
