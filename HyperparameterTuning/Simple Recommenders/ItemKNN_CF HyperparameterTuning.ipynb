# %%
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot

from Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Utils.DataReader import load_urm, load_icm, load_target
# Out:
# Cloning into 'Recommender-Systems-Challenge-2022'...
# remote: Enumerating objects: 619, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 619 (delta 107), reused 139 (delta 52), pack-reused 404
# Receiving objects: 100% (619/619), 106.18 MiB | 23.69 MiB/s, done.
# Resolving deltas: 100% (279/279), done.
# Updating files: 100% (254/254), done.

# %% [markdown]
# # Loading Data

# %%
URM_all = load_urm()

URM_train = sps.load_npz('Dataset/Split/URM_train.npz')
URM_test =  sps.load_npz('Dataset/Split/URM_test.npz')
URM_validation = sps.load_npz('Dataset/Split/URM_validation.npz')

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=[10])
# Out:
# Warning: 921 (2.21 %) of 41629 users have no sampled items
# Warning: 1569 (3.77 %) of 41629 users have no sampled items
# EvaluatorHoldout: Ignoring 1569 ( 3.8%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 921 ( 2.2%) Users that have less than 1 test interactions

# %%
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender

recommender_class = ItemKNNCFRecommender

# %%
from skopt.space import Real, Integer, Categorical

hyperparameters_range_dictionary = {
    "topK": Integer(5, 1000),
    "shrink": Integer(0, 1000),
    "similarity": Categorical(["cosine"]),
    "normalize": Categorical([True, False]),
    "feature_weighting": Categorical(["TF-IDF"])
}

# %%
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

hyperparameterSearch = SearchBayesianSkopt(recommender_class, evaluator_validation=evaluator_validation)

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_all],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %%
import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 50
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
# %load_ext Cython

# %%
from Recommenders.Similarity import *

#let's run the bayesian search
hyperparameterSearch.search(recommender_input_args,
                       recommender_input_args_last_test = recommender_input_args_last_test,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 156, 'shrink': 162, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 662.38 column/sec. Elapsed time 37.00 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 58.05 sec. Users per second: 690
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 156, 'shrink': 162, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0286046, PRECISION_RECALL_MIN_DEN: 0.0563436, RECALL: 0.0542709, MAP: 0.0121248, MAP_MIN_DEN: 0.0238903, MRR: 0.0967683, NDCG: 0.0490555, F1: 0.0374634, HIT_RATE: 0.2267099, ARHR_ALL_HITS: 0.1079455, NOVELTY: 0.0037612, AVERAGE_POPULARITY: 0.3780745, DIVERSITY_MEAN_INTER_LIST: 0.6725353, DIVERSITY_HERFINDAHL: 0.9672519, COVERAGE_ITEM: 0.2406659, COVERAGE_ITEM_HIT: 0.0164035, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2181652, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0082787, SHANNON_ENTROPY: 6.3231964, RATIO_DIVERSITY_HERFINDAHL: 0.9675714, RATIO_DIVERSITY_GINI: 0.0163642, RATIO_SHANNON_ENTROPY: 0.4686758, RATIO_AVERAGE_POPULARITY: 7.4737291, RATIO_NOVELTY: 0.2532124,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 95.6046
# Function value obtained: -0.0121
# Current minimum: -0.0121
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 310, 'shrink': 816, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 579.28 column/sec. Elapsed time 42.31 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.07 min. Users per second: 625
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 310, 'shrink': 816, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0277309, PRECISION_RECALL_MIN_DEN: 0.0550533, RECALL: 0.0530819, MAP: 0.0116177, MAP_MIN_DEN: 0.0230977, MRR: 0.0932733, NDCG: 0.0475564, F1: 0.0364301, HIT_RATE: 0.2207688, ARHR_ALL_HITS: 0.1037929, NOVELTY: 0.0036955, AVERAGE_POPULARITY: 0.4017701, DIVERSITY_MEAN_INTER_LIST: 0.6176427, DIVERSITY_HERFINDAHL: 0.9617627, COVERAGE_ITEM: 0.1994124, COVERAGE_ITEM_HIT: 0.0143224, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2124481, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0057235, SHANNON_ENTROPY: 5.9312088, RATIO_DIVERSITY_HERFINDAHL: 0.9620805, RATIO_DIVERSITY_GINI: 0.0113134, RATIO_SHANNON_ENTROPY: 0.4396217, RATIO_AVERAGE_POPULARITY: 7.9421404, RATIO_NOVELTY: 0.2487872,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 106.8846
# Function value obtained: -0.0116
# Current minimum: -0.0121
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 736, 'shrink': 138, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 440.81 column/sec. Elapsed time 55.60 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.08 min. Users per second: 620
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 736, 'shrink': 138, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0376760, PRECISION_RECALL_MIN_DEN: 0.0718512, RECALL: 0.0689560, MAP: 0.0167991, MAP_MIN_DEN: 0.0320576, MRR: 0.1255957, NDCG: 0.0642091, F1: 0.0487281, HIT_RATE: 0.2783075, ARHR_ALL_HITS: 0.1446276, NOVELTY: 0.0042860, AVERAGE_POPULARITY: 0.2259374, DIVERSITY_MEAN_INTER_LIST: 0.9044674, DIVERSITY_HERFINDAHL: 0.9904445, COVERAGE_ITEM: 0.5990941, COVERAGE_ITEM_HIT: 0.0428857, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2678181, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0408225, SHANNON_ENTROPY: 8.6738123, RATIO_DIVERSITY_HERFINDAHL: 0.9907717, RATIO_DIVERSITY_GINI: 0.0806922, RATIO_SHANNON_ENTROPY: 0.6429036, RATIO_AVERAGE_POPULARITY: 4.4663019, RATIO_NOVELTY: 0.2885391,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 120.9096
# Function value obtained: -0.0168
# Current minimum: -0.0168
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 952, 'shrink': 504, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 419.45 column/sec. Elapsed time 58.43 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.16 min. Users per second: 574
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 952, 'shrink': 504, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0375587, PRECISION_RECALL_MIN_DEN: 0.0718898, RECALL: 0.0689893, MAP: 0.0167214, MAP_MIN_DEN: 0.0318754, MRR: 0.1251088, NDCG: 0.0639916, F1: 0.0486381, HIT_RATE: 0.2783325, ARHR_ALL_HITS: 0.1440221, NOVELTY: 0.0042164, AVERAGE_POPULARITY: 0.2360258, DIVERSITY_MEAN_INTER_LIST: 0.8958704, DIVERSITY_HERFINDAHL: 0.9895848, COVERAGE_ITEM: 0.4621945, COVERAGE_ITEM_HIT: 0.0400294, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2678421, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0274269, SHANNON_ENTROPY: 8.3968661, RATIO_DIVERSITY_HERFINDAHL: 0.9899117, RATIO_DIVERSITY_GINI: 0.0542137, RATIO_SHANNON_ENTROPY: 0.6223764, RATIO_AVERAGE_POPULARITY: 4.6657286, RATIO_NOVELTY: 0.2838528,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 129.0794
# Function value obtained: -0.0167
# Current minimum: -0.0168
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 705, 'shrink': 805, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 444.31 column/sec. Elapsed time 55.16 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.10 min. Users per second: 607
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 705, 'shrink': 805, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0376435, PRECISION_RECALL_MIN_DEN: 0.0720264, RECALL: 0.0691316, MAP: 0.0167924, MAP_MIN_DEN: 0.0320139, MRR: 0.1257760, NDCG: 0.0642170, F1: 0.0487446, HIT_RATE: 0.2786820, ARHR_ALL_HITS: 0.1446979, NOVELTY: 0.0041982, AVERAGE_POPULARITY: 0.2365400, DIVERSITY_MEAN_INTER_LIST: 0.8960237, DIVERSITY_HERFINDAHL: 0.9896001, COVERAGE_ITEM: 0.4137593, COVERAGE_ITEM_HIT: 0.0389277, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2681784, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0237085, SHANNON_ENTROPY: 8.3302865, RATIO_DIVERSITY_HERFINDAHL: 0.9899271, RATIO_DIVERSITY_GINI: 0.0468636, RATIO_SHANNON_ENTROPY: 0.6174415, RATIO_AVERAGE_POPULARITY: 4.6758934, RATIO_NOVELTY: 0.2826282,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 121.9269
# Function value obtained: -0.0168
# Current minimum: -0.0168
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 720, 'shrink': 630, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 460.56 column/sec. Elapsed time 53.21 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.22 min. Users per second: 549
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 720, 'shrink': 630, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0268972, PRECISION_RECALL_MIN_DEN: 0.0536921, RECALL: 0.0517984, MAP: 0.0111676, MAP_MIN_DEN: 0.0222736, MRR: 0.0903698, NDCG: 0.0461099, F1: 0.0354081, HIT_RATE: 0.2162257, ARHR_ALL_HITS: 0.1001834, NOVELTY: 0.0036332, AVERAGE_POPULARITY: 0.4239870, DIVERSITY_MEAN_INTER_LIST: 0.5619939, DIVERSITY_HERFINDAHL: 0.9561980, COVERAGE_ITEM: 0.1442853, COVERAGE_ITEM_HIT: 0.0115885, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2080761, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0034972, SHANNON_ENTROPY: 5.5472653, RATIO_DIVERSITY_HERFINDAHL: 0.9565139, RATIO_DIVERSITY_GINI: 0.0069128, RATIO_SHANNON_ENTROPY: 0.4111637, RATIO_AVERAGE_POPULARITY: 8.3813209, RATIO_NOVELTY: 0.2445957,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 126.8696
# Function value obtained: -0.0112
# Current minimum: -0.0168
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 99, 'shrink': 557, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 697.77 column/sec. Elapsed time 35.12 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 34.23 sec. Users per second: 1170
# SearchBayesianSkopt: New best config found. Config 6: {'topK': 99, 'shrink': 557, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0381802, PRECISION_RECALL_MIN_DEN: 0.0727362, RECALL: 0.0697907, MAP: 0.0170626, MAP_MIN_DEN: 0.0326020, MRR: 0.1269211, NDCG: 0.0650830, F1: 0.0493582, HIT_RATE: 0.2805791, ARHR_ALL_HITS: 0.1465432, NOVELTY: 0.0043412, AVERAGE_POPULARITY: 0.1945019, DIVERSITY_MEAN_INTER_LIST: 0.9341960, DIVERSITY_HERFINDAHL: 0.9934173, COVERAGE_ITEM: 0.4208185, COVERAGE_ITEM_HIT: 0.0482311, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2700041, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0290242, SHANNON_ENTROPY: 8.9320913, RATIO_DIVERSITY_HERFINDAHL: 0.9937455, RATIO_DIVERSITY_GINI: 0.0573709, RATIO_SHANNON_ENTROPY: 0.6620473, RATIO_AVERAGE_POPULARITY: 3.8448883, RATIO_NOVELTY: 0.2922538,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 69.6639
# Function value obtained: -0.0171
# Current minimum: -0.0171
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 762, 'shrink': 768, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 457.65 column/sec. Elapsed time 53.55 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.22 min. Users per second: 545
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 762, 'shrink': 768, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0268123, PRECISION_RECALL_MIN_DEN: 0.0535277, RECALL: 0.0516401, MAP: 0.0111417, MAP_MIN_DEN: 0.0222561, MRR: 0.0901800, NDCG: 0.0460222, F1: 0.0352976, HIT_RATE: 0.2156515, ARHR_ALL_HITS: 0.0999576, NOVELTY: 0.0036300, AVERAGE_POPULARITY: 0.4251285, DIVERSITY_MEAN_INTER_LIST: 0.5591213, DIVERSITY_HERFINDAHL: 0.9559107, COVERAGE_ITEM: 0.1413882, COVERAGE_ITEM_HIT: 0.0113845, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2075236, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0033961, SHANNON_ENTROPY: 5.5268319, RATIO_DIVERSITY_HERFINDAHL: 0.9562266, RATIO_DIVERSITY_GINI: 0.0067128, RATIO_SHANNON_ENTROPY: 0.4096492, RATIO_AVERAGE_POPULARITY: 8.4038866, RATIO_NOVELTY: 0.2443755,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 127.7544
# Function value obtained: -0.0111
# Current minimum: -0.0171
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 342, 'shrink': 173, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 577.19 column/sec. Elapsed time 42.46 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.08 min. Users per second: 616
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 342, 'shrink': 173, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0275911, PRECISION_RECALL_MIN_DEN: 0.0548056, RECALL: 0.0528352, MAP: 0.0115635, MAP_MIN_DEN: 0.0230061, MRR: 0.0930027, NDCG: 0.0473670, F1: 0.0362514, HIT_RATE: 0.2200449, ARHR_ALL_HITS: 0.1033989, NOVELTY: 0.0036873, AVERAGE_POPULARITY: 0.4047380, DIVERSITY_MEAN_INTER_LIST: 0.6104613, DIVERSITY_HERFINDAHL: 0.9610446, COVERAGE_ITEM: 0.1925164, COVERAGE_ITEM_HIT: 0.0139144, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2117514, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0054088, SHANNON_ENTROPY: 5.8821739, RATIO_DIVERSITY_HERFINDAHL: 0.9613621, RATIO_DIVERSITY_GINI: 0.0106914, RATIO_SHANNON_ENTROPY: 0.4359872, RATIO_AVERAGE_POPULARITY: 8.0008096, RATIO_NOVELTY: 0.2482379,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 108.0038
# Function value obtained: -0.0116
# Current minimum: -0.0171
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 917, 'shrink': 495, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 433.46 column/sec. Elapsed time 56.54 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.24 min. Users per second: 536
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 917, 'shrink': 495, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0266725, PRECISION_RECALL_MIN_DEN: 0.0532561, RECALL: 0.0513773, MAP: 0.0110663, MAP_MIN_DEN: 0.0220635, MRR: 0.0896106, NDCG: 0.0457209, F1: 0.0351150, HIT_RATE: 0.2147029, ARHR_ALL_HITS: 0.0993109, NOVELTY: 0.0036197, AVERAGE_POPULARITY: 0.4285367, DIVERSITY_MEAN_INTER_LIST: 0.5502756, DIVERSITY_HERFINDAHL: 0.9550262, COVERAGE_ITEM: 0.1283715, COVERAGE_ITEM_HIT: 0.0108948, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2066108, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0030362, SHANNON_ENTROPY: 5.4616164, RATIO_DIVERSITY_HERFINDAHL: 0.9553417, RATIO_DIVERSITY_GINI: 0.0060015, RATIO_SHANNON_ENTROPY: 0.4048154, RATIO_AVERAGE_POPULARITY: 8.4712597, RATIO_NOVELTY: 0.2436858,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 132.0180
# Function value obtained: -0.0111
# Current minimum: -0.0171
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 145, 'shrink': 495, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 699.18 column/sec. Elapsed time 35.05 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 57.63 sec. Users per second: 695
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'topK': 145, 'shrink': 495, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0286370, PRECISION_RECALL_MIN_DEN: 0.0563444, RECALL: 0.0542672, MAP: 0.0121555, MAP_MIN_DEN: 0.0239012, MRR: 0.0969895, NDCG: 0.0490990, F1: 0.0374903, HIT_RATE: 0.2269346, ARHR_ALL_HITS: 0.1082062, NOVELTY: 0.0037697, AVERAGE_POPULARITY: 0.3749149, DIVERSITY_MEAN_INTER_LIST: 0.6794696, DIVERSITY_HERFINDAHL: 0.9679453, COVERAGE_ITEM: 0.2446240, COVERAGE_ITEM_HIT: 0.0168115, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2183814, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0086001, SHANNON_ENTROPY: 6.3716909, RATIO_DIVERSITY_HERFINDAHL: 0.9682651, RATIO_DIVERSITY_GINI: 0.0169996, RATIO_SHANNON_ENTROPY: 0.4722702, RATIO_AVERAGE_POPULARITY: 7.4112712, RATIO_NOVELTY: 0.2537809,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 93.0279
# Function value obtained: -0.0122
# Current minimum: -0.0171
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 909, 'shrink': 276, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 435.37 column/sec. Elapsed time 56.29 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.25 min. Users per second: 536
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'topK': 909, 'shrink': 276, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0266600, PRECISION_RECALL_MIN_DEN: 0.0532376, RECALL: 0.0513606, MAP: 0.0110647, MAP_MIN_DEN: 0.0220616, MRR: 0.0895901, NDCG: 0.0457102, F1: 0.0351003, HIT_RATE: 0.2146031, ARHR_ALL_HITS: 0.0992914, NOVELTY: 0.0036202, AVERAGE_POPULARITY: 0.4284019, DIVERSITY_MEAN_INTER_LIST: 0.5505812, DIVERSITY_HERFINDAHL: 0.9550567, COVERAGE_ITEM: 0.1293100, COVERAGE_ITEM_HIT: 0.0109357, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2065147, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0030565, SHANNON_ENTROPY: 5.4645011, RATIO_DIVERSITY_HERFINDAHL: 0.9553723, RATIO_DIVERSITY_GINI: 0.0060418, RATIO_SHANNON_ENTROPY: 0.4050293, RATIO_AVERAGE_POPULARITY: 8.4685948, RATIO_NOVELTY: 0.2437155,
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 131.8640
# Function value obtained: -0.0111
# Current minimum: -0.0171
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 947, 'shrink': 447, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 417.74 column/sec. Elapsed time 58.67 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.16 min. Users per second: 574
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'topK': 947, 'shrink': 447, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0375512, PRECISION_RECALL_MIN_DEN: 0.0718446, RECALL: 0.0689457, MAP: 0.0167307, MAP_MIN_DEN: 0.0318828, MRR: 0.1252269, NDCG: 0.0640000, F1: 0.0486210, HIT_RATE: 0.2781078, ARHR_ALL_HITS: 0.1441197, NOVELTY: 0.0042239, AVERAGE_POPULARITY: 0.2350066, DIVERSITY_MEAN_INTER_LIST: 0.8967207, DIVERSITY_HERFINDAHL: 0.9896698, COVERAGE_ITEM: 0.4799853, COVERAGE_ITEM_HIT: 0.0404782, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2676259, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0288035, SHANNON_ENTROPY: 8.4272141, RATIO_DIVERSITY_HERFINDAHL: 0.9899968, RATIO_DIVERSITY_GINI: 0.0569347, RATIO_SHANNON_ENTROPY: 0.6246258, RATIO_AVERAGE_POPULARITY: 4.6455816, RATIO_NOVELTY: 0.2843600,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 129.2516
# Function value obtained: -0.0167
# Current minimum: -0.0171
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 894, 'shrink': 968, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 445.22 column/sec. Elapsed time 55.05 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.25 min. Users per second: 536
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'topK': 894, 'shrink': 968, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0266725, PRECISION_RECALL_MIN_DEN: 0.0532715, RECALL: 0.0513962, MAP: 0.0110771, MAP_MIN_DEN: 0.0220932, MRR: 0.0897013, NDCG: 0.0457568, F1: 0.0351195, HIT_RATE: 0.2147279, ARHR_ALL_HITS: 0.0994066, NOVELTY: 0.0036209, AVERAGE_POPULARITY: 0.4281359, DIVERSITY_MEAN_INTER_LIST: 0.5512952, DIVERSITY_HERFINDAHL: 0.9551281, COVERAGE_ITEM: 0.1304525, COVERAGE_ITEM_HIT: 0.0109765, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2066348, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0030844, SHANNON_ENTROPY: 5.4698931, RATIO_DIVERSITY_HERFINDAHL: 0.9554437, RATIO_DIVERSITY_GINI: 0.0060968, RATIO_SHANNON_ENTROPY: 0.4054289, RATIO_AVERAGE_POPULARITY: 8.4633360, RATIO_NOVELTY: 0.2437680,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 130.6023
# Function value obtained: -0.0111
# Current minimum: -0.0171
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 237, 'shrink': 260, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 634.37 column/sec. Elapsed time 38.63 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.02 min. Users per second: 652
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'topK': 237, 'shrink': 260, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0280604, PRECISION_RECALL_MIN_DEN: 0.0555981, RECALL: 0.0535997, MAP: 0.0118188, MAP_MIN_DEN: 0.0234528, MRR: 0.0948479, NDCG: 0.0482084, F1: 0.0368363, HIT_RATE: 0.2234898, ARHR_ALL_HITS: 0.1055490, NOVELTY: 0.0037190, AVERAGE_POPULARITY: 0.3933492, DIVERSITY_MEAN_INTER_LIST: 0.6379457, DIVERSITY_HERFINDAHL: 0.9637930, COVERAGE_ITEM: 0.2146326, COVERAGE_ITEM_HIT: 0.0150977, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2150664, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0066101, SHANNON_ENTROPY: 6.0741225, RATIO_DIVERSITY_HERFINDAHL: 0.9641114, RATIO_DIVERSITY_GINI: 0.0130658, RATIO_SHANNON_ENTROPY: 0.4502144, RATIO_AVERAGE_POPULARITY: 7.7756781, RATIO_NOVELTY: 0.2503690,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 101.0809
# Function value obtained: -0.0118
# Current minimum: -0.0171
# Iteration No: 16 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 99, 'shrink': 148, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 702.29 column/sec. Elapsed time 34.90 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 33.38 sec. Users per second: 1200
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'topK': 99, 'shrink': 148, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0381977, PRECISION_RECALL_MIN_DEN: 0.0726475, RECALL: 0.0697185, MAP: 0.0170291, MAP_MIN_DEN: 0.0324514, MRR: 0.1265683, NDCG: 0.0649289, F1: 0.0493547, HIT_RATE: 0.2810784, ARHR_ALL_HITS: 0.1462228, NOVELTY: 0.0043978, AVERAGE_POPULARITY: 0.1885787, DIVERSITY_MEAN_INTER_LIST: 0.9377548, DIVERSITY_HERFINDAHL: 0.9937731, COVERAGE_ITEM: 0.5250745, COVERAGE_ITEM_HIT: 0.0504346, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2704845, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0390072, SHANNON_ENTROPY: 9.1401465, RATIO_DIVERSITY_HERFINDAHL: 0.9941015, RATIO_DIVERSITY_GINI: 0.0771039, RATIO_SHANNON_ENTROPY: 0.6774684, RATIO_AVERAGE_POPULARITY: 3.7277998, RATIO_NOVELTY: 0.2960661,
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 69.2420
# Function value obtained: -0.0170
# Current minimum: -0.0171
# Iteration No: 17 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 936, 'shrink': 101, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 436.30 column/sec. Elapsed time 56.17 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.25 min. Users per second: 536
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'topK': 936, 'shrink': 101, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0266650, PRECISION_RECALL_MIN_DEN: 0.0532416, RECALL: 0.0513662, MAP: 0.0110625, MAP_MIN_DEN: 0.0220554, MRR: 0.0895796, NDCG: 0.0457083, F1: 0.0351060, HIT_RATE: 0.2146281, ARHR_ALL_HITS: 0.0992761, NOVELTY: 0.0036186, AVERAGE_POPULARITY: 0.4288972, DIVERSITY_MEAN_INTER_LIST: 0.5493550, DIVERSITY_HERFINDAHL: 0.9549341, COVERAGE_ITEM: 0.1266985, COVERAGE_ITEM_HIT: 0.0107724, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2065387, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0029916, SHANNON_ENTROPY: 5.4543955, RATIO_DIVERSITY_HERFINDAHL: 0.9552496, RATIO_DIVERSITY_GINI: 0.0059134, RATIO_SHANNON_ENTROPY: 0.4042802, RATIO_AVERAGE_POPULARITY: 8.4783861, RATIO_NOVELTY: 0.2436081,
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 132.4034
# Function value obtained: -0.0111
# Current minimum: -0.0171
# Iteration No: 18 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 34, 'shrink': 844, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 778.88 column/sec. Elapsed time 31.46 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 48.82 sec. Users per second: 821
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'topK': 34, 'shrink': 844, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0301523, PRECISION_RECALL_MIN_DEN: 0.0586525, RECALL: 0.0564251, MAP: 0.0129268, MAP_MIN_DEN: 0.0252087, MRR: 0.1017580, NDCG: 0.0515052, F1: 0.0393023, HIT_RATE: 0.2351972, ARHR_ALL_HITS: 0.1143061, NOVELTY: 0.0039526, AVERAGE_POPULARITY: 0.3114799, DIVERSITY_MEAN_INTER_LIST: 0.8017842, DIVERSITY_HERFINDAHL: 0.9801764, COVERAGE_ITEM: 0.3729547, COVERAGE_ITEM_HIT: 0.0228914, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2263326, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0191046, SHANNON_ENTROPY: 7.3949918, RATIO_DIVERSITY_HERFINDAHL: 0.9805003, RATIO_DIVERSITY_GINI: 0.0377634, RATIO_SHANNON_ENTROPY: 0.5481174, RATIO_AVERAGE_POPULARITY: 6.1572959, RATIO_NOVELTY: 0.2660920,
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 81.2627
# Function value obtained: -0.0129
# Current minimum: -0.0171
# Iteration No: 19 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 754.21 column/sec. Elapsed time 32.49 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 28.49 sec. Users per second: 1406
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'topK': 5, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0341862, PRECISION_RECALL_MIN_DEN: 0.0648303, RECALL: 0.0622215, MAP: 0.0149835, MAP_MIN_DEN: 0.0286215, MRR: 0.1149038, NDCG: 0.0580017, F1: 0.0441275, HIT_RATE: 0.2599601, ARHR_ALL_HITS: 0.1308190, NOVELTY: 0.0045625, AVERAGE_POPULARITY: 0.1463826, DIVERSITY_MEAN_INTER_LIST: 0.9660963, DIVERSITY_HERFINDAHL: 0.9966072, COVERAGE_ITEM: 0.4950014, COVERAGE_ITEM_HIT: 0.0570857, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2501621, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0495093, SHANNON_ENTROPY: 9.9042389, RATIO_DIVERSITY_HERFINDAHL: 0.9969365, RATIO_DIVERSITY_GINI: 0.0978631, RATIO_SHANNON_ENTROPY: 0.7341030, RATIO_AVERAGE_POPULARITY: 2.8936719, RATIO_NOVELTY: 0.3071563,
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 61.9632
# Function value obtained: -0.0150
# Current minimum: -0.0171
# Iteration No: 20 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 372, 'shrink': 153, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 547.74 column/sec. Elapsed time 44.74 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 47.98 sec. Users per second: 835
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'topK': 372, 'shrink': 153, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0380055, PRECISION_RECALL_MIN_DEN: 0.0724482, RECALL: 0.0694891, MAP: 0.0169384, MAP_MIN_DEN: 0.0322504, MRR: 0.1260996, NDCG: 0.0646439, F1: 0.0491367, HIT_RATE: 0.2798053, ARHR_ALL_HITS: 0.1455005, NOVELTY: 0.0043164, AVERAGE_POPULARITY: 0.2157114, DIVERSITY_MEAN_INTER_LIST: 0.9141459, DIVERSITY_HERFINDAHL: 0.9914123, COVERAGE_ITEM: 0.5992574, COVERAGE_ITEM_HIT: 0.0456196, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2692594, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0417209, SHANNON_ENTROPY: 8.8063550, RATIO_DIVERSITY_HERFINDAHL: 0.9917399, RATIO_DIVERSITY_GINI: 0.0824679, RATIO_SHANNON_ENTROPY: 0.6527277, RATIO_AVERAGE_POPULARITY: 4.2641554, RATIO_NOVELTY: 0.2905854,
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 93.9546
# Function value obtained: -0.0169
# Current minimum: -0.0171
# Iteration No: 21 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 219, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 622.59 column/sec. Elapsed time 39.36 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 40.98 sec. Users per second: 977
# SearchBayesianSkopt: New best config found. Config 20: {'topK': 219, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0382052, PRECISION_RECALL_MIN_DEN: 0.0729457, RECALL: 0.0699851, MAP: 0.0170878, MAP_MIN_DEN: 0.0325389, MRR: 0.1272729, NDCG: 0.0651292, F1: 0.0494276, HIT_RATE: 0.2816775, ARHR_ALL_HITS: 0.1468454, NOVELTY: 0.0042522, AVERAGE_POPULARITY: 0.2159874, DIVERSITY_MEAN_INTER_LIST: 0.9164485, DIVERSITY_HERFINDAHL: 0.9916426, COVERAGE_ITEM: 0.3871139, COVERAGE_ITEM_HIT: 0.0430897, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2710610, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0236063, SHANNON_ENTROPY: 8.5714724, RATIO_DIVERSITY_HERFINDAHL: 0.9919702, RATIO_DIVERSITY_GINI: 0.0466616, RATIO_SHANNON_ENTROPY: 0.6353182, RATIO_AVERAGE_POPULARITY: 4.2696113, RATIO_NOVELTY: 0.2862679,
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 81.4571
# Function value obtained: -0.0171
# Current minimum: -0.0171
# Iteration No: 22 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 523, 'shrink': 15, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 478.04 column/sec. Elapsed time 51.27 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 56.51 sec. Users per second: 709
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'topK': 523, 'shrink': 15, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0378108, PRECISION_RECALL_MIN_DEN: 0.0719004, RECALL: 0.0689662, MAP: 0.0168499, MAP_MIN_DEN: 0.0320310, MRR: 0.1258037, NDCG: 0.0642749, F1: 0.0488432, HIT_RATE: 0.2791812, ARHR_ALL_HITS: 0.1449647, NOVELTY: 0.0043315, AVERAGE_POPULARITY: 0.2183386, DIVERSITY_MEAN_INTER_LIST: 0.9109852, DIVERSITY_HERFINDAHL: 0.9910962, COVERAGE_ITEM: 0.6491207, COVERAGE_ITEM_HIT: 0.0447627, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2686589, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0487862, SHANNON_ENTROPY: 8.8505050, RATIO_DIVERSITY_HERFINDAHL: 0.9914237, RATIO_DIVERSITY_GINI: 0.0964336, RATIO_SHANNON_ENTROPY: 0.6560001, RATIO_AVERAGE_POPULARITY: 4.3160898, RATIO_NOVELTY: 0.2916037,
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 109.1743
# Function value obtained: -0.0168
# Current minimum: -0.0171
# Iteration No: 23 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 531, 'shrink': 959, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 517.34 column/sec. Elapsed time 47.37 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.17 min. Users per second: 571
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'topK': 531, 'shrink': 959, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0271268, PRECISION_RECALL_MIN_DEN: 0.0540523, RECALL: 0.0521361, MAP: 0.0113160, MAP_MIN_DEN: 0.0225496, MRR: 0.0913921, NDCG: 0.0465705, F1: 0.0356859, HIT_RATE: 0.2174988, ARHR_ALL_HITS: 0.1014104, NOVELTY: 0.0036530, AVERAGE_POPULARITY: 0.4171739, DIVERSITY_MEAN_INTER_LIST: 0.5793390, DIVERSITY_HERFINDAHL: 0.9579325, COVERAGE_ITEM: 0.1651365, COVERAGE_ITEM_HIT: 0.0122414, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2093012, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0041976, SHANNON_ENTROPY: 5.6698008, RATIO_DIVERSITY_HERFINDAHL: 0.9582489, RATIO_DIVERSITY_GINI: 0.0082973, RATIO_SHANNON_ENTROPY: 0.4202461, RATIO_AVERAGE_POPULARITY: 8.2466415, RATIO_NOVELTY: 0.2459258,
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 119.0931
# Function value obtained: -0.0113
# Current minimum: -0.0171
# Iteration No: 24 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 152, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 669.31 column/sec. Elapsed time 36.62 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 37.39 sec. Users per second: 1071
# SearchBayesianSkopt: New best config found. Config 23: {'topK': 152, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0382227, PRECISION_RECALL_MIN_DEN: 0.0728840, RECALL: 0.0699634, MAP: 0.0172084, MAP_MIN_DEN: 0.0327950, MRR: 0.1283851, NDCG: 0.0654302, F1: 0.0494368, HIT_RATE: 0.2816276, ARHR_ALL_HITS: 0.1479967, NOVELTY: 0.0042762, AVERAGE_POPULARITY: 0.2082425, DIVERSITY_MEAN_INTER_LIST: 0.9235414, DIVERSITY_HERFINDAHL: 0.9923518, COVERAGE_ITEM: 0.3729139, COVERAGE_ITEM_HIT: 0.0447219, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2710130, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0238617, SHANNON_ENTROPY: 8.6741722, RATIO_DIVERSITY_HERFINDAHL: 0.9926797, RATIO_DIVERSITY_GINI: 0.0471664, RATIO_SHANNON_ENTROPY: 0.6429303, RATIO_AVERAGE_POPULARITY: 4.1165113, RATIO_NOVELTY: 0.2878794,
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 75.1222
# Function value obtained: -0.0172
# Current minimum: -0.0172
# Iteration No: 25 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 133, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 685.27 column/sec. Elapsed time 35.76 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 36.93 sec. Users per second: 1085
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'topK': 133, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0382351, PRECISION_RECALL_MIN_DEN: 0.0728172, RECALL: 0.0698909, MAP: 0.0171723, MAP_MIN_DEN: 0.0327080, MRR: 0.1279750, NDCG: 0.0653189, F1: 0.0494292, HIT_RATE: 0.2813280, ARHR_ALL_HITS: 0.1476265, NOVELTY: 0.0042846, AVERAGE_POPULARITY: 0.2055541, DIVERSITY_MEAN_INTER_LIST: 0.9259338, DIVERSITY_HERFINDAHL: 0.9925911, COVERAGE_ITEM: 0.3656914, COVERAGE_ITEM_HIT: 0.0452524, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2707247, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0238850, SHANNON_ENTROPY: 8.7104013, RATIO_DIVERSITY_HERFINDAHL: 0.9929190, RATIO_DIVERSITY_GINI: 0.0472125, RATIO_SHANNON_ENTROPY: 0.6456156, RATIO_AVERAGE_POPULARITY: 4.0633674, RATIO_NOVELTY: 0.2884476,
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 73.8209
# Function value obtained: -0.0172
# Current minimum: -0.0172
# Iteration No: 26 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 169, 'shrink': 0, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 643.75 column/sec. Elapsed time 38.07 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 35.83 sec. Users per second: 1118
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'topK': 169, 'shrink': 0, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0382027, PRECISION_RECALL_MIN_DEN: 0.0725412, RECALL: 0.0695956, MAP: 0.0171204, MAP_MIN_DEN: 0.0325460, MRR: 0.1274941, NDCG: 0.0650700, F1: 0.0493280, HIT_RATE: 0.2811533, ARHR_ALL_HITS: 0.1471105, NOVELTY: 0.0044005, AVERAGE_POPULARITY: 0.1960224, DIVERSITY_MEAN_INTER_LIST: 0.9312376, DIVERSITY_HERFINDAHL: 0.9931214, COVERAGE_ITEM: 0.5958298, COVERAGE_ITEM_HIT: 0.0491288, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2705566, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0468468, SHANNON_ENTROPY: 9.1328214, RATIO_DIVERSITY_HERFINDAHL: 0.9934495, RATIO_DIVERSITY_GINI: 0.0926001, RATIO_SHANNON_ENTROPY: 0.6769254, RATIO_AVERAGE_POPULARITY: 3.8749469, RATIO_NOVELTY: 0.2962465,
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 75.0628
# Function value obtained: -0.0171
# Current minimum: -0.0172
# Iteration No: 27 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 451, 'shrink': 12, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 508.80 column/sec. Elapsed time 48.17 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 52.33 sec. Users per second: 766
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'topK': 451, 'shrink': 12, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0378782, PRECISION_RECALL_MIN_DEN: 0.0720737, RECALL: 0.0691092, MAP: 0.0168485, MAP_MIN_DEN: 0.0320773, MRR: 0.1256449, NDCG: 0.0643413, F1: 0.0489353, HIT_RATE: 0.2792312, ARHR_ALL_HITS: 0.1448529, NOVELTY: 0.0043395, AVERAGE_POPULARITY: 0.2159207, DIVERSITY_MEAN_INTER_LIST: 0.9132529, DIVERSITY_HERFINDAHL: 0.9913230, COVERAGE_ITEM: 0.6479373, COVERAGE_ITEM_HIT: 0.0453748, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2687069, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0491531, SHANNON_ENTROPY: 8.8848294, RATIO_DIVERSITY_HERFINDAHL: 0.9916505, RATIO_DIVERSITY_GINI: 0.0971589, RATIO_SHANNON_ENTROPY: 0.6585443, RATIO_AVERAGE_POPULARITY: 4.2682931, RATIO_NOVELTY: 0.2921435,
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 101.8366
# Function value obtained: -0.0168
# Current minimum: -0.0172
# Iteration No: 28 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 455, 'shrink': 351, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 526.01 column/sec. Elapsed time 46.59 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.14 min. Users per second: 585
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'topK': 455, 'shrink': 351, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0273215, PRECISION_RECALL_MIN_DEN: 0.0543713, RECALL: 0.0524467, MAP: 0.0114055, MAP_MIN_DEN: 0.0226859, MRR: 0.0919473, NDCG: 0.0468526, F1: 0.0359272, HIT_RATE: 0.2184473, ARHR_ALL_HITS: 0.1021082, NOVELTY: 0.0036649, AVERAGE_POPULARITY: 0.4129329, DIVERSITY_MEAN_INTER_LIST: 0.5898976, DIVERSITY_HERFINDAHL: 0.9589883, COVERAGE_ITEM: 0.1756641, COVERAGE_ITEM_HIT: 0.0127311, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2102140, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0046171, SHANNON_ENTROPY: 5.7433992, RATIO_DIVERSITY_HERFINDAHL: 0.9593051, RATIO_DIVERSITY_GINI: 0.0091265, RATIO_SHANNON_ENTROPY: 0.4257012, RATIO_AVERAGE_POPULARITY: 8.1628060, RATIO_NOVELTY: 0.2467263,
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 116.4038
# Function value obtained: -0.0114
# Current minimum: -0.0172
# Iteration No: 29 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 163, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 650.45 column/sec. Elapsed time 37.68 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 38.33 sec. Users per second: 1045
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'topK': 163, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0382751, PRECISION_RECALL_MIN_DEN: 0.0730630, RECALL: 0.0701230, MAP: 0.0171493, MAP_MIN_DEN: 0.0327269, MRR: 0.1279168, NDCG: 0.0653832, F1: 0.0495205, HIT_RATE: 0.2824264, ARHR_ALL_HITS: 0.1474595, NOVELTY: 0.0042718, AVERAGE_POPULARITY: 0.2096862, DIVERSITY_MEAN_INTER_LIST: 0.9223839, DIVERSITY_HERFINDAHL: 0.9922361, COVERAGE_ITEM: 0.3764639, COVERAGE_ITEM_HIT: 0.0443547, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2717817, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0238642, SHANNON_ENTROPY: 8.6573446, RATIO_DIVERSITY_HERFINDAHL: 0.9925639, RATIO_DIVERSITY_GINI: 0.0471714, RATIO_SHANNON_ENTROPY: 0.6416831, RATIO_AVERAGE_POPULARITY: 4.1450498, RATIO_NOVELTY: 0.2875838,
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 77.1876
# Function value obtained: -0.0171
# Current minimum: -0.0172
# Iteration No: 30 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 650, 'shrink': 712, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 475.01 column/sec. Elapsed time 51.59 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.21 min. Users per second: 553
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'topK': 650, 'shrink': 712, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0269945, PRECISION_RECALL_MIN_DEN: 0.0538805, RECALL: 0.0519760, MAP: 0.0112198, MAP_MIN_DEN: 0.0223712, MRR: 0.0907712, NDCG: 0.0462958, F1: 0.0355339, HIT_RATE: 0.2168497, ARHR_ALL_HITS: 0.1006368, NOVELTY: 0.0036397, AVERAGE_POPULARITY: 0.4217505, DIVERSITY_MEAN_INTER_LIST: 0.5677379, DIVERSITY_HERFINDAHL: 0.9567724, COVERAGE_ITEM: 0.1520790, COVERAGE_ITEM_HIT: 0.0117517, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2086766, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0037255, SHANNON_ENTROPY: 5.5875668, RATIO_DIVERSITY_HERFINDAHL: 0.9570885, RATIO_DIVERSITY_GINI: 0.0073640, RATIO_SHANNON_ENTROPY: 0.4141509, RATIO_AVERAGE_POPULARITY: 8.3371100, RATIO_NOVELTY: 0.2450330,
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 125.4675
# Function value obtained: -0.0112
# Current minimum: -0.0172
# Iteration No: 31 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 289, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 594.91 column/sec. Elapsed time 41.19 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 45.80 sec. Users per second: 875
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'topK': 289, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0380155, PRECISION_RECALL_MIN_DEN: 0.0726832, RECALL: 0.0697461, MAP: 0.0170108, MAP_MIN_DEN: 0.0324523, MRR: 0.1269526, NDCG: 0.0649307, F1: 0.0492092, HIT_RATE: 0.2813530, ARHR_ALL_HITS: 0.1463187, NOVELTY: 0.0042330, AVERAGE_POPULARITY: 0.2227207, DIVERSITY_MEAN_INTER_LIST: 0.9100339, DIVERSITY_HERFINDAHL: 0.9910011, COVERAGE_ITEM: 0.3971518, COVERAGE_ITEM_HIT: 0.0418656, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2707488, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0235122, SHANNON_ENTROPY: 8.4892544, RATIO_DIVERSITY_HERFINDAHL: 0.9913285, RATIO_DIVERSITY_GINI: 0.0464756, RATIO_SHANNON_ENTROPY: 0.6292242, RATIO_AVERAGE_POPULARITY: 4.4027146, RATIO_NOVELTY: 0.2849736,
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 88.2514
# Function value obtained: -0.0170
# Current minimum: -0.0172
# Iteration No: 32 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 336, 'shrink': 354, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 582.81 column/sec. Elapsed time 42.05 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.06 min. Users per second: 627
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'topK': 336, 'shrink': 354, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0275936, PRECISION_RECALL_MIN_DEN: 0.0548379, RECALL: 0.0528734, MAP: 0.0115702, MAP_MIN_DEN: 0.0230251, MRR: 0.0930378, NDCG: 0.0473943, F1: 0.0362625, HIT_RATE: 0.2200200, ARHR_ALL_HITS: 0.1034504, NOVELTY: 0.0036887, AVERAGE_POPULARITY: 0.4042368, DIVERSITY_MEAN_INTER_LIST: 0.6117118, DIVERSITY_HERFINDAHL: 0.9611696, COVERAGE_ITEM: 0.1938222, COVERAGE_ITEM_HIT: 0.0139552, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2117274, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0054635, SHANNON_ENTROPY: 5.8903099, RATIO_DIVERSITY_HERFINDAHL: 0.9614872, RATIO_DIVERSITY_GINI: 0.0107996, RATIO_SHANNON_ENTROPY: 0.4365902, RATIO_AVERAGE_POPULARITY: 7.9909023, RATIO_NOVELTY: 0.2483284,
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 107.5455
# Function value obtained: -0.0116
# Current minimum: -0.0172
# Iteration No: 33 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 385, 'shrink': 415, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 564.33 column/sec. Elapsed time 43.43 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.11 min. Users per second: 603
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'topK': 385, 'shrink': 415, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0275137, PRECISION_RECALL_MIN_DEN: 0.0546505, RECALL: 0.0526940, MAP: 0.0114939, MAP_MIN_DEN: 0.0228649, MRR: 0.0924391, NDCG: 0.0471481, F1: 0.0361513, HIT_RATE: 0.2196955, ARHR_ALL_HITS: 0.1027746, NOVELTY: 0.0036779, AVERAGE_POPULARITY: 0.4082126, DIVERSITY_MEAN_INTER_LIST: 0.6017692, DIVERSITY_HERFINDAHL: 0.9601754, COVERAGE_ITEM: 0.1857837, COVERAGE_ITEM_HIT: 0.0132615, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2114151, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0050758, SHANNON_ENTROPY: 5.8244048, RATIO_DIVERSITY_HERFINDAHL: 0.9604926, RATIO_DIVERSITY_GINI: 0.0100331, RATIO_SHANNON_ENTROPY: 0.4317053, RATIO_AVERAGE_POPULARITY: 8.0694960, RATIO_NOVELTY: 0.2476013,
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 111.3866
# Function value obtained: -0.0115
# Current minimum: -0.0172
# Iteration No: 34 started. Searching for the next optimal point.
# ...
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 120.0963
# Function value obtained: -0.0113
# Current minimum: -0.0172
# Iteration No: 41 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 918, 'shrink': 621, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 402.96 column/sec. Elapsed time 1.01 min
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.16 min. Users per second: 574
# SearchBayesianSkopt: Config 40 is suboptimal. Config: {'topK': 918, 'shrink': 621, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0375562, PRECISION_RECALL_MIN_DEN: 0.0718391, RECALL: 0.0689242, MAP: 0.0167310, MAP_MIN_DEN: 0.0318792, MRR: 0.1251797, NDCG: 0.0639817, F1: 0.0486198, HIT_RATE: 0.2781827, ARHR_ALL_HITS: 0.1440725, NOVELTY: 0.0042045, AVERAGE_POPULARITY: 0.2374096, DIVERSITY_MEAN_INTER_LIST: 0.8947676, DIVERSITY_HERFINDAHL: 0.9894745, COVERAGE_ITEM: 0.4358755, COVERAGE_ITEM_HIT: 0.0391725, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2676980, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0254009, SHANNON_ENTROPY: 8.3502556, RATIO_DIVERSITY_HERFINDAHL: 0.9898014, RATIO_DIVERSITY_GINI: 0.0502089, RATIO_SHANNON_ENTROPY: 0.6189216, RATIO_AVERAGE_POPULARITY: 4.6930835, RATIO_NOVELTY: 0.2830521,
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 132.4574
# Function value obtained: -0.0167
# Current minimum: -0.0172
# Iteration No: 42 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 138, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 658.45 column/sec. Elapsed time 37.22 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 37.22 sec. Users per second: 1076
# SearchBayesianSkopt: New best config found. Config 41: {'topK': 138, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0382027, PRECISION_RECALL_MIN_DEN: 0.0727093, RECALL: 0.0697743, MAP: 0.0172102, MAP_MIN_DEN: 0.0327575, MRR: 0.1281427, NDCG: 0.0653450, F1: 0.0493729, HIT_RATE: 0.2808787, ARHR_ALL_HITS: 0.1478961, NOVELTY: 0.0042825, AVERAGE_POPULARITY: 0.2061592, DIVERSITY_MEAN_INTER_LIST: 0.9255210, DIVERSITY_HERFINDAHL: 0.9925498, COVERAGE_ITEM: 0.3665483, COVERAGE_ITEM_HIT: 0.0450075, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2702923, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0238368, SHANNON_ENTROPY: 8.7018217, RATIO_DIVERSITY_HERFINDAHL: 0.9928777, RATIO_DIVERSITY_GINI: 0.0471172, RATIO_SHANNON_ENTROPY: 0.6449797, RATIO_AVERAGE_POPULARITY: 4.0753288, RATIO_NOVELTY: 0.2883074,
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 75.9066
# Function value obtained: -0.0172
# Current minimum: -0.0172
# Iteration No: 43 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 137, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# SearchBayesianSkopt: Config 42 was already explored at index 38. Config: {'topK': 137, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0381777, PRECISION_RECALL_MIN_DEN: 0.0726683, RECALL: 0.0697422, MAP: 0.0171831, MAP_MIN_DEN: 0.0327350, MRR: 0.1280356, NDCG: 0.0653007, F1: 0.0493440, HIT_RATE: 0.2809286, ARHR_ALL_HITS: 0.1477141, NOVELTY: 0.0042830, AVERAGE_POPULARITY: 0.2060262, DIVERSITY_MEAN_INTER_LIST: 0.9255719, DIVERSITY_HERFINDAHL: 0.9925549, COVERAGE_ITEM: 0.3665483, COVERAGE_ITEM_HIT: 0.0450075, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2703404, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0238563, SHANNON_ENTROPY: 8.7036685, RATIO_DIVERSITY_HERFINDAHL: 0.9928828, RATIO_DIVERSITY_GINI: 0.0471558, RATIO_SHANNON_ENTROPY: 0.6451166, RATIO_AVERAGE_POPULARITY: 4.0727001, RATIO_NOVELTY: 0.2883416,
# /opt/conda/lib/python3.7/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 1.2565
# Function value obtained: -0.0172
# Current minimum: -0.0172
# Iteration No: 44 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 923, 'shrink': 967, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 407.14 column/sec. Elapsed time 1.00 min
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.17 min. Users per second: 570
# SearchBayesianSkopt: Config 43 is suboptimal. Config: {'topK': 923, 'shrink': 967, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0375462, PRECISION_RECALL_MIN_DEN: 0.0718861, RECALL: 0.0689683, MAP: 0.0166930, MAP_MIN_DEN: 0.0318142, MRR: 0.1249875, NDCG: 0.0639184, F1: 0.0486224, HIT_RATE: 0.2784324, ARHR_ALL_HITS: 0.1438004, NOVELTY: 0.0041723, AVERAGE_POPULARITY: 0.2422863, DIVERSITY_MEAN_INTER_LIST: 0.8905340, DIVERSITY_HERFINDAHL: 0.9890512, COVERAGE_ITEM: 0.3712817, COVERAGE_ITEM_HIT: 0.0375811, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2679382, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0208974, SHANNON_ENTROPY: 8.2196870, RATIO_DIVERSITY_HERFINDAHL: 0.9893779, RATIO_DIVERSITY_GINI: 0.0413069, RATIO_SHANNON_ENTROPY: 0.6092438, RATIO_AVERAGE_POPULARITY: 4.7894858, RATIO_NOVELTY: 0.2808850,
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 132.3941
# Function value obtained: -0.0167
# Current minimum: -0.0172
# Iteration No: 45 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 147, 'shrink': 723, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 692.14 column/sec. Elapsed time 35.41 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 57.62 sec. Users per second: 695
# SearchBayesianSkopt: Config 44 is suboptimal. Config: {'topK': 147, 'shrink': 723, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0286071, PRECISION_RECALL_MIN_DEN: 0.0562419, RECALL: 0.0541696, MAP: 0.0121382, MAP_MIN_DEN: 0.0238601, MRR: 0.0968806, NDCG: 0.0490264, F1: 0.0374413, HIT_RATE: 0.2267349, ARHR_ALL_HITS: 0.1080683, NOVELTY: 0.0037679, AVERAGE_POPULARITY: 0.3756004, DIVERSITY_MEAN_INTER_LIST: 0.6778592, DIVERSITY_HERFINDAHL: 0.9677842, COVERAGE_ITEM: 0.2439711, COVERAGE_ITEM_HIT: 0.0167299, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2181892, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0085257, SHANNON_ENTROPY: 6.3608602, RATIO_DIVERSITY_HERFINDAHL: 0.9681040, RATIO_DIVERSITY_GINI: 0.0168523, RATIO_SHANNON_ENTROPY: 0.4714675, RATIO_AVERAGE_POPULARITY: 7.4248211, RATIO_NOVELTY: 0.2536592,
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 94.4816
# Function value obtained: -0.0121
# Current minimum: -0.0172
# Iteration No: 46 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 137, 'shrink': 56, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 695.35 column/sec. Elapsed time 35.24 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 57.42 sec. Users per second: 698
# SearchBayesianSkopt: Config 45 is suboptimal. Config: {'topK': 137, 'shrink': 56, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0287169, PRECISION_RECALL_MIN_DEN: 0.0564610, RECALL: 0.0543824, MAP: 0.0121934, MAP_MIN_DEN: 0.0239704, MRR: 0.0972720, NDCG: 0.0492297, F1: 0.0375862, HIT_RATE: 0.2274588, ARHR_ALL_HITS: 0.1085466, NOVELTY: 0.0037762, AVERAGE_POPULARITY: 0.3726492, DIVERSITY_MEAN_INTER_LIST: 0.6843885, DIVERSITY_HERFINDAHL: 0.9684371, COVERAGE_ITEM: 0.2486228, COVERAGE_ITEM_HIT: 0.0169747, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2188859, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0088831, SHANNON_ENTROPY: 6.4097717, RATIO_DIVERSITY_HERFINDAHL: 0.9687571, RATIO_DIVERSITY_GINI: 0.0175588, RATIO_SHANNON_ENTROPY: 0.4750928, RATIO_AVERAGE_POPULARITY: 7.3664823, RATIO_NOVELTY: 0.2542226,
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 94.1464
# Function value obtained: -0.0122
# Current minimum: -0.0172
# Iteration No: 47 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 967, 'shrink': 83, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 402.36 column/sec. Elapsed time 1.02 min
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.16 min. Users per second: 577
# SearchBayesianSkopt: Config 46 is suboptimal. Config: {'topK': 967, 'shrink': 83, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0376086, PRECISION_RECALL_MIN_DEN: 0.0717575, RECALL: 0.0688583, MAP: 0.0167333, MAP_MIN_DEN: 0.0318897, MRR: 0.1250583, NDCG: 0.0639857, F1: 0.0486473, HIT_RATE: 0.2780579, ARHR_ALL_HITS: 0.1440461, NOVELTY: 0.0042868, AVERAGE_POPULARITY: 0.2276538, DIVERSITY_MEAN_INTER_LIST: 0.9026084, DIVERSITY_HERFINDAHL: 0.9902586, COVERAGE_ITEM: 0.6059901, COVERAGE_ITEM_HIT: 0.0432121, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2675779, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0418889, SHANNON_ENTROPY: 8.6702219, RATIO_DIVERSITY_HERFINDAHL: 0.9905858, RATIO_DIVERSITY_GINI: 0.0828001, RATIO_SHANNON_ENTROPY: 0.6426375, RATIO_AVERAGE_POPULARITY: 4.5002319, RATIO_NOVELTY: 0.2885950,
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 132.2840
# Function value obtained: -0.0167
# Current minimum: -0.0172
# Iteration No: 48 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 138, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# SearchBayesianSkopt: Config 47 was already explored at index 41. Config: {'topK': 138, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0382027, PRECISION_RECALL_MIN_DEN: 0.0727093, RECALL: 0.0697743, MAP: 0.0172102, MAP_MIN_DEN: 0.0327575, MRR: 0.1281427, NDCG: 0.0653450, F1: 0.0493729, HIT_RATE: 0.2808787, ARHR_ALL_HITS: 0.1478961, NOVELTY: 0.0042825, AVERAGE_POPULARITY: 0.2061592, DIVERSITY_MEAN_INTER_LIST: 0.9255210, DIVERSITY_HERFINDAHL: 0.9925498, COVERAGE_ITEM: 0.3665483, COVERAGE_ITEM_HIT: 0.0450075, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2702923, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0238368, SHANNON_ENTROPY: 8.7018217, RATIO_DIVERSITY_HERFINDAHL: 0.9928777, RATIO_DIVERSITY_GINI: 0.0471172, RATIO_SHANNON_ENTROPY: 0.6449797, RATIO_AVERAGE_POPULARITY: 4.0753288, RATIO_NOVELTY: 0.2883074,
# /opt/conda/lib/python3.7/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 1.2340
# Function value obtained: -0.0172
# Current minimum: -0.0172
# Iteration No: 49 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 236, 'shrink': 991, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 640.09 column/sec. Elapsed time 38.29 sec
# EvaluatorHoldout: Processed 40060 (100.0%) in 1.03 min. Users per second: 650
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'topK': 236, 'shrink': 991, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0280679, PRECISION_RECALL_MIN_DEN: 0.0556038, RECALL: 0.0536052, MAP: 0.0118239, MAP_MIN_DEN: 0.0234631, MRR: 0.0948901, NDCG: 0.0482228, F1: 0.0368441, HIT_RATE: 0.2235147, ARHR_ALL_HITS: 0.1055937, NOVELTY: 0.0037194, AVERAGE_POPULARITY: 0.3932341, DIVERSITY_MEAN_INTER_LIST: 0.6381994, DIVERSITY_HERFINDAHL: 0.9638183, COVERAGE_ITEM: 0.2150814, COVERAGE_ITEM_HIT: 0.0150977, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2150904, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0066309, SHANNON_ENTROPY: 6.0764583, RATIO_DIVERSITY_HERFINDAHL: 0.9641368, RATIO_DIVERSITY_GINI: 0.0131070, RATIO_SHANNON_ENTROPY: 0.4503876, RATIO_AVERAGE_POPULARITY: 7.7734028, RATIO_NOVELTY: 0.2503951,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 101.4868
# Function value obtained: -0.0118
# Current minimum: -0.0172
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 137, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# SearchBayesianSkopt: Config 49 was already explored at index 38. Config: {'topK': 137, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0381777, PRECISION_RECALL_MIN_DEN: 0.0726683, RECALL: 0.0697422, MAP: 0.0171831, MAP_MIN_DEN: 0.0327350, MRR: 0.1280356, NDCG: 0.0653007, F1: 0.0493440, HIT_RATE: 0.2809286, ARHR_ALL_HITS: 0.1477141, NOVELTY: 0.0042830, AVERAGE_POPULARITY: 0.2060262, DIVERSITY_MEAN_INTER_LIST: 0.9255719, DIVERSITY_HERFINDAHL: 0.9925549, COVERAGE_ITEM: 0.3665483, COVERAGE_ITEM_HIT: 0.0450075, ITEMS_IN_GT: 0.9862896, COVERAGE_USER: 0.9623099, COVERAGE_USER_HIT: 0.2703404, USERS_IN_GT: 0.9623099, DIVERSITY_GINI: 0.0238563, SHANNON_ENTROPY: 8.7036685, RATIO_DIVERSITY_HERFINDAHL: 0.9928828, RATIO_DIVERSITY_GINI: 0.0471558, RATIO_SHANNON_ENTROPY: 0.6451166, RATIO_AVERAGE_POPULARITY: 4.0727001, RATIO_NOVELTY: 0.2883416,
# /opt/conda/lib/python3.7/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 1.2708
# Function value obtained: -0.0172
# Current minimum: -0.0172
# SearchBayesianSkopt: Search complete. Best config is 41: {'topK': 138, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
#
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 138, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 536.47 column/sec. Elapsed time 45.68 sec
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_best_model_last'
# ItemKNNCFRecommender: Saving complete

# %%
from Recommenders.DataIO import DataIO

#explore the results of the search
data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

search_metadata.keys()
# Out:
# dict_keys(['result_on_validation_df', 'metric_to_optimize', 'result_on_last', 'time_on_last_df', 'result_on_earlystopping_df', 'hyperparameters_df', 'time_on_validation_avg', 'algorithm_name_recommender', 'cutoff_to_optimize', 'result_on_test_best', 'algorithm_name_search', 'hyperparameters_best_index', 'time_on_test_avg', 'result_on_validation_best', 'result_on_test_df', 'time_on_test_total', 'exception_list', 'time_on_validation_total', 'time_on_train_avg', 'time_df', 'hyperparameters_best', 'time_on_train_total'])

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#    topK shrink similarity normalize feature_weighting
# 0   156    162     cosine     False            TF-IDF
# 1   310    816     cosine     False            TF-IDF
# 2   736    138     cosine      True            TF-IDF
# 3   952    504     cosine      True            TF-IDF
# 4   705    805     cosine      True            TF-IDF
# 5   720    630     cosine     False            TF-IDF
# 6    99    557     cosine      True            TF-IDF
# 7   762    768     cosine     False            TF-IDF
# 8   342    173     cosine     False            TF-IDF
# 9   917    495     cosine     False            TF-IDF
# 10  145    495     cosine     False            TF-IDF
# 11  909    276     cosine     False            TF-IDF
# 12  947    447     cosine      True            TF-IDF
# 13  894    968     cosine     False            TF-IDF
# 14  237    260     cosine     False            TF-IDF
# 15   99    148     cosine      True            TF-IDF
# 16  936    101     cosine     False            TF-IDF
# 17   34    844     cosine     False            TF-IDF
# 18    5   1000     cosine      True            TF-IDF
# 19  372    153     cosine      True            TF-IDF
# 20  219   1000     cosine      True            TF-IDF
# 21  523     15     cosine      True            TF-IDF
# 22  531    959     cosine     False            TF-IDF
# 23  152   1000     cosine      True            TF-IDF
# 24  133   1000     cosine      True            TF-IDF
# 25  169      0     cosine      True            TF-IDF
# 26  451     12     cosine      True            TF-IDF
# 27  455    351     cosine     False            TF-IDF
# 28  163   1000     cosine      True            TF-IDF
# 29  650    712     cosine     False            TF-IDF
# 30  289   1000     cosine      True            TF-IDF
# 31  336    354     cosine     False            TF-IDF
# 32  385    415     cosine     False            TF-IDF
# 33  872    646     cosine      True            TF-IDF
# 34  429    332     cosine     False            TF-IDF
# 35  727     80     cosine     False            TF-IDF
# 36  759    649     cosine      True            TF-IDF
# 37  840    663     cosine      True            TF-IDF
# 38  137   1000     cosine      True            TF-IDF
# 39  516    459     cosine     False            TF-IDF
# 40  918    621     cosine      True            TF-IDF
# 41  138   1000     cosine      True            TF-IDF
# 42  137   1000     cosine      True            TF-IDF
# 43  923    967     cosine      True            TF-IDF
# 44  147    723     cosine     False            TF-IDF
# 45  137     56     cosine     False            TF-IDF
# 46  967     83     cosine      True            TF-IDF
# 47  138   1000     cosine      True            TF-IDF
# 48  236    991     cosine     False            TF-IDF
# 49  137   1000     cosine      True            TF-IDF

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#           PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#    cutoff
# 0  10      0.028605                 0.056344  0.054271  0.012125     0.02389
# 1  10      0.027731                 0.055053  0.053082  0.011618    0.023098
# 2  10      0.037676                 0.071851  0.068956  0.016799    0.032058
# 3  10      0.037559                  0.07189  0.068989  0.016721    0.031875
# 4  10      0.037644                 0.072026  0.069132  0.016792    0.032014
# 5  10      0.026897                 0.053692  0.051798  0.011168    0.022274
# 6  10       0.03818                 0.072736  0.069791  0.017063    0.032602
# 7  10      0.026812                 0.053528   0.05164  0.011142    0.022256
# 8  10      0.027591                 0.054806  0.052835  0.011564    0.023006
# 9  10      0.026672                 0.053256  0.051377  0.011066    0.022064
# 10 10      0.028637                 0.056344  0.054267  0.012156    0.023901
# 11 10       0.02666                 0.053238  0.051361  0.011065    0.022062
# 12 10      0.037551                 0.071845  0.068946  0.016731    0.031883
# 13 10      0.026672                 0.053272  0.051396  0.011077    0.022093
# 14 10       0.02806                 0.055598    0.0536  0.011819    0.023453
# 15 10      0.038198                 0.072647  0.069719  0.017029    0.032451
# 16 10      0.026665                 0.053242  0.051366  0.011062    0.022055
# 17 10      0.030152                 0.058652  0.056425  0.012927    0.025209
# 18 10      0.034186                  0.06483  0.062221  0.014983    0.028621
# 19 10      0.038005                 0.072448  0.069489  0.016938     0.03225
# 20 10      0.038205                 0.072946  0.069985  0.017088    0.032539
# 21 10      0.037811                   0.0719  0.068966   0.01685    0.032031
# 22 10      0.027127                 0.054052  0.052136  0.011316     0.02255
# 23 10      0.038223                 0.072884  0.069963  0.017208    0.032795
# 24 10      0.038235                 0.072817  0.069891  0.017172    0.032708
# 25 10      0.038203                 0.072541  0.069596   0.01712    0.032546
# 26 10      0.037878                 0.072074  0.069109  0.016848    0.032077
# 27 10      0.027322                 0.054371  0.052447  0.011406    0.022686
# 28 10      0.038275                 0.073063  0.070123  0.017149    0.032727
# 29 10      0.026995                 0.053881  0.051976   0.01122    0.022371
# 30 10      0.038015                 0.072683  0.069746  0.017011    0.032452
# 31 10      0.027594                 0.054838  0.052873   0.01157    0.023025
# 32 10      0.027514                  0.05465  0.052694  0.011494    0.022865
# 33 10      0.037559                 0.071924   0.06902  0.016727    0.031898
# 34 10      0.027396                 0.054448  0.052508  0.011435    0.022747
# 35 10      0.026885                 0.053657  0.051763  0.011162    0.022263
# 36 10      0.037639                 0.072084  0.069189  0.016776    0.032023
# 37 10      0.037661                 0.072156  0.069247  0.016741    0.031943
# 38 10      0.038178                 0.072668  0.069742  0.017183    0.032735
# 39 10      0.027162                  0.05414  0.052227  0.011334    0.022573
# 40 10      0.037556                 0.071839  0.068924  0.016731    0.031879
# 41 10      0.038203                 0.072709  0.069774   0.01721    0.032758
# 42 10      0.038178                 0.072668  0.069742  0.017183    0.032735
# 43 10      0.037546                 0.071886  0.068968  0.016693    0.031814
# 44 10      0.028607                 0.056242   0.05417  0.012138     0.02386
# 45 10      0.028717                 0.056461  0.054382  0.012193     0.02397
# 46 10      0.037609                 0.071757  0.068858  0.016733     0.03189
# 47 10      0.038203                 0.072709  0.069774   0.01721    0.032758
# 48 10      0.028068                 0.055604  0.053605  0.011824    0.023463
# 49 10      0.038178                 0.072668  0.069742  0.017183    0.032735
#
#                 MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#    cutoff                                                        ...
# 0  10      0.096768  0.049055  0.037463   0.22671      0.107946  ...
# 1  10      0.093273  0.047556   0.03643  0.220769      0.103793  ...
# 2  10      0.125596  0.064209  0.048728  0.278308      0.144628  ...
# 3  10      0.125109  0.063992  0.048638  0.278333      0.144022  ...
# 4  10      0.125776  0.064217  0.048745  0.278682      0.144698  ...
# 5  10       0.09037   0.04611  0.035408  0.216226      0.100183  ...
# 6  10      0.126921  0.065083  0.049358  0.280579      0.146543  ...
# 7  10       0.09018  0.046022  0.035298  0.215652      0.099958  ...
# 8  10      0.093003  0.047367  0.036251  0.220045      0.103399  ...
# 9  10      0.089611  0.045721  0.035115  0.214703      0.099311  ...
# 10 10       0.09699  0.049099   0.03749  0.226935      0.108206  ...
# 11 10       0.08959   0.04571    0.0351  0.214603      0.099291  ...
# 12 10      0.125227     0.064  0.048621  0.278108       0.14412  ...
# 13 10      0.089701  0.045757  0.035119  0.214728      0.099407  ...
# 14 10      0.094848  0.048208  0.036836   0.22349      0.105549  ...
# 15 10      0.126568  0.064929  0.049355  0.281078      0.146223  ...
# 16 10       0.08958  0.045708  0.035106  0.214628      0.099276  ...
# 17 10      0.101758  0.051505  0.039302  0.235197      0.114306  ...
# 18 10      0.114904  0.058002  0.044128   0.25996      0.130819  ...
# 19 10        0.1261  0.064644  0.049137  0.279805        0.1455  ...
# 20 10      0.127273  0.065129  0.049428  0.281677      0.146845  ...
# 21 10      0.125804  0.064275  0.048843  0.279181      0.144965  ...
# 22 10      0.091392   0.04657  0.035686  0.217499       0.10141  ...
# 23 10      0.128385   0.06543  0.049437  0.281628      0.147997  ...
# 24 10      0.127975  0.065319  0.049429  0.281328      0.147626  ...
# 25 10      0.127494   0.06507  0.049328  0.281153      0.147111  ...
# 26 10      0.125645  0.064341  0.048935  0.279231      0.144853  ...
# 27 10      0.091947  0.046853  0.035927  0.218447      0.102108  ...
# 28 10      0.127917  0.065383  0.049521  0.282426      0.147459  ...
# 29 10      0.090771  0.046296  0.035534   0.21685      0.100637  ...
# 30 10      0.126953  0.064931  0.049209  0.281353      0.146319  ...
# 31 10      0.093038  0.047394  0.036263   0.22002       0.10345  ...
# 32 10      0.092439  0.047148  0.036151  0.219695      0.102775  ...
# 33 10      0.125255  0.064026  0.048646  0.278407      0.144119  ...
# 34 10       0.09206  0.046944  0.036006  0.218947      0.102297  ...
# 35 10      0.090315  0.046086  0.035389  0.216076      0.100127  ...
# 36 10      0.125612  0.064211  0.048755  0.278857       0.14454  ...
# 37 10      0.125327  0.064142  0.048788  0.279031      0.144215  ...
# 38 10      0.128036  0.065301  0.049344  0.280929      0.147714  ...
# 39 10      0.091461  0.046621  0.035738  0.217524      0.101527  ...
# 40 10       0.12518  0.063982   0.04862  0.278183      0.144073  ...
# 41 10      0.128143  0.065345  0.049373  0.280879      0.147896  ...
# 42 10      0.128036  0.065301  0.049344  0.280929      0.147714  ...
# 43 10      0.124988  0.063918  0.048622  0.278432        0.1438  ...
# 44 10      0.096881  0.049026  0.037441  0.226735      0.108068  ...
# 45 10      0.097272   0.04923  0.037586  0.227459      0.108547  ...
# 46 10      0.125058  0.063986  0.048647  0.278058      0.144046  ...
# 47 10      0.128143  0.065345  0.049373  0.280879      0.147896  ...
# 48 10       0.09489  0.048223  0.036844  0.223515      0.105594  ...
# 49 10      0.128036  0.065301  0.049344  0.280929      0.147714  ...
#
#           COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#    cutoff
# 0  10           0.96231          0.218165     0.96231       0.008279
# 1  10           0.96231          0.212448     0.96231       0.005724
# 2  10           0.96231          0.267818     0.96231       0.040823
# 3  10           0.96231          0.267842     0.96231       0.027427
# 4  10           0.96231          0.268178     0.96231       0.023709
# 5  10           0.96231          0.208076     0.96231       0.003497
# 6  10           0.96231          0.270004     0.96231       0.029024
# 7  10           0.96231          0.207524     0.96231       0.003396
# 8  10           0.96231          0.211751     0.96231       0.005409
# 9  10           0.96231          0.206611     0.96231       0.003036
# 10 10           0.96231          0.218381     0.96231         0.0086
# 11 10           0.96231          0.206515     0.96231       0.003057
# 12 10           0.96231          0.267626     0.96231       0.028804
# 13 10           0.96231          0.206635     0.96231       0.003084
# 14 10           0.96231          0.215066     0.96231        0.00661
# 15 10           0.96231          0.270485     0.96231       0.039007
# 16 10           0.96231          0.206539     0.96231       0.002992
# 17 10           0.96231          0.226333     0.96231       0.019105
# 18 10           0.96231          0.250162     0.96231       0.049509
# 19 10           0.96231          0.269259     0.96231       0.041721
# 20 10           0.96231          0.271061     0.96231       0.023606
# 21 10           0.96231          0.268659     0.96231       0.048786
# 22 10           0.96231          0.209301     0.96231       0.004198
# 23 10           0.96231          0.271013     0.96231       0.023862
# 24 10           0.96231          0.270725     0.96231       0.023885
# 25 10           0.96231          0.270557     0.96231       0.046847
# 26 10           0.96231          0.268707     0.96231       0.049153
# 27 10           0.96231          0.210214     0.96231       0.004617
# 28 10           0.96231          0.271782     0.96231       0.023864
# 29 10           0.96231          0.208677     0.96231       0.003725
# 30 10           0.96231          0.270749     0.96231       0.023512
# 31 10           0.96231          0.211727     0.96231       0.005464
# 32 10           0.96231          0.211415     0.96231       0.005076
# 33 10           0.96231          0.267914     0.96231       0.025233
# 34 10           0.96231          0.210694     0.96231       0.004772
# 35 10           0.96231          0.207932     0.96231       0.003479
# 36 10           0.96231          0.268347     0.96231       0.025684
# 37 10           0.96231          0.268515     0.96231       0.025074
# 38 10           0.96231           0.27034     0.96231       0.023856
# 39 10           0.96231          0.209325     0.96231       0.004266
# 40 10           0.96231          0.267698     0.96231       0.025401
# 41 10           0.96231          0.270292     0.96231       0.023837
# 42 10           0.96231           0.27034     0.96231       0.023856
# 43 10           0.96231          0.267938     0.96231       0.020897
# 44 10           0.96231          0.218189     0.96231       0.008526
# 45 10           0.96231          0.218886     0.96231       0.008883
# 46 10           0.96231          0.267578     0.96231       0.041889
# 47 10           0.96231          0.270292     0.96231       0.023837
# 48 10           0.96231           0.21509     0.96231       0.006631
# 49 10           0.96231           0.27034     0.96231       0.023856
#
#           SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#    cutoff
# 0  10            6.323196                   0.967571             0.016364
# 1  10            5.931209                    0.96208             0.011313
# 2  10            8.673812                   0.990772             0.080692
# 3  10            8.396866                   0.989912             0.054214
# 4  10            8.330286                   0.989927             0.046864
# 5  10            5.547265                   0.956514             0.006913
# 6  10            8.932091                   0.993745             0.057371
# 7  10            5.526832                   0.956227             0.006713
# 8  10            5.882174                   0.961362             0.010691
# 9  10            5.461616                   0.955342             0.006002
# 10 10            6.371691                   0.968265                0.017
# 11 10            5.464501                   0.955372             0.006042
# 12 10            8.427214                   0.989997             0.056935
# 13 10            5.469893                   0.955444             0.006097
# 14 10            6.074123                   0.964111             0.013066
# 15 10            9.140146                   0.994101             0.077104
# 16 10            5.454395                    0.95525             0.005913
# 17 10            7.394992                     0.9805             0.037763
# 18 10            9.904239                   0.996936             0.097863
# 19 10            8.806355                    0.99174             0.082468
# 20 10            8.571472                    0.99197             0.046662
# 21 10            8.850505                   0.991424             0.096434
# 22 10            5.669801                   0.958249             0.008297
# 23 10            8.674172                    0.99268             0.047166
# 24 10            8.710401                   0.992919             0.047213
# 25 10            9.132821                    0.99345               0.0926
# 26 10            8.884829                   0.991651             0.097159
# 27 10            5.743399                   0.959305             0.009126
# 28 10            8.657345                   0.992564             0.047171
# 29 10            5.587567                   0.957088             0.007364
# 30 10            8.489254                   0.991329             0.046476
# 31 10             5.89031                   0.961487               0.0108
# 32 10            5.824405                   0.960493             0.010033
# 33 10            8.349112                   0.989824             0.049877
# 34 10            5.770297                   0.959695             0.009433
# 35 10            5.543056                   0.956451             0.006877
# 36 10             8.37559                   0.990009             0.050769
# 37 10             8.34906                    0.98986             0.049562
# 38 10            8.703668                   0.992883             0.047156
# 39 10            5.683262                   0.958447             0.008432
# 40 10            8.350256                   0.989801             0.050209
# 41 10            8.701822                   0.992878             0.047117
# 42 10            8.703668                   0.992883             0.047156
# 43 10            8.219687                   0.989378             0.041307
# 44 10             6.36086                   0.968104             0.016852
# 45 10            6.409772                   0.968757             0.017559
# 46 10            8.670222                   0.990586               0.0828
# 47 10            8.701822                   0.992878             0.047117
# 48 10            6.076458                   0.964137             0.013107
# 49 10            8.703668                   0.992883             0.047156
#
#           RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#    cutoff
# 0  10                  0.468676                 7.473729      0.253212
# 1  10                  0.439622                  7.94214      0.248787
# 2  10                  0.642904                 4.466302      0.288539
# 3  10                  0.622376                 4.665729      0.283853
# 4  10                  0.617441                 4.675893      0.282628
# 5  10                  0.411164                 8.381321      0.244596
# 6  10                  0.662047                 3.844888      0.292254
# 7  10                  0.409649                 8.403887      0.244375
# 8  10                  0.435987                  8.00081      0.248238
# 9  10                  0.404815                  8.47126      0.243686
# 10 10                   0.47227                 7.411271      0.253781
# 11 10                  0.405029                 8.468595      0.243715
# 12 10                  0.624626                 4.645582       0.28436
# 13 10                  0.405429                 8.463336      0.243768
# 14 10                  0.450214                 7.775678      0.250369
# 15 10                  0.677468                   3.7278      0.296066
# 16 10                   0.40428                 8.478386      0.243608
# 17 10                  0.548117                 6.157296      0.266092
# 18 10                  0.734103                 2.893672      0.307156
# 19 10                  0.652728                 4.264155      0.290585
# 20 10                  0.635318                 4.269611      0.286268
# 21 10                     0.656                  4.31609      0.291604
# 22 10                  0.420246                 8.246642      0.245926
# 23 10                   0.64293                 4.116511      0.287879
# 24 10                  0.645616                 4.063367      0.288448
# 25 10                  0.676925                 3.874947      0.296247
# 26 10                  0.658544                 4.268293      0.292144
# 27 10                  0.425701                 8.162806      0.246726
# 28 10                  0.641683                  4.14505      0.287584
# 29 10                  0.414151                  8.33711      0.245033
# 30 10                  0.629224                 4.402715      0.284974
# 31 10                   0.43659                 7.990902      0.248328
# 32 10                  0.431705                 8.069496      0.247601
# 33 10                  0.618837                 4.688111      0.283029
# 34 10                  0.427695                  8.13113       0.24702
# 35 10                  0.410852                 8.386236      0.244551
# 36 10                  0.620799                 4.652667      0.283424
# 37 10                  0.618833                 4.682453      0.283019
# 38 10                  0.645117                   4.0727      0.288342
# 39 10                  0.421244                 8.230396      0.246075
# 40 10                  0.618922                 4.693084      0.283052
# 41 10                   0.64498                 4.075329      0.288307
# 42 10                  0.645117                   4.0727      0.288342
# 43 10                  0.609244                 4.789486      0.280885
# 44 10                  0.471467                 7.424821      0.253659
# 45 10                  0.475093                 7.366482      0.254223
# 46 10                  0.642638                 4.500232      0.288595
# 47 10                   0.64498                 4.075329      0.288307
# 48 10                  0.450388                 7.773403      0.250395
# 49 10                  0.645117                   4.0727      0.288342
#
# [50 rows x 27 columns]

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 138,
#  'shrink': 1000,
#  'similarity': 'cosine',
#  'normalize': True,
#  'feature_weighting': 'TF-IDF'}

# %% [markdown]
# This are the best hyperparameters found by the bayesian search, we will use them in our model

# %%
recommender = ItemKNNCFRecommender(URM_all)
recommender.fit(shrink=1000, topK=138, feature_weighting = 'TF-IDF', similarity = 'cosine', normalize=True)
# Out:
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 24507 (100.0%), 532.77 column/sec. Elapsed time 46.00 sec

# %% [markdown]
# # Create final recommendations

# %%
test_users = pd.read_csv('/kaggle/working/Recommender-Systems-Challenge-2022/Dataset/data_target_users_test.csv')

# %%
user_id = test_users['user_id']
recommendations = []
for user in user_id:
    recommendations.append(recommender.recommend(user, cutoff=10))

# %%
for index in range(len(recommendations)):
    recommendations[index]=np.array(recommendations[index])

test_users['item_list']= recommendations
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])
test_users.to_csv('/kaggle/working/Submission_SLIM_EN_rp3Beta_EaseR_Linear.csv', index=False)
