# %%
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot

from Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Utils.DataReader import load_urm, load_icm, load_target

# %%
URM_all = load_urm()

URM_train = sps.load_npz('Dataset/Split/URM_train.npz')
URM_test =  sps.load_npz('Dataset/Split/URM_test.npz')
URM_validation = sps.load_npz('Dataset/Split/URM_validation.npz')

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=[10])
# Out:
# Warning: 959 (2.30 %) of 41629 users have no sampled items
# Warning: 1590 (3.82 %) of 41629 users have no sampled items
# EvaluatorHoldout: Ignoring 1590 ( 3.8%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 959 ( 2.3%) Users that have less than 1 test interactions

# %% [markdown]
# ## RP3 Beta Recommender

# %%
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender

recommender_class = RP3betaRecommender

# %%
import os

output_folder_path = "Experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_cases = 500
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from skopt.space import Real, Integer, Categorical

hyperparameters_range_dictionary = {
    "alpha": Real(low=0, high=1, prior='uniform'),
    "beta": Real(low=0, high=1, prior='uniform'),
    "topK": Integer(1, 800),
    "implicit": Categorical([True, False])
}

# %% [markdown]
# We create a bayesian optimizer object, we pass the recommender and the evaluator

# %%
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                           evaluator_validation=evaluator_validation)

# %% [markdown]
# We provide data needed to create the instance of the model, one on the URM_train, the other on URM_all

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_all],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %% [markdown]
# ### Bayesian Search

# %%
hyperparameterSearch.search(recommender_input_args,
                            recommender_input_args_last_test = recommender_input_args_last_test,
                            hyperparameter_search_space = hyperparameters_range_dictionary,
                            n_cases = n_cases,
                            n_random_starts = n_random_starts,
                            save_model = "last",
                            output_folder_path = output_folder_path, # Where to save the results
                            output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                            metric_to_optimize = metric_to_optimize,
                            cutoff_to_optimize = cutoff_to_optimize,
                            )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.20292943880839825, 'beta': 0.2212987251629815, 'topK': 572, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 673.02 column/sec. Elapsed time 36.41 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 35.08 sec. Users per second: 1141
# SearchBayesianSkopt: New best config found. Config 0: {'alpha': 0.20292943880839825, 'beta': 0.2212987251629815, 'topK': 572, 'implicit': True} - results: PRECISION: 0.0370264, PRECISION_RECALL_MIN_DEN: 0.0717681, RECALL: 0.0690555, MAP: 0.0163139, MAP_MIN_DEN: 0.0316289, MRR: 0.1235570, NDCG: 0.0635077, F1: 0.0482057, HIT_RATE: 0.2783536, ARHR_ALL_HITS: 0.1415759, NOVELTY: 0.0040260, AVERAGE_POPULARITY: 0.2947674, DIVERSITY_MEAN_INTER_LIST: 0.8346703, DIVERSITY_HERFINDAHL: 0.9834649, COVERAGE_ITEM: 0.3632840, COVERAGE_ITEM_HIT: 0.0342351, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2677220, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0170797, SHANNON_ENTROPY: 7.6408700, RATIO_DIVERSITY_HERFINDAHL: 0.9837897, RATIO_DIVERSITY_GINI: 0.0337378, RATIO_SHANNON_ENTROPY: 0.5663615, RATIO_AVERAGE_POPULARITY: 5.7766452, RATIO_NOVELTY: 0.2710487,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 76.8872
# Function value obtained: -0.0163
# Current minimum: -0.0163
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.6681444794819312, 'beta': 0.042523366802125435, 'topK': 15, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1357.43 column/sec. Elapsed time 18.05 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 24.59 sec. Users per second: 1628
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'alpha': 0.6681444794819312, 'beta': 0.042523366802125435, 'topK': 15, 'implicit': False} - results: PRECISION: 0.0244686, PRECISION_RECALL_MIN_DEN: 0.0445393, RECALL: 0.0423894, MAP: 0.0119260, MAP_MIN_DEN: 0.0224641, MRR: 0.0951891, NDCG: 0.0439852, F1: 0.0310273, HIT_RATE: 0.1913384, ARHR_ALL_HITS: 0.1061808, NOVELTY: 0.0051751, AVERAGE_POPULARITY: 0.0567110, DIVERSITY_MEAN_INTER_LIST: 0.9912020, DIVERSITY_HERFINDAHL: 0.9991177, COVERAGE_ITEM: 0.6347982, COVERAGE_ITEM_HIT: 0.0579018, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1840304, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1367750, SHANNON_ENTROPY: 11.6629218, RATIO_DIVERSITY_HERFINDAHL: 0.9994477, RATIO_DIVERSITY_GINI: 0.2701736, RATIO_SHANNON_ENTROPY: 0.8644866, RATIO_AVERAGE_POPULARITY: 1.1113830, RATIO_NOVELTY: 0.3484075,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 43.1209
# Function value obtained: -0.0119
# Current minimum: -0.0163
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7578633549881036, 'beta': 0.5799542678802919, 'topK': 240, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 915.33 column/sec. Elapsed time 26.77 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 30.72 sec. Users per second: 1303
# SearchBayesianSkopt: New best config found. Config 2: {'alpha': 0.7578633549881036, 'beta': 0.5799542678802919, 'topK': 240, 'implicit': True} - results: PRECISION: 0.0391868, PRECISION_RECALL_MIN_DEN: 0.0747103, RECALL: 0.0718132, MAP: 0.0178536, MAP_MIN_DEN: 0.0339520, MRR: 0.1329528, NDCG: 0.0674812, F1: 0.0507050, HIT_RATE: 0.2880691, ARHR_ALL_HITS: 0.1535915, NOVELTY: 0.0046335, AVERAGE_POPULARITY: 0.1810247, DIVERSITY_MEAN_INTER_LIST: 0.9451117, DIVERSITY_HERFINDAHL: 0.9945088, COVERAGE_ITEM: 0.7772065, COVERAGE_ITEM_HIT: 0.0489248, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2770665, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1074890, SHANNON_ENTROPY: 10.0203227, RATIO_DIVERSITY_HERFINDAHL: 0.9948372, RATIO_DIVERSITY_GINI: 0.2123247, RATIO_SHANNON_ENTROPY: 0.7427328, RATIO_AVERAGE_POPULARITY: 3.5475958, RATIO_NOVELTY: 0.3119438,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 60.1237
# Function value obtained: -0.0179
# Current minimum: -0.0179
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7592134511858061, 'beta': 0.8803146659565677, 'topK': 511, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 706.53 column/sec. Elapsed time 34.69 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 40.05 sec. Users per second: 1000
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'alpha': 0.7592134511858061, 'beta': 0.8803146659565677, 'topK': 511, 'implicit': False} - results: PRECISION: 0.0181848, PRECISION_RECALL_MIN_DEN: 0.0304120, RECALL: 0.0285126, MAP: 0.0074065, MAP_MIN_DEN: 0.0123155, MRR: 0.0553400, NDCG: 0.0270389, F1: 0.0222066, HIT_RATE: 0.1367167, ARHR_ALL_HITS: 0.0637808, NOVELTY: 0.0060763, AVERAGE_POPULARITY: 0.0179884, DIVERSITY_MEAN_INTER_LIST: 0.9960577, DIVERSITY_HERFINDAHL: 0.9996033, COVERAGE_ITEM: 0.8070755, COVERAGE_ITEM_HIT: 0.0571673, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1314949, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2714025, SHANNON_ENTROPY: 12.8901153, RATIO_DIVERSITY_HERFINDAHL: 0.9999334, RATIO_DIVERSITY_GINI: 0.5361054, RATIO_SHANNON_ENTROPY: 0.9554494, RATIO_AVERAGE_POPULARITY: 0.3525241, RATIO_NOVELTY: 0.4090818,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 79.7104
# Function value obtained: -0.0074
# Current minimum: -0.0179
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9019664343193668, 'beta': 0.2903377102460784, 'topK': 762, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 607.70 column/sec. Elapsed time 40.33 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 40.26 sec. Users per second: 995
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'alpha': 0.9019664343193668, 'beta': 0.2903377102460784, 'topK': 762, 'implicit': False} - results: PRECISION: 0.0365918, PRECISION_RECALL_MIN_DEN: 0.0711545, RECALL: 0.0685366, MAP: 0.0163163, MAP_MIN_DEN: 0.0317237, MRR: 0.1237019, NDCG: 0.0633510, F1: 0.0477108, HIT_RATE: 0.2746572, ARHR_ALL_HITS: 0.1417095, NOVELTY: 0.0041747, AVERAGE_POPULARITY: 0.2923935, DIVERSITY_MEAN_INTER_LIST: 0.8315500, DIVERSITY_HERFINDAHL: 0.9831529, COVERAGE_ITEM: 0.7356674, COVERAGE_ITEM_HIT: 0.0327253, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2641668, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0647851, SHANNON_ENTROPY: 8.2530530, RATIO_DIVERSITY_HERFINDAHL: 0.9834776, RATIO_DIVERSITY_GINI: 0.1279711, RATIO_SHANNON_ENTROPY: 0.6117381, RATIO_AVERAGE_POPULARITY: 5.7301229, RATIO_NOVELTY: 0.2810606,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 86.7198
# Function value obtained: -0.0163
# Current minimum: -0.0179
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.5084045065502466, 'beta': 0.7735714535209516, 'topK': 457, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 732.39 column/sec. Elapsed time 33.46 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 37.84 sec. Users per second: 1058
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'alpha': 0.5084045065502466, 'beta': 0.7735714535209516, 'topK': 457, 'implicit': True} - results: PRECISION: 0.0291940, PRECISION_RECALL_MIN_DEN: 0.0527779, RECALL: 0.0503895, MAP: 0.0124558, MAP_MIN_DEN: 0.0225456, MRR: 0.0937993, NDCG: 0.0470291, F1: 0.0369693, HIT_RATE: 0.2182872, ARHR_ALL_HITS: 0.1077318, NOVELTY: 0.0054327, AVERAGE_POPULARITY: 0.0592790, DIVERSITY_MEAN_INTER_LIST: 0.9886858, DIVERSITY_HERFINDAHL: 0.9988661, COVERAGE_ITEM: 0.8484515, COVERAGE_ITEM_HIT: 0.0647978, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2099498, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2166392, SHANNON_ENTROPY: 12.0597299, RATIO_DIVERSITY_HERFINDAHL: 0.9991960, RATIO_DIVERSITY_GINI: 0.4279306, RATIO_SHANNON_ENTROPY: 0.8938990, RATIO_AVERAGE_POPULARITY: 1.1617074, RATIO_NOVELTY: 0.3657484,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 76.3662
# Function value obtained: -0.0125
# Current minimum: -0.0179
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9286686130272754, 'beta': 0.3920609984200434, 'topK': 339, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 835.69 column/sec. Elapsed time 29.33 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 31.22 sec. Users per second: 1283
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'alpha': 0.9286686130272754, 'beta': 0.3920609984200434, 'topK': 339, 'implicit': True} - results: PRECISION: 0.0386198, PRECISION_RECALL_MIN_DEN: 0.0747224, RECALL: 0.0719580, MAP: 0.0175350, MAP_MIN_DEN: 0.0339194, MRR: 0.1320572, NDCG: 0.0672502, F1: 0.0502634, HIT_RATE: 0.2872699, ARHR_ALL_HITS: 0.1517411, NOVELTY: 0.0043129, AVERAGE_POPULARITY: 0.2492831, DIVERSITY_MEAN_INTER_LIST: 0.8867732, DIVERSITY_HERFINDAHL: 0.9886751, COVERAGE_ITEM: 0.7269760, COVERAGE_ITEM_HIT: 0.0372547, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2762978, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0703875, SHANNON_ENTROPY: 8.8540297, RATIO_DIVERSITY_HERFINDAHL: 0.9890016, RATIO_DIVERSITY_GINI: 0.1390376, RATIO_SHANNON_ENTROPY: 0.6562841, RATIO_AVERAGE_POPULARITY: 4.8852758, RATIO_NOVELTY: 0.2903600,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 64.1170
# Function value obtained: -0.0175
# Current minimum: -0.0179
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.8215673955693473, 'beta': 0.9039354644594714, 'topK': 498, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 709.92 column/sec. Elapsed time 34.52 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 39.35 sec. Users per second: 1018
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'alpha': 0.8215673955693473, 'beta': 0.9039354644594714, 'topK': 498, 'implicit': False} - results: PRECISION: 0.0155374, PRECISION_RECALL_MIN_DEN: 0.0254860, RECALL: 0.0237377, MAP: 0.0062217, MAP_MIN_DEN: 0.0102320, MRR: 0.0463588, NDCG: 0.0226630, F1: 0.0187814, HIT_RATE: 0.1170858, ARHR_ALL_HITS: 0.0534808, NOVELTY: 0.0061852, AVERAGE_POPULARITY: 0.0133935, DIVERSITY_MEAN_INTER_LIST: 0.9967541, DIVERSITY_HERFINDAHL: 0.9996729, COVERAGE_ITEM: 0.7880197, COVERAGE_ITEM_HIT: 0.0534133, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1126138, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2688960, SHANNON_ENTROPY: 12.9361573, RATIO_DIVERSITY_HERFINDAHL: 1.0000031, RATIO_DIVERSITY_GINI: 0.5311542, RATIO_SHANNON_ENTROPY: 0.9588622, RATIO_AVERAGE_POPULARITY: 0.2624758, RATIO_NOVELTY: 0.4164092,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 78.6697
# Function value obtained: -0.0062
# Current minimum: -0.0179
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.5398376566428695, 'beta': 0.9272203038113112, 'topK': 540, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 688.10 column/sec. Elapsed time 35.62 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 39.71 sec. Users per second: 1008
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'alpha': 0.5398376566428695, 'beta': 0.9272203038113112, 'topK': 540, 'implicit': True} - results: PRECISION: 0.0159395, PRECISION_RECALL_MIN_DEN: 0.0268611, RECALL: 0.0252014, MAP: 0.0063832, MAP_MIN_DEN: 0.0108130, MRR: 0.0490006, NDCG: 0.0238348, F1: 0.0195279, HIT_RATE: 0.1230051, ARHR_ALL_HITS: 0.0557154, NOVELTY: 0.0061155, AVERAGE_POPULARITY: 0.0136831, DIVERSITY_MEAN_INTER_LIST: 0.9959374, DIVERSITY_HERFINDAHL: 0.9995913, COVERAGE_ITEM: 0.8026278, COVERAGE_ITEM_HIT: 0.0603093, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1183069, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2599006, SHANNON_ENTROPY: 12.8298262, RATIO_DIVERSITY_HERFINDAHL: 0.9999214, RATIO_DIVERSITY_GINI: 0.5133854, RATIO_SHANNON_ENTROPY: 0.9509806, RATIO_AVERAGE_POPULARITY: 0.2681516, RATIO_NOVELTY: 0.4117165,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 81.1334
# Function value obtained: -0.0064
# Current minimum: -0.0179
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9249290809669473, 'beta': 0.19417281329395225, 'topK': 73, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1228.85 column/sec. Elapsed time 19.94 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 26.65 sec. Users per second: 1503
# SearchBayesianSkopt: New best config found. Config 9: {'alpha': 0.9249290809669473, 'beta': 0.19417281329395225, 'topK': 73, 'implicit': True} - results: PRECISION: 0.0408252, PRECISION_RECALL_MIN_DEN: 0.0778214, RECALL: 0.0747472, MAP: 0.0185011, MAP_MIN_DEN: 0.0354389, MRR: 0.1375554, NDCG: 0.0702188, F1: 0.0528079, HIT_RATE: 0.2990334, ARHR_ALL_HITS: 0.1589714, NOVELTY: 0.0044947, AVERAGE_POPULARITY: 0.1858319, DIVERSITY_MEAN_INTER_LIST: 0.9465287, DIVERSITY_HERFINDAHL: 0.9946505, COVERAGE_ITEM: 0.7239156, COVERAGE_ITEM_HIT: 0.0468846, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2876120, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0733282, SHANNON_ENTROPY: 9.6353944, RATIO_DIVERSITY_HERFINDAHL: 0.9949790, RATIO_DIVERSITY_GINI: 0.1448463, RATIO_SHANNON_ENTROPY: 0.7142009, RATIO_AVERAGE_POPULARITY: 3.6418030, RATIO_NOVELTY: 0.3025998,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 47.9809
# Function value obtained: -0.0185
# Current minimum: -0.0185
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.2608740957841909, 'beta': 0.5383597269237458, 'topK': 327, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 844.04 column/sec. Elapsed time 29.04 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 32.43 sec. Users per second: 1235
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'alpha': 0.2608740957841909, 'beta': 0.5383597269237458, 'topK': 327, 'implicit': False} - results: PRECISION: 0.0392018, PRECISION_RECALL_MIN_DEN: 0.0751709, RECALL: 0.0722634, MAP: 0.0177270, MAP_MIN_DEN: 0.0338837, MRR: 0.1317108, NDCG: 0.0674161, F1: 0.0508294, HIT_RATE: 0.2889433, ARHR_ALL_HITS: 0.1523272, NOVELTY: 0.0045303, AVERAGE_POPULARITY: 0.1825707, DIVERSITY_MEAN_INTER_LIST: 0.9442524, DIVERSITY_HERFINDAHL: 0.9944229, COVERAGE_ITEM: 0.7681887, COVERAGE_ITEM_HIT: 0.0528012, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2779072, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0816967, SHANNON_ENTROPY: 9.7253361, RATIO_DIVERSITY_HERFINDAHL: 0.9947513, RATIO_DIVERSITY_GINI: 0.1613768, RATIO_SHANNON_ENTROPY: 0.7208676, RATIO_AVERAGE_POPULARITY: 3.5778921, RATIO_NOVELTY: 0.3049954,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 64.8337
# Function value obtained: -0.0177
# Current minimum: -0.0185
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.23851925643989108, 'beta': 0.3167389755997831, 'topK': 414, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 778.31 column/sec. Elapsed time 31.49 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 31.93 sec. Users per second: 1254
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'alpha': 0.23851925643989108, 'beta': 0.3167389755997831, 'topK': 414, 'implicit': False} - results: PRECISION: 0.0383951, PRECISION_RECALL_MIN_DEN: 0.0742705, RECALL: 0.0714791, MAP: 0.0172581, MAP_MIN_DEN: 0.0334116, MRR: 0.1296217, NDCG: 0.0664080, F1: 0.0499561, HIT_RATE: 0.2850471, ARHR_ALL_HITS: 0.1491328, NOVELTY: 0.0041741, AVERAGE_POPULARITY: 0.2584250, DIVERSITY_MEAN_INTER_LIST: 0.8790962, DIVERSITY_HERFINDAHL: 0.9879074, COVERAGE_ITEM: 0.5325825, COVERAGE_ITEM_HIT: 0.0402334, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2741598, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0318636, SHANNON_ENTROPY: 8.3144676, RATIO_DIVERSITY_HERFINDAHL: 0.9882337, RATIO_DIVERSITY_GINI: 0.0629406, RATIO_SHANNON_ENTROPY: 0.6162903, RATIO_AVERAGE_POPULARITY: 5.0644320, RATIO_NOVELTY: 0.2810149,
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 68.1695
# Function value obtained: -0.0173
# Current minimum: -0.0185
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9906343742759337, 'beta': 0.6818585963477584, 'topK': 167, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1092.21 column/sec. Elapsed time 22.44 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 30.73 sec. Users per second: 1303
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'alpha': 0.9906343742759337, 'beta': 0.6818585963477584, 'topK': 167, 'implicit': True} - results: PRECISION: 0.0358500, PRECISION_RECALL_MIN_DEN: 0.0662456, RECALL: 0.0634132, MAP: 0.0162850, MAP_MIN_DEN: 0.0300600, MRR: 0.1202537, NDCG: 0.0603389, F1: 0.0458048, HIT_RATE: 0.2608707, ARHR_ALL_HITS: 0.1395134, NOVELTY: 0.0050536, AVERAGE_POPULARITY: 0.1241012, DIVERSITY_MEAN_INTER_LIST: 0.9734817, DIVERSITY_HERFINDAHL: 0.9973457, COVERAGE_ITEM: 0.7615375, COVERAGE_ITEM_HIT: 0.0497409, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2509068, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1475238, SHANNON_ENTROPY: 11.0940732, RATIO_DIVERSITY_HERFINDAHL: 0.9976751, RATIO_DIVERSITY_GINI: 0.2914060, RATIO_SHANNON_ENTROPY: 0.8223220, RATIO_AVERAGE_POPULARITY: 2.4320482, RATIO_NOVELTY: 0.3402288,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 55.0495
# Function value obtained: -0.0163
# Current minimum: -0.0185
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.6256382368155389, 'beta': 0.035274643992297634, 'topK': 204, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1012.19 column/sec. Elapsed time 24.21 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 26.35 sec. Users per second: 1519
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'alpha': 0.6256382368155389, 'beta': 0.035274643992297634, 'topK': 204, 'implicit': True} - results: PRECISION: 0.0393516, PRECISION_RECALL_MIN_DEN: 0.0757969, RECALL: 0.0728930, MAP: 0.0174630, MAP_MIN_DEN: 0.0335205, MRR: 0.1307121, NDCG: 0.0672268, F1: 0.0511108, HIT_RATE: 0.2919154, ARHR_ALL_HITS: 0.1505853, NOVELTY: 0.0041266, AVERAGE_POPULARITY: 0.2448891, DIVERSITY_MEAN_INTER_LIST: 0.9002703, DIVERSITY_HERFINDAHL: 0.9900248, COVERAGE_ITEM: 0.2857551, COVERAGE_ITEM_HIT: 0.0371731, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2807658, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0149537, SHANNON_ENTROPY: 8.1065532, RATIO_DIVERSITY_HERFINDAHL: 0.9903517, RATIO_DIVERSITY_GINI: 0.0295382, RATIO_SHANNON_ENTROPY: 0.6008791, RATIO_AVERAGE_POPULARITY: 4.7991662, RATIO_NOVELTY: 0.2778168,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 52.5286
# Function value obtained: -0.0175
# Current minimum: -0.0185
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.322329163672962, 'beta': 0.25083118087614226, 'topK': 30, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1304.91 column/sec. Elapsed time 18.78 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 24.90 sec. Users per second: 1608
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'alpha': 0.322329163672962, 'beta': 0.25083118087614226, 'topK': 30, 'implicit': False} - results: PRECISION: 0.0370714, PRECISION_RECALL_MIN_DEN: 0.0689262, RECALL: 0.0660467, MAP: 0.0172093, MAP_MIN_DEN: 0.0323962, MRR: 0.1298393, NDCG: 0.0641199, F1: 0.0474881, HIT_RATE: 0.2747072, ARHR_ALL_HITS: 0.1489937, NOVELTY: 0.0049773, AVERAGE_POPULARITY: 0.1136631, DIVERSITY_MEAN_INTER_LIST: 0.9786786, DIVERSITY_HERFINDAHL: 0.9978654, COVERAGE_ITEM: 0.8033623, COVERAGE_ITEM_HIT: 0.0716938, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2642149, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1427584, SHANNON_ENTROPY: 11.2422736, RATIO_DIVERSITY_HERFINDAHL: 0.9981950, RATIO_DIVERSITY_GINI: 0.2819927, RATIO_SHANNON_ENTROPY: 0.8333070, RATIO_AVERAGE_POPULARITY: 2.2274902, RATIO_NOVELTY: 0.3350926,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 44.3128
# Function value obtained: -0.0172
# Current minimum: -0.0185
# Iteration No: 16 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.227276318178315, 'beta': 0.6756763623580067, 'topK': 116, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1133.86 column/sec. Elapsed time 21.61 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 28.46 sec. Users per second: 1407
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'alpha': 0.227276318178315, 'beta': 0.6756763623580067, 'topK': 116, 'implicit': False} - results: PRECISION: 0.0351632, PRECISION_RECALL_MIN_DEN: 0.0661974, RECALL: 0.0635234, MAP: 0.0154720, MAP_MIN_DEN: 0.0292181, MRR: 0.1158080, NDCG: 0.0590713, F1: 0.0452683, HIT_RATE: 0.2613702, ARHR_ALL_HITS: 0.1334615, NOVELTY: 0.0049018, AVERAGE_POPULARITY: 0.1111816, DIVERSITY_MEAN_INTER_LIST: 0.9763001, DIVERSITY_HERFINDAHL: 0.9976276, COVERAGE_ITEM: 0.7058391, COVERAGE_ITEM_HIT: 0.0659811, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2513873, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1063807, SHANNON_ENTROPY: 10.7977892, RATIO_DIVERSITY_HERFINDAHL: 0.9979570, RATIO_DIVERSITY_GINI: 0.2101355, RATIO_SHANNON_ENTROPY: 0.8003607, RATIO_AVERAGE_POPULARITY: 2.1788598, RATIO_NOVELTY: 0.3300087,
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 51.4032
# Function value obtained: -0.0155
# Current minimum: -0.0185
# Iteration No: 17 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.4223771054694404, 'beta': 0.5514193250761578, 'topK': 499, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 717.82 column/sec. Elapsed time 34.14 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 38.32 sec. Users per second: 1045
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'alpha': 0.4223771054694404, 'beta': 0.5514193250761578, 'topK': 499, 'implicit': False} - results: PRECISION: 0.0389620, PRECISION_RECALL_MIN_DEN: 0.0743501, RECALL: 0.0714438, MAP: 0.0177070, MAP_MIN_DEN: 0.0336975, MRR: 0.1314695, NDCG: 0.0670005, F1: 0.0504248, HIT_RATE: 0.2862709, ARHR_ALL_HITS: 0.1520934, NOVELTY: 0.0045577, AVERAGE_POPULARITY: 0.1918002, DIVERSITY_MEAN_INTER_LIST: 0.9365260, DIVERSITY_HERFINDAHL: 0.9936503, COVERAGE_ITEM: 0.8255600, COVERAGE_ITEM_HIT: 0.0501489, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2753369, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1058990, SHANNON_ENTROPY: 9.8037545, RATIO_DIVERSITY_HERFINDAHL: 0.9939784, RATIO_DIVERSITY_GINI: 0.2091839, RATIO_SHANNON_ENTROPY: 0.7266802, RATIO_AVERAGE_POPULARITY: 3.7587666, RATIO_NOVELTY: 0.3068449,
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 77.4555
# Function value obtained: -0.0177
# Current minimum: -0.0185
# Iteration No: 18 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.5521473789742177, 'beta': 0.7915678306018783, 'topK': 719, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 631.67 column/sec. Elapsed time 38.80 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 42.42 sec. Users per second: 944
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'alpha': 0.5521473789742177, 'beta': 0.7915678306018783, 'topK': 719, 'implicit': True} - results: PRECISION: 0.0258448, PRECISION_RECALL_MIN_DEN: 0.0448058, RECALL: 0.0425081, MAP: 0.0108644, MAP_MIN_DEN: 0.0187632, MRR: 0.0808147, NDCG: 0.0400270, F1: 0.0321453, HIT_RATE: 0.1916631, ARHR_ALL_HITS: 0.0933829, NOVELTY: 0.0057201, AVERAGE_POPULARITY: 0.0398938, DIVERSITY_MEAN_INTER_LIST: 0.9930672, DIVERSITY_HERFINDAHL: 0.9993042, COVERAGE_ITEM: 0.8615498, COVERAGE_ITEM_HIT: 0.0656547, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1843426, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2720189, SHANNON_ENTROPY: 12.6301352, RATIO_DIVERSITY_HERFINDAHL: 0.9996343, RATIO_DIVERSITY_GINI: 0.5373230, RATIO_SHANNON_ENTROPY: 0.9361790, RATIO_AVERAGE_POPULARITY: 0.7818109, RATIO_NOVELTY: 0.3851027,
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 87.4042
# Function value obtained: -0.0109
# Current minimum: -0.0185
# Iteration No: 19 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.03666909207722258, 'beta': 0.8316197704337684, 'topK': 349, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 831.49 column/sec. Elapsed time 29.47 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 32.49 sec. Users per second: 1232
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'alpha': 0.03666909207722258, 'beta': 0.8316197704337684, 'topK': 349, 'implicit': False} - results: PRECISION: 0.0215914, PRECISION_RECALL_MIN_DEN: 0.0399324, RECALL: 0.0382121, MAP: 0.0088346, MAP_MIN_DEN: 0.0165765, MRR: 0.0694679, NDCG: 0.0349608, F1: 0.0275922, HIT_RATE: 0.1704089, ARHR_ALL_HITS: 0.0780834, NOVELTY: 0.0055355, AVERAGE_POPULARITY: 0.0345228, DIVERSITY_MEAN_INTER_LIST: 0.9894926, DIVERSITY_HERFINDAHL: 0.9989468, COVERAGE_ITEM: 0.7952422, COVERAGE_ITEM_HIT: 0.0711225, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1639002, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1784098, SHANNON_ENTROPY: 11.9371643, RATIO_DIVERSITY_HERFINDAHL: 0.9992767, RATIO_DIVERSITY_GINI: 0.3524155, RATIO_SHANNON_ENTROPY: 0.8848142, RATIO_AVERAGE_POPULARITY: 0.6765530, RATIO_NOVELTY: 0.3726734,
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 65.6081
# Function value obtained: -0.0088
# Current minimum: -0.0185
# Iteration No: 20 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.24466466071839793, 'beta': 0.5493887250112317, 'topK': 402, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 770.08 column/sec. Elapsed time 31.82 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 36.09 sec. Users per second: 1109
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'alpha': 0.24466466071839793, 'beta': 0.5493887250112317, 'topK': 402, 'implicit': False} - results: PRECISION: 0.0388971, PRECISION_RECALL_MIN_DEN: 0.0744712, RECALL: 0.0715926, MAP: 0.0175660, MAP_MIN_DEN: 0.0335414, MRR: 0.1303499, NDCG: 0.0667707, F1: 0.0504073, HIT_RATE: 0.2864207, ARHR_ALL_HITS: 0.1508409, NOVELTY: 0.0045442, AVERAGE_POPULARITY: 0.1826421, DIVERSITY_MEAN_INTER_LIST: 0.9431236, DIVERSITY_HERFINDAHL: 0.9943100, COVERAGE_ITEM: 0.7876933, COVERAGE_ITEM_HIT: 0.0528420, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2754810, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0876372, SHANNON_ENTROPY: 9.7600326, RATIO_DIVERSITY_HERFINDAHL: 0.9946384, RATIO_DIVERSITY_GINI: 0.1731111, RATIO_SHANNON_ENTROPY: 0.7234394, RATIO_AVERAGE_POPULARITY: 3.5792928, RATIO_NOVELTY: 0.3059302,
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 72.4311
# Function value obtained: -0.0176
# Current minimum: -0.0185
# Iteration No: 21 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.0631769134701723, 'beta': 0.49428866608084177, 'topK': 368, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 823.45 column/sec. Elapsed time 29.76 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 32.22 sec. Users per second: 1243
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'alpha': 0.0631769134701723, 'beta': 0.49428866608084177, 'topK': 368, 'implicit': False} - results: PRECISION: 0.0389695, PRECISION_RECALL_MIN_DEN: 0.0747106, RECALL: 0.0718266, MAP: 0.0176838, MAP_MIN_DEN: 0.0338861, MRR: 0.1316976, NDCG: 0.0672418, F1: 0.0505261, HIT_RATE: 0.2878943, ARHR_ALL_HITS: 0.1521247, NOVELTY: 0.0044672, AVERAGE_POPULARITY: 0.1940144, DIVERSITY_MEAN_INTER_LIST: 0.9358733, DIVERSITY_HERFINDAHL: 0.9935850, COVERAGE_ITEM: 0.6967397, COVERAGE_ITEM_HIT: 0.0514547, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2768983, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0651715, SHANNON_ENTROPY: 9.4768220, RATIO_DIVERSITY_HERFINDAHL: 0.9939131, RATIO_DIVERSITY_GINI: 0.1287342, RATIO_SHANNON_ENTROPY: 0.7024471, RATIO_AVERAGE_POPULARITY: 3.8021588, RATIO_NOVELTY: 0.3007480,
#
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 66.0080
# Function value obtained: -0.0177
# Current minimum: -0.0185
# Iteration No: 22 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.745960947079903, 'beta': 0.5163829011196309, 'topK': 95, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1233.16 column/sec. Elapsed time 19.87 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 28.44 sec. Users per second: 1408
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'alpha': 0.745960947079903, 'beta': 0.5163829011196309, 'topK': 95, 'implicit': True} - results: PRECISION: 0.0396738, PRECISION_RECALL_MIN_DEN: 0.0753881, RECALL: 0.0723942, MAP: 0.0182464, MAP_MIN_DEN: 0.0347060, MRR: 0.1354843, NDCG: 0.0685847, F1: 0.0512574, HIT_RATE: 0.2899923, ARHR_ALL_HITS: 0.1566624, NOVELTY: 0.0046227, AVERAGE_POPULARITY: 0.1622443, DIVERSITY_MEAN_INTER_LIST: 0.9608076, DIVERSITY_HERFINDAHL: 0.9960784, COVERAGE_ITEM: 0.7361978, COVERAGE_ITEM_HIT: 0.0508426, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2789161, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0905779, SHANNON_ENTROPY: 10.0803387, RATIO_DIVERSITY_HERFINDAHL: 0.9964073, RATIO_DIVERSITY_GINI: 0.1789198, RATIO_SHANNON_ENTROPY: 0.7471813, RATIO_AVERAGE_POPULARITY: 3.1795501, RATIO_NOVELTY: 0.3112213,
#
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 49.5400
# Function value obtained: -0.0182
# Current minimum: -0.0185
# Iteration No: 23 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.6450822707820782, 'beta': 0.9242627471746523, 'topK': 759, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 614.68 column/sec. Elapsed time 39.87 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 42.79 sec. Users per second: 936
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'alpha': 0.6450822707820782, 'beta': 0.9242627471746523, 'topK': 759, 'implicit': True} - results: PRECISION: 0.0140263, PRECISION_RECALL_MIN_DEN: 0.0224386, RECALL: 0.0207885, MAP: 0.0055708, MAP_MIN_DEN: 0.0089930, MRR: 0.0418961, NDCG: 0.0201438, F1: 0.0167507, HIT_RATE: 0.1062714, ARHR_ALL_HITS: 0.0480981, NOVELTY: 0.0062348, AVERAGE_POPULARITY: 0.0105226, DIVERSITY_MEAN_INTER_LIST: 0.9971428, DIVERSITY_HERFINDAHL: 0.9997118, COVERAGE_ITEM: 0.8044640, COVERAGE_ITEM_HIT: 0.0567593, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1022124, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2823518, SHANNON_ENTROPY: 13.0250903, RATIO_DIVERSITY_HERFINDAHL: 1.0000419, RATIO_DIVERSITY_GINI: 0.5577337, RATIO_SHANNON_ENTROPY: 0.9654541, RATIO_AVERAGE_POPULARITY: 0.2062144, RATIO_NOVELTY: 0.4197518,
#
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 89.0890
# Function value obtained: -0.0056
# Current minimum: -0.0185
# Iteration No: 24 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.5175126360422321, 'beta': 0.8605911705322006, 'topK': 219, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 988.69 column/sec. Elapsed time 24.79 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 30.84 sec. Users per second: 1298
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'alpha': 0.5175126360422321, 'beta': 0.8605911705322006, 'topK': 219, 'implicit': True} - results: PRECISION: 0.0228577, PRECISION_RECALL_MIN_DEN: 0.0410008, RECALL: 0.0390107, MAP: 0.0093748, MAP_MIN_DEN: 0.0169971, MRR: 0.0725146, NDCG: 0.0361735, F1: 0.0288255, HIT_RATE: 0.1771273, ARHR_ALL_HITS: 0.0821443, NOVELTY: 0.0056532, AVERAGE_POPULARITY: 0.0352030, DIVERSITY_MEAN_INTER_LIST: 0.9908048, DIVERSITY_HERFINDAHL: 0.9990780, COVERAGE_ITEM: 0.7790835, COVERAGE_ITEM_HIT: 0.0645938, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1703620, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1941028, SHANNON_ENTROPY: 12.1342585, RATIO_DIVERSITY_HERFINDAHL: 0.9994079, RATIO_DIVERSITY_GINI: 0.3834142, RATIO_SHANNON_ENTROPY: 0.8994233, RATIO_AVERAGE_POPULARITY: 0.6898829, RATIO_NOVELTY: 0.3805978,
#
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 58.2199
# Function value obtained: -0.0094
# Current minimum: -0.0185
# Iteration No: 25 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.6655243659351681, 'beta': 0.13299599876553672, 'topK': 110, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1160.80 column/sec. Elapsed time 21.11 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 27.41 sec. Users per second: 1461
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'alpha': 0.6655243659351681, 'beta': 0.13299599876553672, 'topK': 110, 'implicit': False} - results: PRECISION: 0.0405530, PRECISION_RECALL_MIN_DEN: 0.0776895, RECALL: 0.0746465, MAP: 0.0182971, MAP_MIN_DEN: 0.0351027, MRR: 0.1361970, NDCG: 0.0697431, F1: 0.0525547, HIT_RATE: 0.2981593, ARHR_ALL_HITS: 0.1573275, NOVELTY: 0.0043497, AVERAGE_POPULARITY: 0.2055670, DIVERSITY_MEAN_INTER_LIST: 0.9326722, DIVERSITY_HERFINDAHL: 0.9932649, COVERAGE_ITEM: 0.6044395, COVERAGE_ITEM_HIT: 0.0459053, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2867712, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0444812, SHANNON_ENTROPY: 9.0617174, RATIO_DIVERSITY_HERFINDAHL: 0.9935929, RATIO_DIVERSITY_GINI: 0.0878645, RATIO_SHANNON_ENTROPY: 0.6716784, RATIO_AVERAGE_POPULARITY: 4.0285583, RATIO_NOVELTY: 0.2928363,
#
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 49.9178
# Function value obtained: -0.0183
# Current minimum: -0.0185
# Iteration No: 26 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.2778844235303039, 'beta': 0.33534510079664187, 'topK': 606, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 674.55 column/sec. Elapsed time 36.33 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 36.49 sec. Users per second: 1097
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'alpha': 0.2778844235303039, 'beta': 0.33534510079664187, 'topK': 606, 'implicit': False} - results: PRECISION: 0.0377482, PRECISION_RECALL_MIN_DEN: 0.0729532, RECALL: 0.0701868, MAP: 0.0168940, MAP_MIN_DEN: 0.0326927, MRR: 0.1272095, NDCG: 0.0651706, F1: 0.0490930, HIT_RATE: 0.2815005, ARHR_ALL_HITS: 0.1461821, NOVELTY: 0.0041465, AVERAGE_POPULARITY: 0.2745001, DIVERSITY_MEAN_INTER_LIST: 0.8581479, DIVERSITY_HERFINDAHL: 0.9858126, COVERAGE_ITEM: 0.6129677, COVERAGE_ITEM_HIT: 0.0380300, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2707488, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0386599, SHANNON_ENTROPY: 8.1885659, RATIO_DIVERSITY_HERFINDAHL: 0.9861382, RATIO_DIVERSITY_GINI: 0.0763654, RATIO_SHANNON_ENTROPY: 0.6069581, RATIO_AVERAGE_POPULARITY: 5.3794619, RATIO_NOVELTY: 0.2791586,
#
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 78.3834
# Function value obtained: -0.0169
# Current minimum: -0.0185
# Iteration No: 27 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.6230110433900117, 'beta': 0.7799105536245529, 'topK': 565, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 693.24 column/sec. Elapsed time 35.35 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 40.11 sec. Users per second: 998
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'alpha': 0.6230110433900117, 'beta': 0.7799105536245529, 'topK': 565, 'implicit': False} - results: PRECISION: 0.0278179, PRECISION_RECALL_MIN_DEN: 0.0488693, RECALL: 0.0464690, MAP: 0.0118302, MAP_MIN_DEN: 0.0207614, MRR: 0.0881972, NDCG: 0.0437900, F1: 0.0348021, HIT_RATE: 0.2058992, ARHR_ALL_HITS: 0.1017971, NOVELTY: 0.0056093, AVERAGE_POPULARITY: 0.0494674, DIVERSITY_MEAN_INTER_LIST: 0.9915758, DIVERSITY_HERFINDAHL: 0.9991551, COVERAGE_ITEM: 0.8510630, COVERAGE_ITEM_HIT: 0.0635737, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1980350, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2504030, SHANNON_ENTROPY: 12.4205962, RATIO_DIVERSITY_HERFINDAHL: 0.9994851, RATIO_DIVERSITY_GINI: 0.4946248, RATIO_SHANNON_ENTROPY: 0.9206474, RATIO_AVERAGE_POPULARITY: 0.9694277, RATIO_NOVELTY: 0.3776431,
#
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 81.0116
# Function value obtained: -0.0118
# Current minimum: -0.0185
# Iteration No: 28 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.3326720174480973, 'beta': 0.16334334218431493, 'topK': 135, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1148.39 column/sec. Elapsed time 21.34 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 27.43 sec. Users per second: 1460
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'alpha': 0.3326720174480973, 'beta': 0.16334334218431493, 'topK': 135, 'implicit': False} - results: PRECISION: 0.0406079, PRECISION_RECALL_MIN_DEN: 0.0777834, RECALL: 0.0747509, MAP: 0.0181656, MAP_MIN_DEN: 0.0347686, MRR: 0.1348593, NDCG: 0.0693661, F1: 0.0526267, HIT_RATE: 0.2973351, ARHR_ALL_HITS: 0.1559654, NOVELTY: 0.0043246, AVERAGE_POPULARITY: 0.2084275, DIVERSITY_MEAN_INTER_LIST: 0.9306785, DIVERSITY_HERFINDAHL: 0.9930655, COVERAGE_ITEM: 0.5019382, COVERAGE_ITEM_HIT: 0.0480679, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2859785, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0343507, SHANNON_ENTROPY: 8.9509800, RATIO_DIVERSITY_HERFINDAHL: 0.9933935, RATIO_DIVERSITY_GINI: 0.0678535, RATIO_SHANNON_ENTROPY: 0.6634703, RATIO_AVERAGE_POPULARITY: 4.0846161, RATIO_NOVELTY: 0.2911505,
#
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 50.6237
# Function value obtained: -0.0182
# Current minimum: -0.0185
# Iteration No: 29 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.6886671508316125, 'beta': 0.6571850557283588, 'topK': 474, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 727.88 column/sec. Elapsed time 33.67 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 37.86 sec. Users per second: 1058
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'alpha': 0.6886671508316125, 'beta': 0.6571850557283588, 'topK': 474, 'implicit': True} - results: PRECISION: 0.0370514, PRECISION_RECALL_MIN_DEN: 0.0686662, RECALL: 0.0657648, MAP: 0.0166788, MAP_MIN_DEN: 0.0308917, MRR: 0.1227032, NDCG: 0.0621294, F1: 0.0473987, HIT_RATE: 0.2697370, ARHR_ALL_HITS: 0.1426059, NOVELTY: 0.0049931, AVERAGE_POPULARITY: 0.1307964, DIVERSITY_MEAN_INTER_LIST: 0.9707727, DIVERSITY_HERFINDAHL: 0.9970748, COVERAGE_ITEM: 0.8401681, COVERAGE_ITEM_HIT: 0.0543110, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2594345, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1726967, SHANNON_ENTROPY: 11.0973654, RATIO_DIVERSITY_HERFINDAHL: 0.9974041, RATIO_DIVERSITY_GINI: 0.3411304, RATIO_SHANNON_ENTROPY: 0.8225660, RATIO_AVERAGE_POPULARITY: 2.5632563, RATIO_NOVELTY: 0.3361547,
#
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 76.8059
# Function value obtained: -0.0167
# Current minimum: -0.0185
# Iteration No: 30 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9377366001568406, 'beta': 0.5604847487780134, 'topK': 264, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 887.06 column/sec. Elapsed time 27.63 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 31.50 sec. Users per second: 1271
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'alpha': 0.9377366001568406, 'beta': 0.5604847487780134, 'topK': 264, 'implicit': False} - results: PRECISION: 0.0388746, PRECISION_RECALL_MIN_DEN: 0.0739552, RECALL: 0.0710962, MAP: 0.0178064, MAP_MIN_DEN: 0.0338347, MRR: 0.1326528, NDCG: 0.0671049, F1: 0.0502649, HIT_RATE: 0.2857464, ARHR_ALL_HITS: 0.1532683, NOVELTY: 0.0046373, AVERAGE_POPULARITY: 0.1917506, DIVERSITY_MEAN_INTER_LIST: 0.9369891, DIVERSITY_HERFINDAHL: 0.9936966, COVERAGE_ITEM: 0.7721467, COVERAGE_ITEM_HIT: 0.0449259, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2748324, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1120229, SHANNON_ENTROPY: 9.9824949, RATIO_DIVERSITY_HERFINDAHL: 0.9940247, RATIO_DIVERSITY_GINI: 0.2212806, RATIO_SHANNON_ENTROPY: 0.7399289, RATIO_AVERAGE_POPULARITY: 3.7577933, RATIO_NOVELTY: 0.3122034,
#
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 61.8801
# Function value obtained: -0.0178
# Current minimum: -0.0185
# Iteration No: 31 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9981136581054941, 'beta': 0.24090028761397436, 'topK': 521, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 711.56 column/sec. Elapsed time 34.44 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 35.67 sec. Users per second: 1122
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'alpha': 0.9981136581054941, 'beta': 0.24090028761397436, 'topK': 521, 'implicit': False} - results: PRECISION: 0.0368765, PRECISION_RECALL_MIN_DEN: 0.0718873, RECALL: 0.0692649, MAP: 0.0162242, MAP_MIN_DEN: 0.0316488, MRR: 0.1230416, NDCG: 0.0634784, F1: 0.0481292, HIT_RATE: 0.2776043, ARHR_ALL_HITS: 0.1409542, NOVELTY: 0.0041003, AVERAGE_POPULARITY: 0.3011033, DIVERSITY_MEAN_INTER_LIST: 0.8212101, DIVERSITY_HERFINDAHL: 0.9821190, COVERAGE_ITEM: 0.6394091, COVERAGE_ITEM_HIT: 0.0311340, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2670014, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0453146, SHANNON_ENTROPY: 7.9451450, RATIO_DIVERSITY_HERFINDAHL: 0.9824433, RATIO_DIVERSITY_GINI: 0.0895105, RATIO_SHANNON_ENTROPY: 0.5889151, RATIO_AVERAGE_POPULARITY: 5.9008110, RATIO_NOVELTY: 0.2760505,
#
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 74.7640
# Function value obtained: -0.0162
# Current minimum: -0.0185
# Iteration No: 32 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.6611711248236477, 'beta': 0.8582183849016923, 'topK': 556, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 692.84 column/sec. Elapsed time 35.37 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 40.49 sec. Users per second: 989
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'alpha': 0.6611711248236477, 'beta': 0.8582183849016923, 'topK': 556, 'implicit': True} - results: PRECISION: 0.0205150, PRECISION_RECALL_MIN_DEN: 0.0348165, RECALL: 0.0327945, MAP: 0.0083636, MAP_MIN_DEN: 0.0141877, MRR: 0.0629214, NDCG: 0.0309190, F1: 0.0252405, HIT_RATE: 0.1542746, ARHR_ALL_HITS: 0.0722821, NOVELTY: 0.0059642, AVERAGE_POPULARITY: 0.0226163, DIVERSITY_MEAN_INTER_LIST: 0.9953330, DIVERSITY_HERFINDAHL: 0.9995308, COVERAGE_ITEM: 0.8252744, COVERAGE_ITEM_HIT: 0.0619415, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1483821, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2729691, SHANNON_ENTROPY: 12.8307144, RATIO_DIVERSITY_HERFINDAHL: 0.9998609, RATIO_DIVERSITY_GINI: 0.5391999, RATIO_SHANNON_ENTROPY: 0.9510465, RATIO_AVERAGE_POPULARITY: 0.4432189, RATIO_NOVELTY: 0.4015305,
#
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 81.1378
# Function value obtained: -0.0084
# Current minimum: -0.0185
# Iteration No: 33 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9486763365617659, 'beta': 0.49529434239743575, 'topK': 734, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 613.31 column/sec. Elapsed time 39.96 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 41.47 sec. Users per second: 965
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'alpha': 0.9486763365617659, 'beta': 0.49529434239743575, 'topK': 734, 'implicit': False} - results: PRECISION: 0.0375634, PRECISION_RECALL_MIN_DEN: 0.0706849, RECALL: 0.0678508, MAP: 0.0171850, MAP_MIN_DEN: 0.0322839, MRR: 0.1281017, NDCG: 0.0643671, F1: 0.0483560, HIT_RATE: 0.2760808, ARHR_ALL_HITS: 0.1479300, NOVELTY: 0.0046922, AVERAGE_POPULARITY: 0.2047233, DIVERSITY_MEAN_INTER_LIST: 0.9238974, DIVERSITY_HERFINDAHL: 0.9923874, COVERAGE_ITEM: 0.8258865, COVERAGE_ITEM_HIT: 0.0401926, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2655360, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.1449571, SHANNON_ENTROPY: 10.0989198, RATIO_DIVERSITY_HERFINDAHL: 0.9927152, RATIO_DIVERSITY_GINI: 0.2863360, RATIO_SHANNON_ENTROPY: 0.7485586, RATIO_AVERAGE_POPULARITY: 4.0120246, RATIO_NOVELTY: 0.3158997,
#
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 87.3747
# Function value obtained: -0.0172
# Current minimum: -0.0185
# Iteration No: 34 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7547676866226489, 'beta': 0.9863919634253681, 'topK': 712, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 613.30 column/sec. Elapsed time 39.96 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 42.40 sec. Users per second: 944
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'alpha': 0.7547676866226489, 'beta': 0.9863919634253681, 'topK': 712, 'implicit': True} - results: PRECISION: 0.0093084, PRECISION_RECALL_MIN_DEN: 0.0146969, RECALL: 0.0134908, MAP: 0.0036482, MAP_MIN_DEN: 0.0057819, MRR: 0.0276593, NDCG: 0.0131595, F1: 0.0110160, HIT_RATE: 0.0714304, ARHR_ALL_HITS: 0.0316367, NOVELTY: 0.0063904, AVERAGE_POPULARITY: 0.0059136, DIVERSITY_MEAN_INTER_LIST: 0.9975805, DIVERSITY_HERFINDAHL: 0.9997556, COVERAGE_ITEM: 0.7570082, COVERAGE_ITEM_HIT: 0.0453340, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.0687021, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2584405, SHANNON_ENTROPY: 12.9519736, RATIO_DIVERSITY_HERFINDAHL: 1.0000857, RATIO_DIVERSITY_GINI: 0.5105013, RATIO_SHANNON_ENTROPY: 0.9600345, RATIO_AVERAGE_POPULARITY: 0.1158903, RATIO_NOVELTY: 0.4302267,
#
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 88.7070
# Function value obtained: -0.0036
# Current minimum: -0.0185
# Iteration No: 35 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7225267888511534, 'beta': 0.3766005027743714, 'topK': 610, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 660.08 column/sec. Elapsed time 37.13 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 38.36 sec. Users per second: 1044
# ...
# Function value obtained: -0.0188
# Current minimum: -0.0188
# Iteration No: 490 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.010276326380666003, 'beta': 0.626884429089368, 'topK': 140, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1149.08 column/sec. Elapsed time 21.33 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 28.22 sec. Users per second: 1419
# SearchBayesianSkopt: Config 489 is suboptimal. Config: {'alpha': 0.010276326380666003, 'beta': 0.626884429089368, 'topK': 140, 'implicit': False} - results: PRECISION: 0.0361847, PRECISION_RECALL_MIN_DEN: 0.0685795, RECALL: 0.0658168, MAP: 0.0160755, MAP_MIN_DEN: 0.0304273, MRR: 0.1196235, NDCG: 0.0611797, F1: 0.0466966, HIT_RATE: 0.2667150, ARHR_ALL_HITS: 0.1381937, NOVELTY: 0.0048159, AVERAGE_POPULARITY: 0.1232606, DIVERSITY_MEAN_INTER_LIST: 0.9729733, DIVERSITY_HERFINDAHL: 0.9972949, COVERAGE_ITEM: 0.6550781, COVERAGE_ITEM_HIT: 0.0643490, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2565279, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0903243, SHANNON_ENTROPY: 10.5609774, RATIO_DIVERSITY_HERFINDAHL: 0.9976243, RATIO_DIVERSITY_GINI: 0.1784189, RATIO_SHANNON_ENTROPY: 0.7828075, RATIO_AVERAGE_POPULARITY: 2.4155750, RATIO_NOVELTY: 0.3242251,
#
# Iteration No: 490 ended. Search finished for the next optimal point.
# Time taken: 78.0254
# Function value obtained: -0.0161
# Current minimum: -0.0188
# Iteration No: 491 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9965278864196134, 'beta': 0.003111088040554156, 'topK': 276, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 940.63 column/sec. Elapsed time 26.05 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 27.72 sec. Users per second: 1444
# SearchBayesianSkopt: Config 490 is suboptimal. Config: {'alpha': 0.9965278864196134, 'beta': 0.003111088040554156, 'topK': 276, 'implicit': True} - results: PRECISION: 0.0380904, PRECISION_RECALL_MIN_DEN: 0.0738324, RECALL: 0.0710942, MAP: 0.0167322, MAP_MIN_DEN: 0.0323227, MRR: 0.1265504, NDCG: 0.0651286, F1: 0.0496041, HIT_RATE: 0.2853718, ARHR_ALL_HITS: 0.1451229, NOVELTY: 0.0040222, AVERAGE_POPULARITY: 0.2782321, DIVERSITY_MEAN_INTER_LIST: 0.8649899, DIVERSITY_HERFINDAHL: 0.9864968, COVERAGE_ITEM: 0.2835108, COVERAGE_ITEM_HIT: 0.0307667, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2744721, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0125569, SHANNON_ENTROPY: 7.6576805, RATIO_DIVERSITY_HERFINDAHL: 0.9868226, RATIO_DIVERSITY_GINI: 0.0248038, RATIO_SHANNON_ENTROPY: 0.5676075, RATIO_AVERAGE_POPULARITY: 5.4525980, RATIO_NOVELTY: 0.2707894,
#
# Iteration No: 491 ended. Search finished for the next optimal point.
# Time taken: 83.7390
# Function value obtained: -0.0167
# Current minimum: -0.0188
# Iteration No: 492 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.744017685942313, 'beta': 0.3260406177347083, 'topK': 59, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1276.15 column/sec. Elapsed time 19.20 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 26.21 sec. Users per second: 1528
# SearchBayesianSkopt: Config 491 is suboptimal. Config: {'alpha': 0.744017685942313, 'beta': 0.3260406177347083, 'topK': 59, 'implicit': True} - results: PRECISION: 0.0410350, PRECISION_RECALL_MIN_DEN: 0.0776726, RECALL: 0.0745525, MAP: 0.0187750, MAP_MIN_DEN: 0.0358784, MRR: 0.1392551, NDCG: 0.0707721, F1: 0.0529341, HIT_RATE: 0.2990584, ARHR_ALL_HITS: 0.1611418, NOVELTY: 0.0046090, AVERAGE_POPULARITY: 0.1620344, DIVERSITY_MEAN_INTER_LIST: 0.9619435, DIVERSITY_HERFINDAHL: 0.9961919, COVERAGE_ITEM: 0.7588036, COVERAGE_ITEM_HIT: 0.0548007, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2876360, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0882509, SHANNON_ENTROPY: 10.1076350, RATIO_DIVERSITY_HERFINDAHL: 0.9965209, RATIO_DIVERSITY_GINI: 0.1743232, RATIO_SHANNON_ENTROPY: 0.7492046, RATIO_AVERAGE_POPULARITY: 3.1754371, RATIO_NOVELTY: 0.3102962,
#
# Iteration No: 492 ended. Search finished for the next optimal point.
# Time taken: 74.4273
# Function value obtained: -0.0188
# Current minimum: -0.0188
# Iteration No: 493 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7468837956695205, 'beta': 0.32677352015243183, 'topK': 59, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1305.24 column/sec. Elapsed time 18.78 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 26.18 sec. Users per second: 1530
# SearchBayesianSkopt: Config 492 is suboptimal. Config: {'alpha': 0.7468837956695205, 'beta': 0.32677352015243183, 'topK': 59, 'implicit': True} - results: PRECISION: 0.0410175, PRECISION_RECALL_MIN_DEN: 0.0776889, RECALL: 0.0745755, MAP: 0.0187736, MAP_MIN_DEN: 0.0358742, MRR: 0.1392604, NDCG: 0.0707656, F1: 0.0529254, HIT_RATE: 0.2989086, ARHR_ALL_HITS: 0.1611318, NOVELTY: 0.0046088, AVERAGE_POPULARITY: 0.1620940, DIVERSITY_MEAN_INTER_LIST: 0.9619204, DIVERSITY_HERFINDAHL: 0.9961896, COVERAGE_ITEM: 0.7588036, COVERAGE_ITEM_HIT: 0.0547599, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2874919, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0882036, SHANNON_ENTROPY: 10.1067736, RATIO_DIVERSITY_HERFINDAHL: 0.9965186, RATIO_DIVERSITY_GINI: 0.1742298, RATIO_SHANNON_ENTROPY: 0.7491408, RATIO_AVERAGE_POPULARITY: 3.1766052, RATIO_NOVELTY: 0.3102832,
#
# Iteration No: 493 ended. Search finished for the next optimal point.
# Time taken: 74.0050
# Function value obtained: -0.0188
# Current minimum: -0.0188
# Iteration No: 494 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7436425026820764, 'beta': 0.32683087722202686, 'topK': 59, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1354.98 column/sec. Elapsed time 18.09 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 26.59 sec. Users per second: 1506
# SearchBayesianSkopt: Config 493 is suboptimal. Config: {'alpha': 0.7436425026820764, 'beta': 0.32683087722202686, 'topK': 59, 'implicit': True} - results: PRECISION: 0.0410200, PRECISION_RECALL_MIN_DEN: 0.0776654, RECALL: 0.0745491, MAP: 0.0187669, MAP_MIN_DEN: 0.0358646, MRR: 0.1392060, NDCG: 0.0707509, F1: 0.0529208, HIT_RATE: 0.2990584, ARHR_ALL_HITS: 0.1610747, NOVELTY: 0.0046092, AVERAGE_POPULARITY: 0.1620049, DIVERSITY_MEAN_INTER_LIST: 0.9619691, DIVERSITY_HERFINDAHL: 0.9961945, COVERAGE_ITEM: 0.7590076, COVERAGE_ITEM_HIT: 0.0548007, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2876360, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0882638, SHANNON_ENTROPY: 10.1087395, RATIO_DIVERSITY_HERFINDAHL: 0.9965235, RATIO_DIVERSITY_GINI: 0.1743488, RATIO_SHANNON_ENTROPY: 0.7492865, RATIO_AVERAGE_POPULARITY: 3.1748588, RATIO_NOVELTY: 0.3103101,
#
# Iteration No: 494 ended. Search finished for the next optimal point.
# Time taken: 71.4433
# Function value obtained: -0.0188
# Current minimum: -0.0188
# Iteration No: 495 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7486958428224532, 'beta': 0.3254079260789993, 'topK': 59, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1286.91 column/sec. Elapsed time 19.04 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 25.70 sec. Users per second: 1558
# SearchBayesianSkopt: Config 494 is suboptimal. Config: {'alpha': 0.7486958428224532, 'beta': 0.3254079260789993, 'topK': 59, 'implicit': True} - results: PRECISION: 0.0410475, PRECISION_RECALL_MIN_DEN: 0.0777298, RECALL: 0.0746075, MAP: 0.0187661, MAP_MIN_DEN: 0.0358627, MRR: 0.1391822, NDCG: 0.0707658, F1: 0.0529584, HIT_RATE: 0.2990834, ARHR_ALL_HITS: 0.1610489, NOVELTY: 0.0046084, AVERAGE_POPULARITY: 0.1622455, DIVERSITY_MEAN_INTER_LIST: 0.9618034, DIVERSITY_HERFINDAHL: 0.9961779, COVERAGE_ITEM: 0.7580283, COVERAGE_ITEM_HIT: 0.0550047, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2876600, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0881612, SHANNON_ENTROPY: 10.1040455, RATIO_DIVERSITY_HERFINDAHL: 0.9965069, RATIO_DIVERSITY_GINI: 0.1741462, RATIO_SHANNON_ENTROPY: 0.7489386, RATIO_AVERAGE_POPULARITY: 3.1795732, RATIO_NOVELTY: 0.3102528,
#
# Iteration No: 495 ended. Search finished for the next optimal point.
# Time taken: 73.0672
# Function value obtained: -0.0188
# Current minimum: -0.0188
# Iteration No: 496 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.743823388914527, 'beta': 0.32586269629008846, 'topK': 59, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1284.02 column/sec. Elapsed time 19.09 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 26.28 sec. Users per second: 1524
# SearchBayesianSkopt: Config 495 is suboptimal. Config: {'alpha': 0.743823388914527, 'beta': 0.32586269629008846, 'topK': 59, 'implicit': True} - results: PRECISION: 0.0410450, PRECISION_RECALL_MIN_DEN: 0.0776760, RECALL: 0.0745482, MAP: 0.0187795, MAP_MIN_DEN: 0.0358849, MRR: 0.1392940, NDCG: 0.0707832, F1: 0.0529413, HIT_RATE: 0.2989835, ARHR_ALL_HITS: 0.1611743, NOVELTY: 0.0046089, AVERAGE_POPULARITY: 0.1621055, DIVERSITY_MEAN_INTER_LIST: 0.9618801, DIVERSITY_HERFINDAHL: 0.9961856, COVERAGE_ITEM: 0.7587628, COVERAGE_ITEM_HIT: 0.0548415, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2875640, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0882637, SHANNON_ENTROPY: 10.1066917, RATIO_DIVERSITY_HERFINDAHL: 0.9965146, RATIO_DIVERSITY_GINI: 0.1743486, RATIO_SHANNON_ENTROPY: 0.7491347, RATIO_AVERAGE_POPULARITY: 3.1768295, RATIO_NOVELTY: 0.3102911,
#
# Iteration No: 496 ended. Search finished for the next optimal point.
# Time taken: 73.4167
# Function value obtained: -0.0188
# Current minimum: -0.0188
# Iteration No: 497 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9961318574513791, 'beta': 0.8242599355065212, 'topK': 629, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 689.80 column/sec. Elapsed time 35.53 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 40.64 sec. Users per second: 985
# SearchBayesianSkopt: Config 496 is suboptimal. Config: {'alpha': 0.9961318574513791, 'beta': 0.8242599355065212, 'topK': 629, 'implicit': True} - results: PRECISION: 0.0185369, PRECISION_RECALL_MIN_DEN: 0.0298648, RECALL: 0.0277670, MAP: 0.0076532, MAP_MIN_DEN: 0.0122246, MRR: 0.0550425, NDCG: 0.0268771, F1: 0.0222320, HIT_RATE: 0.1343690, ARHR_ALL_HITS: 0.0646461, NOVELTY: 0.0061092, AVERAGE_POPULARITY: 0.0196494, DIVERSITY_MEAN_INTER_LIST: 0.9968115, DIVERSITY_HERFINDAHL: 0.9996787, COVERAGE_ITEM: 0.8073612, COVERAGE_ITEM_HIT: 0.0512099, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.1292368, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.2894298, SHANNON_ENTROPY: 13.0257031, RATIO_DIVERSITY_HERFINDAHL: 1.0000088, RATIO_DIVERSITY_GINI: 0.5717150, RATIO_SHANNON_ENTROPY: 0.9654995, RATIO_AVERAGE_POPULARITY: 0.3850762, RATIO_NOVELTY: 0.4112922,
#
# Iteration No: 497 ended. Search finished for the next optimal point.
# Time taken: 112.2931
# Function value obtained: -0.0077
# Current minimum: -0.0188
# Iteration No: 498 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9881179676572889, 'beta': 0.11047046371457572, 'topK': 398, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 808.49 column/sec. Elapsed time 30.31 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 31.41 sec. Users per second: 1275
# SearchBayesianSkopt: Config 497 is suboptimal. Config: {'alpha': 0.9881179676572889, 'beta': 0.11047046371457572, 'topK': 398, 'implicit': False} - results: PRECISION: 0.0371113, PRECISION_RECALL_MIN_DEN: 0.0723047, RECALL: 0.0696487, MAP: 0.0161924, MAP_MIN_DEN: 0.0315257, MRR: 0.1232014, NDCG: 0.0635576, F1: 0.0484218, HIT_RATE: 0.2798521, ARHR_ALL_HITS: 0.1408794, NOVELTY: 0.0040023, AVERAGE_POPULARITY: 0.3021115, DIVERSITY_MEAN_INTER_LIST: 0.8275629, DIVERSITY_HERFINDAHL: 0.9827542, COVERAGE_ITEM: 0.4340393, COVERAGE_ITEM_HIT: 0.0294610, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2691633, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0203682, SHANNON_ENTROPY: 7.5527247, RATIO_DIVERSITY_HERFINDAHL: 0.9830788, RATIO_DIVERSITY_GINI: 0.0402336, RATIO_SHANNON_ENTROPY: 0.5598279, RATIO_AVERAGE_POPULARITY: 5.9205698, RATIO_NOVELTY: 0.2694489,
#
# Iteration No: 498 ended. Search finished for the next optimal point.
# Time taken: 93.6668
# Function value obtained: -0.0162
# Current minimum: -0.0188
# Iteration No: 499 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7364562114576645, 'beta': 0.32535317622061344, 'topK': 59, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1282.50 column/sec. Elapsed time 19.11 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 26.26 sec. Users per second: 1525
# SearchBayesianSkopt: Config 498 is suboptimal. Config: {'alpha': 0.7364562114576645, 'beta': 0.32535317622061344, 'topK': 59, 'implicit': True} - results: PRECISION: 0.0410350, PRECISION_RECALL_MIN_DEN: 0.0776950, RECALL: 0.0745701, MAP: 0.0187801, MAP_MIN_DEN: 0.0358882, MRR: 0.1392422, NDCG: 0.0707785, F1: 0.0529386, HIT_RATE: 0.2989585, ARHR_ALL_HITS: 0.1611435, NOVELTY: 0.0046099, AVERAGE_POPULARITY: 0.1618137, DIVERSITY_MEAN_INTER_LIST: 0.9619977, DIVERSITY_HERFINDAHL: 0.9961974, COVERAGE_ITEM: 0.7597421, COVERAGE_ITEM_HIT: 0.0553719, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2875399, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0883236, SHANNON_ENTROPY: 10.1098058, RATIO_DIVERSITY_HERFINDAHL: 0.9965264, RATIO_DIVERSITY_GINI: 0.1744669, RATIO_SHANNON_ENTROPY: 0.7493655, RATIO_AVERAGE_POPULARITY: 3.1711114, RATIO_NOVELTY: 0.3103534,
#
# Iteration No: 499 ended. Search finished for the next optimal point.
# Time taken: 75.9744
# Function value obtained: -0.0188
# Current minimum: -0.0188
# Iteration No: 500 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7380350171270419, 'beta': 0.32597349922558744, 'topK': 59, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1295.54 column/sec. Elapsed time 18.92 sec
# EvaluatorHoldout: Processed 40039 (100.0%) in 26.24 sec. Users per second: 1526
# SearchBayesianSkopt: Config 499 is suboptimal. Config: {'alpha': 0.7380350171270419, 'beta': 0.32597349922558744, 'topK': 59, 'implicit': True} - results: PRECISION: 0.0410375, PRECISION_RECALL_MIN_DEN: 0.0777148, RECALL: 0.0745936, MAP: 0.0187769, MAP_MIN_DEN: 0.0358755, MRR: 0.1392663, NDCG: 0.0707762, F1: 0.0529466, HIT_RATE: 0.2991583, ARHR_ALL_HITS: 0.1611402, NOVELTY: 0.0046100, AVERAGE_POPULARITY: 0.1617460, DIVERSITY_MEAN_INTER_LIST: 0.9620303, DIVERSITY_HERFINDAHL: 0.9962006, COVERAGE_ITEM: 0.7595789, COVERAGE_ITEM_HIT: 0.0553719, ITEMS_IN_GT: 0.9847391, COVERAGE_USER: 0.9618055, COVERAGE_USER_HIT: 0.2877321, USERS_IN_GT: 0.9618055, DIVERSITY_GINI: 0.0883115, SHANNON_ENTROPY: 10.1100716, RATIO_DIVERSITY_HERFINDAHL: 0.9965296, RATIO_DIVERSITY_GINI: 0.1744431, RATIO_SHANNON_ENTROPY: 0.7493852, RATIO_AVERAGE_POPULARITY: 3.1697846, RATIO_NOVELTY: 0.3103626,
#
# Iteration No: 500 ended. Search finished for the next optimal point.
# Time taken: 76.2380
# Function value obtained: -0.0188
# Current minimum: -0.0188
# SearchBayesianSkopt: Search complete. Best config is 304: {'alpha': 0.7513264232341178, 'beta': 0.3247853600339675, 'topK': 58, 'implicit': True}
#
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'alpha': 0.7513264232341178, 'beta': 0.3247853600339675, 'topK': 58, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1132.29 column/sec. Elapsed time 21.64 sec
# SearchBayesianSkopt: Saving model in Experiments/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'Experiments/RP3betaRecommender_best_model_last'
# RP3betaRecommender: Saving complete

# %% [markdown]
# ### Search Results

# %%
from Recommenders.DataIO import DataIO

#explore the results of the search
data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

search_metadata.keys()
# Out:
# dict_keys(['time_on_test_avg', 'time_on_validation_avg', 'hyperparameters_best', 'result_on_last', 'time_on_train_avg', 'time_on_test_total', 'hyperparameters_df', 'result_on_validation_best', 'result_on_validation_df', 'cutoff_to_optimize', 'time_df', 'hyperparameters_best_index', 'result_on_test_df', 'time_on_validation_total', 'algorithm_name_search', 'time_on_train_total', 'exception_list', 'time_on_last_df', 'result_on_earlystopping_df', 'algorithm_name_recommender', 'metric_to_optimize', 'result_on_test_best'])

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#         alpha      beta topK implicit
# 0    0.202929  0.221299  572     True
# 1    0.668144  0.042523   15    False
# 2    0.757863  0.579954  240     True
# 3    0.759213  0.880315  511    False
# 4    0.901966  0.290338  762    False
# ..        ...       ...  ...      ...
# 495  0.743823  0.325863   59     True
# 496  0.996132   0.82426  629     True
# 497  0.988118   0.11047  398    False
# 498  0.736456  0.325353   59     True
# 499  0.738035  0.325973   59     True
#
# [500 rows x 4 columns]

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#            PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#     cutoff
# 0   10      0.037026                 0.071768  0.069056  0.016314    0.031629
# 1   10      0.024469                 0.044539  0.042389  0.011926    0.022464
# 2   10      0.039187                  0.07471  0.071813  0.017854    0.033952
# 3   10      0.018185                 0.030412  0.028513  0.007406    0.012315
# 4   10      0.036592                 0.071154  0.068537  0.016316    0.031724
# ...              ...                      ...       ...       ...         ...
# 495 10      0.041045                 0.077676  0.074548   0.01878    0.035885
# 496 10      0.018537                 0.029865  0.027767  0.007653    0.012225
# 497 10      0.037111                 0.072305  0.069649  0.016192    0.031526
# 498 10      0.041035                 0.077695   0.07457   0.01878    0.035888
# 499 10      0.041037                 0.077715  0.074594  0.018777    0.035875
#
#                  MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#     cutoff                                                        ...
# 0   10      0.123557  0.063508  0.048206  0.278354      0.141576  ...
# 1   10      0.095189  0.043985  0.031027  0.191338      0.106181  ...
# 2   10      0.132953  0.067481  0.050705  0.288069      0.153592  ...
# 3   10       0.05534  0.027039  0.022207  0.136717      0.063781  ...
# 4   10      0.123702  0.063351  0.047711  0.274657       0.14171  ...
# ...              ...       ...       ...       ...           ...  ...
# 495 10      0.139294  0.070783  0.052941  0.298983      0.161174  ...
# 496 10      0.055042  0.026877  0.022232  0.134369      0.064646  ...
# 497 10      0.123201  0.063558  0.048422  0.279852      0.140879  ...
# 498 10      0.139242  0.070779  0.052939  0.298959      0.161144  ...
# 499 10      0.139266  0.070776  0.052947  0.299158       0.16114  ...
#
#            COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#     cutoff
# 0   10          0.961805          0.267722    0.961805        0.01708
# 1   10          0.961805           0.18403    0.961805       0.136775
# 2   10          0.961805          0.277066    0.961805       0.107489
# 3   10          0.961805          0.131495    0.961805       0.271403
# 4   10          0.961805          0.264167    0.961805       0.064785
# ...                  ...               ...         ...            ...
# 495 10          0.961805          0.287564    0.961805       0.088264
# 496 10          0.961805          0.129237    0.961805        0.28943
# 497 10          0.961805          0.269163    0.961805       0.020368
# 498 10          0.961805           0.28754    0.961805       0.088324
# 499 10          0.961805          0.287732    0.961805       0.088312
#
#            SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#     cutoff
# 0   10             7.64087                    0.98379             0.033738
# 1   10           11.662922                   0.999448             0.270174
# 2   10           10.020323                   0.994837             0.212325
# 3   10           12.890115                   0.999933             0.536105
# 4   10            8.253053                   0.983478             0.127971
# ...                    ...                        ...                  ...
# 495 10           10.106692                   0.996515             0.174349
# 496 10           13.025703                   1.000009             0.571715
# 497 10            7.552725                   0.983079             0.040234
# 498 10           10.109806                   0.996526             0.174467
# 499 10           10.110072                    0.99653             0.174443
#
#            RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#     cutoff
# 0   10                  0.566361                 5.776645      0.271049
# 1   10                  0.864487                 1.111383      0.348407
# 2   10                  0.742733                 3.547596      0.311944
# 3   10                  0.955449                 0.352524      0.409082
# 4   10                  0.611738                 5.730123      0.281061
# ...                          ...                      ...           ...
# 495 10                  0.749135                  3.17683      0.310291
# 496 10                    0.9655                 0.385076      0.411292
# 497 10                  0.559828                  5.92057      0.269449
# 498 10                  0.749366                 3.171111      0.310353
# 499 10                  0.749385                 3.169785      0.310363
#
# [500 rows x 27 columns]

# %% [markdown]
# This are the best hyperparameters found by the bayesian search -> We will train our model using these

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'alpha': 0.7513264232341178,
#  'beta': 0.3247853600339675,
#  'topK': 58,
#  'implicit': True}
